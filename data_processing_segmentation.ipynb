# %%
# Run if working locally
# %load_ext autoreload
# %autoreload 2
# %load_ext nb_black

import sys, os
import config

config.root_path = os.path.abspath(os.path.join(os.getcwd()))
sys.path.insert(0, config.root_path)
import nltk
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
config.root_path
# Out:
# '/Users/amitmaraj/Documents/PhD/context-encoder-qmsum'

# %%
import json

# read the dataset
# please enter the path of your data
split = "train"
data_path = "./data/ALL/jsonl/" + split + ".jsonl"
data = []
with open(data_path) as f:
    for line in f:
        data.append(json.loads(line))
n_meetings = len(data)
print("Total {} meetings in the {} set.".format(n_meetings, split))
# Out:
# Total 162 meetings in the train set.

# %%
from nltk import word_tokenize

# tokneize a sent
def tokenize(sent):
    tokens = " ".join(word_tokenize(sent.lower()))
    return tokens

# %%
# filter some noises caused by speech recognition
def clean_data(text):
    text = text.replace("{vocalsound}", "")
    text = text.replace("{disfmarker}", "")
    text = text.replace("a_m_i_", "ami")
    text = text.replace("l_c_d_", "lcd")
    text = text.replace("p_m_s", "pms")
    text = text.replace("t_v_", "tv")
    text = text.replace("{pause}", "")
    text = text.replace("{nonvocalsound}", "")
    text = text.replace("{gap}", "")
    return text

# %%
clean_data("Okay , it's a {disfmarker}")
# Out:
# "Okay , it's a "

# %%
# data

# %% [markdown]
# ### Exploration

# %% [markdown]
# To get all the topics based on the given spans, each text span is for the turn (i.e., the speaker's turn). So each text spen is the entirety of a speakers speech for that period. Let's explore with one sample.

# %%
first_sample = data[1]
topic_list = first_sample["topic_list"]
meeting_transcripts = first_sample["meeting_transcripts"]

# %%
topic_list, meeting_transcripts
# Out:
# ([{'topic': 'Prototype presentation', 'relevant_text_span': [['0', '38']]},
#   {'topic': 'Budget balancing', 'relevant_text_span': [['39', '254']]},
#   {'topic': 'Product evaluation', 'relevant_text_span': [['255', '426']]},
#   {'topic': 'A summary for the whole project',
#    'relevant_text_span': [['427', '516']]}],
#  [{'speaker': 'Project Manager',
#    'content': "That should hopefully do the trick , um . 'Kay . Sorry about the small delay . Falling a little bit behind schedule . And that's uh fifteen twenty five . Okay . So just to try and roughly go over what we agreed in the last one , um we're gonna go for something uh uh how was it ? Uh The new black , I believe ."},
#   {'speaker': 'Marketing', 'content': '{gap} .'},
#   {'speaker': 'Project Manager',
#    'content': "Um something that looks good 'cause that seems to be in preference to actual functionality in the end , though we should never avoid functionality , of course . Uh many of our components are gonna be standard , off the shelf , but it seemed like we were gonna require at least an advanced chip and we were still very much for the idea of using an L_C_D_ display . Um other things were we were hoping to use rubber , most likely gonna be double curved , etcetera . Okay . So um due to your hard work , we might as well let the uh two designers go first , and uh show us the prototype ."},
#   {'speaker': 'User Interface', 'content': "Okay , it's a {disfmarker}"},
#   {'speaker': 'Project Manager',
#    'content': "Quite how the best way to do this is , I'm not sure ,"},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface', 'content': '{gap} I think if we both step up'},
#   {'speaker': 'Project Manager', 'content': 'but {disfmarker}'},
#   {'speaker': 'User Interface',
#    'content': 'and uh outline our ideas . Okay . Now do {disfmarker} uh doing the prototype gave us a bit more insight into the ergonomics of the design . Um for one thing , it turned out that the only point at which it needs to be articulated for handedness is um is h i is down here for the uh L_E_D_ . As it turned out , the whole thing transfers from the right to left hand fairly well from the point of view of operating the uh function buttons and joystick , though it might be an idea to be able to a adjust the positions for the base of the joystick just a little bit for uh {disfmarker}'},
#   {'speaker': 'Project Manager', 'content': 'Okay .'},
#   {'speaker': 'User Interface',
#    'content': "{gap} ju just a thought . You could simply have a slightly ovoid shaped joystick that could then just be turn uh twisted round , so that the uh sticky uh so that the bit that sticks out a bit more is on one side or the other . But as you as you see with the uh {vocalsound} with holding it in the left hand , the L_ uh the L_C_D_ is nowhere useful , so that would need to be articulated uh if we're going to retain {gap} ergonomic design . Um now I I got your note about uh keeping the cost down ."},
#   {'speaker': 'Project Manager', 'content': "I'm afraid yeah ."},
#   {'speaker': 'User Interface', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager', 'content': "We'll go into that a bit more ,"},
#   {'speaker': 'User Interface',
#    'content': '{gap} this design could be done with um with uh plastic casing .'},
#   {'speaker': 'Project Manager', 'content': 'but please go on .'},
#   {'speaker': 'User Interface',
#    'content': "Though I would recommend around the grip part here in the middle , having maybe just a rubber grip over that which would allow for a slightly more sort of bio-morphic form , and a bit more ergonomic as well . As for the um as for the single curve , um well this edge and this edge , like I say it would be nice to have some curvature to it , but it's not absolutely necessary . Really the curve that's most needed is the underside so that the jo so that the joystick rests over the the edge of the hand like this . Um and you have the uh transmitter here and a wee speaker for the uh for the uh for the uh fi uh for the remote control finder . So ."},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface', 'content': 'Any further comments ?'},
#   {'speaker': 'Industrial Designer',
#    'content': "Um obviously it's gonna be bulkier than how it looks , because it's gonna be flat on one side , so the L_C_D_ will be s sticking down like this , won't it ?"},
#   {'speaker': 'User Interface', 'content': 'Mm-hmm . Yeah .'},
#   {'speaker': 'Industrial Designer',
#    'content': "'Cause it {disfmarker} you can't get it curved ."},
#   {'speaker': 'User Interface', 'content': 'Yeah , I mean the'},
#   {'speaker': 'Industrial Designer', 'content': 'Uh because of costs .'},
#   {'speaker': 'User Interface', 'content': 'uh {disfmarker} Yeah .'},
#   {'speaker': 'Industrial Designer',
#    'content': "And it's plastic as well , so it won't be as comfortable on the hand ."},
#   {'speaker': 'User Interface',
#    'content': "Yeah . I mean with the with the rubber design it could i you know it could pretty much mould very much to the to the user's hand ."},
#   {'speaker': 'Project Manager', 'content': 'Mm .'},
#   {'speaker': 'User Interface',
#    'content': 'One nice wee feature if we could if we could still do the rubber , I though of was to have {gap} the uh rubber extend beyond the end of the uh {vocalsound} of the rigid substructure . So it has a wee sort of tail that you just drape over your wrist so it stays in position nicely .'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface', 'content': 'Mm . Lovely . Um .'},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah , {gap} . {vocalsound}'},
#   {'speaker': 'Project Manager', 'content': 'Okay , yeah . Great . Um .'},
#   {'speaker': 'Marketing',
#    'content': "Right . Yeah I've got a {disfmarker} if you load up my evaluation document ."},
#   {'speaker': 'Project Manager', 'content': 'Yeah , okay {gap} .'},
#   {'speaker': 'User Interface', 'content': 'Okay .'},
#   {'speaker': 'Project Manager', 'content': 'Excellent work .'},
#   {'speaker': 'Marketing', 'content': 'Mm .'},
#   {'speaker': 'Project Manager', 'content': 'Um .'},
#   {'speaker': 'Marketing',
#    'content': "Uh evaluation . {vocalsound} Basic point uh have a list of criteria that we need to rate the prototype by . {vocalsound} Um then we will {disfmarker} it's a seven s um seven seven step kinda evaluation process . So um not seven steps , seven scale . So after we've finished doing all the ratings for each criteria , we average that and that will give us some type of uh confidence in our prototype . And uh the criteria {gap} based on Real Reactions' kinda goals and policies , marketing strategies , and also those I put together from the user requirements phase . 'Kay . Um if you flip the {disfmarker} {vocalsound} So , those are the criteria . And uh perhaps I could have put 'em a bit better , but you notice a few things that we've totally abandoned , which means {vocalsound} that uh the product will score very badly on some of those points ."},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': "{vocalsound} Put it mildly . So we have um true ? One , t Seven , eight , oh . Fourth . Okay , so we have to go through each point . If we imagine it's actually straight , and just give it a a score . So um how well would you say the prototype is uh how well have we realised the dream of being able to stop remotes from from being lost , or to be able to find them once they are lost . I mean , uh is the homing thing still {disfmarker} the locator , is that still {disfmarker}"},
#   {'speaker': 'User Interface',
#    'content': "Yeah , that's still part of the design ."},
#   {'speaker': 'Marketing',
#    'content': 'Sure . And Adam , we can keep that in ?'},
#   {'speaker': 'Project Manager',
#    'content': "Yeah , I believe so . So I mean I don't think anybody could actually stop a remote being lost ,"},
#   {'speaker': 'Marketing', 'content': 'Okay .'},
#   {'speaker': 'Project Manager',
#    'content': "'cause that would mean doing something about the human element ,"},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Sure .'},
#   {'speaker': 'Project Manager',
#    'content': "but I'd like to think that we've done something about finding the damn thing once we have ."},
#   {'speaker': 'Marketing', 'content': 'T'},
#   {'speaker': 'User Interface',
#    'content': 'Mm . Mm . And making it a bright colour helps'},
#   {'speaker': 'Marketing', 'content': 'Sure .'},
#   {'speaker': 'User Interface',
#    'content': 'with the {disfmarker} personally I would have gone for purple {gap} . {vocalsound}'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': 'Mm . Bright colour . So we still have that noise thing , yeah ?'},
#   {'speaker': 'User Interface', 'content': 'Mm-hmm .'},
#   {'speaker': 'Marketing',
#    'content': "Os on a scale of one to seven , how would you guys rate it for finding {gap} finding it once it's lost ?"},
#   {'speaker': 'User Interface', 'content': "I'd say number one ."},
#   {'speaker': 'Marketing', 'content': 'Number one ?'},
#   {'speaker': 'Industrial Designer', 'content': 'One . Yeah . {vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': 'Okay . Number number one for the first criteria .'},
#   {'speaker': 'User Interface',
#    'content': "I think w if it was just the sounder then th {gap} I mean something I've found with uh w w with say tr trying to find uh a cordless phone or a m mobile , you can hear it , but you can't quite pin it dow pin down where it is ."},
#   {'speaker': 'Marketing',
#    'content': 'Yeah you can tell what room the mobile is {disfmarker}'},
#   {'speaker': 'User Interface', 'content': 'Bu'},
#   {'speaker': 'Industrial Designer',
#    'content': "What about {disfmarker} what if the the volume on the T_V_'s turned up massively and uh you just wanna turn down the volume {gap} can't find remote . Suppose you have to go to the T_V_ and do it manually . Mm ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'User Interface', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager', 'content': 'Mm . Um'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Industrial Designer',
#    'content': "Like y you wouldn't hear the speaker {gap} ."},
#   {'speaker': 'Marketing', 'content': 'Mm-hmm .'},
#   {'speaker': 'Project Manager',
#    'content': "just before we go through all of the steps here , um well what we'll do is"},
#   {'speaker': 'Marketing', 'content': 'You wanna say something ?'},
#   {'speaker': 'Project Manager',
#    'content': "um if we can look at the criteria you're gonna evaluate , and then we'll come back to the product evaluation if that's alright ."},
#   {'speaker': 'Marketing', 'content': "That's fine ."},
#   {'speaker': 'Project Manager', 'content': 'Yeah , is that {disfmarker}'},
#   {'speaker': 'Marketing', 'content': "Oh that's that's fine ."},
#   {'speaker': 'Project Manager',
#    'content': "Um so is there anything here that you that you wanted to cover as in the criteria that you've covered ? And then we'll come back pretty much promptly to this ."},
#   {'speaker': 'Marketing',
#    'content': 'What do you mean cr is there anything I wanna {disfmarker}'},
#   {'speaker': 'Project Manager',
#    'content': 'I is there any of these criteria that need any explaining ? Or is there anything that yous thought tha really would stand out compared to the others ?'},
#   {'speaker': 'Marketing',
#    'content': "Um , a few . {vocalsound} Something I neglected from my initial research is that Real Reactions has a a goal strategy that all of the products be inspired by material fashion , and clothing fashion . That is why fruit and veg being popular in the home and in clothing was important and they want all their products to be somehow inspired by current trends in fashion . So they say we put the fashion in electronics , well they really mean it they they're very big on fashion ,"},
#   {'speaker': 'Project Manager', 'content': 'Okay .'},
#   {'speaker': 'Marketing',
#    'content': "so . That's this bit right here . And uh this bit is this one easy to use for visitors or for anybody ? I guess it's just the same as saying easy to use interface , so it's kinda condensed into one . And we can come back to it , you said ."},
#   {'speaker': 'Project Manager', 'content': 'Okay .'},
#   {'speaker': 'Marketing', 'content': 'So .'},
#   {'speaker': 'Project Manager',
#    'content': "No and which we will do very very shortly . Um . Okay . Slight problem we had was that we have an amazing four Euros over budget for what we were hoping to do . Um most of it stems from the use of the L_C_D_ which I think in the end accounted for about half of our expenditure because of course we required a chip as well . Um the only way to get this down was either to ditch the a L_C_D_ , at which point we've removed a large part of how we were gonna interface , {gap} require more buttons , etcetera . Or what we did was that we um we as in I as I was quickly going over it was altering the actual structure . Um changing it to plastic and a solid unit with a single curve design would allow us to come back into the um proposed costs and we're just scraping it in , we've got point two of a Euro left over there . So we're just managing it really . Even then as well , um there was no criteria technically defined for a joystick so I've used what I think's appropriate . With any luck that won't mean that we've incurred more cost than we can actually afford to . It blows a lot of our really good ideas kind of slightly to one side , for example the possibility of having a U_S_B_ connection is definitely not viable now . Um ."},
#   {'speaker': 'Marketing', 'content': 'Different languages ?'},
#   {'speaker': 'Project Manager',
#    'content': "That should still be viable . We've got an advanced chip , we've got the use of the L_C_D_ . So being able to communicate in multiple languages is still very much a possibility ."},
#   {'speaker': 'Marketing', 'content': 'Yeah . {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Um but what's something we need to decide on is how we're gonna go from here . {vocalsound} We do need to try and come up with an idea which could be continued with other people if need be . Um . We can I can bring the excel up sheet up and uh show you if you wish um . I really think as m much as it pains me is that we might have to go with plastic and some kind of solid design , possibly meaning that the L_C_D_ wouldn't be in this perfect place . It might be s stuck like slightly between what would be good for left handed and what would be good for a right handed person ."},
#   {'speaker': 'User Interface',
#    'content': 'Mm-hmm I suppose o one thing that could be done is h {vocalsound} is have it um circular and have it s {vocalsound} so that the uh the pink {gap} actually goes a bit over the pinkie finger . Mm .'},
#   {'speaker': 'Project Manager', 'content': 'Okay .'},
#   {'speaker': 'Marketing', 'content': 'Mm .'},
#   {'speaker': 'User Interface', 'content': 'So that uh th'},
#   {'speaker': 'Project Manager',
#    'content': 'It very much is about making concessions , unfortunately . Um .'},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Marketing',
#    'content': 'Do you have any data on how much um different prints cost ? I mean can you get the entire thing printed with a design um ?'},
#   {'speaker': 'Project Manager',
#    'content': 'Um b b b da is {disfmarker} you mean on the plastic , or ?'},
#   {'speaker': 'Marketing', 'content': '{gap} .'},
#   {'speaker': 'Project Manager',
#    'content': "Let's have a look . You now have as much information as I do . {vocalsound} Um ."},
#   {'speaker': 'Marketing', 'content': 'Yeah , yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "So as you can see here , for example , the battery really not very little choice in that one . We've gone for one of the cheaper options as well . Unfortunately we require the advanced chip if we're gonna do what we're needing to . I've said single curved . We really do need it to be that way for the ergonomics of it . Um plastic for some reason incurs no cost , which I've had to very much make advantage of , despite the fact that rubber's only got a value of two Euros per unit . Problem comes here as you can see in the interface . Um if I've read this thing correctly , then we can save point five of a Euro here in that it's not per push button . That might make sense , because then a numeric keypad would come in at um what , four point five Euros , which is an awful lot , so that could well be wrong . Even if we save point five there , it would just mean that we're most likely placing it in actually just gaining a colour for the unit , which has had to be put to one side . As you can see , the use of an L_C_ display um advanced chip and what would determine the scroll wheel here as well because it's an integrated scroll scroll wheel push button that wasn't quite what I think they had in mind with a joystick ."},
#   {'speaker': 'Marketing',
#    'content': "Why would why would that be more expensive than an individual push button and scroll wheel together ? That's quite significantly expensive ."},
#   {'speaker': 'Project Manager',
#    'content': "I {disfmarker} that's something you'll have to take up with the bean counters . Um"},
#   {'speaker': 'Marketing', 'content': '{gap} .'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface', 'content': 'Mm . {gap} yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "as you can see I mean that's taken up well over half of the price ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "So um I'm very much open to suggestions of where we go , but because we need to shed what was four Euros off of the um the price of for what we really desired , this one comes in under price as you can see , but this was the one that sacrificed the material for the case and for the actual case design ."},
#   {'speaker': 'Marketing',
#    'content': "We don't even have uh speakers here . The {disfmarker} like uh we uh {disfmarker} what about speakers and transmitters and stuff like that ? Have we factored that in ?"},
#   {'speaker': 'Industrial Designer', 'content': 'Mm .'},
#   {'speaker': 'Project Manager',
#    'content': "Uh no , we haven't , not {disfmarker}"},
#   {'speaker': 'Marketing',
#    'content': "Transmitter , receiver , speakers . Plus the extra device itself that's gonna be on a T_V_ ."},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': 'Is that gonna be a button , or {disfmarker}'},
#   {'speaker': 'Project Manager',
#    'content': "That'll {gap} it literally would just be a button ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager', 'content': 'We might have to {disfmarker}'},
#   {'speaker': 'Industrial Designer',
#    'content': "That's too expensive {gap} isn't it ?"},
#   {'speaker': 'Project Manager',
#    'content': 'It looks like almost nothing {disfmarker} Mm . Oh good call , I missed that .'},
#   {'speaker': 'Marketing', 'content': "I I mean it's not on here , but um ."},
#   {'speaker': 'Project Manager',
#    'content': "{gap} that's a very valid point ."},
#   {'speaker': 'Marketing',
#    'content': 'Did they s do we have to use an advanced chip for the L_C_D_ ?'},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah .'},
#   {'speaker': 'Marketing',
#    'content': "Okay . Well that's {disfmarker} yeah ."},
#   {'speaker': 'Project Manager',
#    'content': "So if we're gonna go with the L_C_ display , then that's {disfmarker}"},
#   {'speaker': 'Marketing',
#    'content': "What's a hand dyna dynamo ? You have to wind it up ?"},
#   {'speaker': 'Project Manager', 'content': 'I believe so , yeah .'},
#   {'speaker': 'Marketing', 'content': '{vocalsound}'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': 'That would probably not be in keeping with the um the fashion statement and such ,'},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Technology . Yeah .'},
#   {'speaker': 'Industrial Designer', 'content': 'Fashion .'},
#   {'speaker': 'Project Manager', 'content': 'yeah .'},
#   {'speaker': 'Marketing', 'content': 'Okay .'},
#   {'speaker': 'Industrial Designer',
#    'content': 'So basically the only new thing is the L_C_D_ on the remote now .'},
#   {'speaker': 'Project Manager',
#    'content': 'Being manipulated by the joystick , yeah .'},
#   {'speaker': 'Industrial Designer', 'content': 'Oh , and joystick , yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "Which I'm defining as scroll wheel . Um ."},
#   {'speaker': 'Marketing',
#    'content': "And we couldn't replace the joystick , right ? Because we would need four extra buttons to replace it , up down left and right , and that would be more expensive than a {disfmarker} but is a scroll wheel not just back and forward ?"},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Project Manager',
#    'content': "Yeah it's just because there was no actual definition for what a joystick might be , that that's what I've labelled it for the purposes of this evaluation ."},
#   {'speaker': 'Industrial Designer',
#    'content': 'So {disfmarker} The L_C_D_ basically is the big selling point of'},
#   {'speaker': 'Project Manager',
#    'content': 'If we remove the L_C_ display , we could save ourselves'},
#   {'speaker': 'Industrial Designer', 'content': 'the remote .'},
#   {'speaker': 'Project Manager',
#    'content': 'a fair amount . Which you could {vocalsound} {disfmarker}'},
#   {'speaker': 'Industrial Designer',
#    'content': "But that's what makes it uh original though ,"},
#   {'speaker': 'User Interface',
#    'content': 'Mm . I think {gap} if we remove the the L_C_ display then there was absolutely no point to any of these meetings'},
#   {'speaker': 'Marketing', 'content': 'Yeah . {vocalsound}'},
#   {'speaker': 'Industrial Designer', 'content': "isn't it ?"},
#   {'speaker': 'User Interface',
#    'content': 'and we just {gap} we could just put our branding on any other remote control .'},
#   {'speaker': 'Marketing', 'content': 'Yeah . Yeah . Um . Uh k'},
#   {'speaker': 'Project Manager',
#    'content': "It's a shame . We should possibly have {disfmarker} If we could've increased the price we could've manufactured that and we could've got something far closer to what we were hoping to ."},
#   {'speaker': 'Marketing',
#    'content': "Does this does this bear in mind that {disfmarker} I mean it's a bit ridiculous that they're gonna charge us what is it , like this much money for three million if we're gonna buy three million components ,"},
#   {'speaker': 'Project Manager',
#    'content': "Again , you'll have to argue with the accountants on that one ."},
#   {'speaker': 'Marketing', 'content': 'you know .'},
#   {'speaker': 'Project Manager',
#    'content': "Um but for the purposes of this meeting , I'm {disfmarker} we're gonna have to stick with these figures ."},
#   {'speaker': 'Marketing', 'content': "Mm . 'Kay ."},
#   {'speaker': 'Project Manager',
#    'content': "So , I would say that it would seem like the general opinion is we're gonna keep the L_C_ display 'cause it's about what really separates us , {vocalsound} despite the cost it's gonna incur . Um"},
#   {'speaker': 'Marketing', 'content': 'I think so .'},
#   {'speaker': 'Project Manager',
#    'content': 'are people maybe not happy with , but are willing to go ahead with this in going for a plastic solid case , to keep the L_C_D_ ?'},
#   {'speaker': 'User Interface',
#    'content': 'Mm-hmm . Um yeah {gap} I mean one thing , I mean ho uh how much extra would it be to to keep I mean {vocalsound} keep the um the articulation ?'},
#   {'speaker': 'Project Manager',
#    'content': "It's hard to tell . Um I would say that you're at least gonna take double curved ,"},
#   {'speaker': 'User Interface', 'content': "This is what I'm wondering ."},
#   {'speaker': 'Project Manager',
#    'content': "and even then I'm not quite sure if that's incorporating the idea of articulation ."},
#   {'speaker': 'User Interface', 'content': 'Oh'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'User Interface',
#    'content': "no , I think I I it d that it needn't require it to be double curved ."},
#   {'speaker': 'Industrial Designer',
#    'content': 'It can be s yeah , it can still be single curved ,'},
#   {'speaker': 'User Interface',
#    'content': "It's uh it's just {vocalsound} it's just {vocalsound} it's just that the case would come in t {vocalsound} would be made in two parts and then joined together with an articulation ."},
#   {'speaker': 'Industrial Designer', 'content': 'but {disfmarker}'},
#   {'speaker': 'Project Manager',
#    'content': 'Single curved with articulation ?'},
#   {'speaker': 'Industrial Designer', 'content': 'You just {gap} .'},
#   {'speaker': 'Marketing',
#    'content': "Could we could we not get rid of the curvy the curvous the curvaceousness and focus on the menu being the best interface ? 'Cause like we {disfmarker} do we have re restrictions on software ?"},
#   {'speaker': 'Industrial Designer',
#    'content': "That's what we need for the joystick I think though ."},
#   {'speaker': 'User Interface', 'content': 'Mm . Yeah , I mean'},
#   {'speaker': 'Marketing', 'content': 'Oh but there has to be {disfmarker}'},
#   {'speaker': 'User Interface',
#    'content': 'and {vocalsound} I mean the uh I mean if you look uh if you look closer at the uh at the prototype here , the lines here along the grip are actually quite straight . Um I mean {gap} yeah ,'},
#   {'speaker': 'Project Manager',
#    'content': '{vocalsound} But the curves all o over {gap} hand ,'},
#   {'speaker': 'User Interface',
#    'content': "on the {gap} on the L_C_D_ I mean although we've done it with a curve it"},
#   {'speaker': 'Project Manager', 'content': 'is it ?'},
#   {'speaker': 'User Interface',
#    'content': "could just as easily be done um without curves . The curve that's really needed is up here ,"},
#   {'speaker': 'Marketing', 'content': '{gap} joystick .'},
#   {'speaker': 'User Interface',
#    'content': 'to put uh to keep the joystick in a good ergonomic position for it to have it rest on the top of the hand .'},
#   {'speaker': 'Marketing', 'content': 'Okay . Sure . Okay , my bad .'},
#   {'speaker': 'Project Manager',
#    'content': "We wouldn't actually save a lot by reducing it anyway , so I mean for the purposes of this meeting maybe we can state that single curve still allows articulation ."},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Project Manager',
#    'content': 'Um unless we hear otherwise we could go ahead with that proposal .'},
#   {'speaker': 'Marketing',
#    'content': 'So I think the product is not gonna perform so well for my criteria .'},
#   {'speaker': 'Project Manager',
#    'content': "Which is what we can get onto now . As long as {disfmarker} so are we gonna say {disfmarker} {gap} w we have to keep an eye on the time as well , but we're gonna say um single curved design {vocalsound} {disfmarker}"},
#   {'speaker': 'Marketing',
#    'content': 'Oh , wait a minute . Sample speaker ? What is a sample speaker ? Is that somewhat similar to what we want ?'},
#   {'speaker': 'Project Manager', 'content': 'It could well be ,'},
#   {'speaker': 'User Interface', 'content': 'Mm no'},
#   {'speaker': 'Project Manager', 'content': 'but at a cost of {disfmarker}'},
#   {'speaker': 'User Interface',
#    'content': "that's that voice response thing that we got the email about ."},
#   {'speaker': 'Industrial Designer', 'content': 'Costs four .'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'User Interface',
#    'content': 'But I thought it was just completely pointless .'},
#   {'speaker': 'Marketing',
#    'content': 'You got a email about voice response ?'},
#   {'speaker': 'User Interface', 'content': 'Yeah .'},
#   {'speaker': 'Marketing', 'content': 'I did not ,'},
#   {'speaker': 'User Interface', 'content': 'Alright .'},
#   {'speaker': 'Marketing', 'content': 'so .'},
#   {'speaker': 'User Interface',
#    'content': 'B i basically it was {gap} saying that our labs had come up with a chip that you could , you know , say hello to , and it would say hello back in a friendly female voice {gap} . {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Okay , yeah we'll definitely won't go with that one ."},
#   {'speaker': 'Marketing',
#    'content': "We won't go with that one , did you say ?"},
#   {'speaker': 'Project Manager',
#    'content': "Yeah , that's voice recognition , so ."},
#   {'speaker': 'Marketing',
#    'content': 'I mean I {disfmarker} we {disfmarker} Okay , okay .'},
#   {'speaker': 'Project Manager',
#    'content': 'Um . So , okay yeah , battery definitely , {disfmarker}'},
#   {'speaker': 'Marketing',
#    'content': "So it looks like we're gonna get rid of the whole loca {vocalsound} locator thing ."},
#   {'speaker': 'Project Manager',
#    'content': 'It looks like it unless we can manage to put it in under point two Euros , um .'},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah .'},
#   {'speaker': 'Marketing',
#    'content': '{vocalsound} Okay . {vocalsound} Okay .'},
#   {'speaker': 'User Interface', 'content': 'Mm-hmm .'},
#   {'speaker': 'Project Manager',
#    'content': "Maybe even slight well oh yeah , pretty much point two Euros , I'd say . So we'll leave that one for now . {gap} we'll just have {disfmarker}"},
#   {'speaker': 'Industrial Designer',
#    'content': 'Are we going for a special colour at all ?'},
#   {'speaker': 'Project Manager',
#    'content': "It's uh a case of um I'm uh slightly unsure . One {disfmarker} point five of a Euro for one push button doesn't sound quite right . So maybe it's a case of a push button is maybe one or more . Um ."},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Industrial Designer', 'content': 'Well'},
#   {'speaker': 'Project Manager', 'content': 'At which point if {disfmarker}'},
#   {'speaker': 'Industrial Designer',
#    'content': 'I was {gap} for a case . Or had you already incorporated that ?'},
#   {'speaker': 'Marketing', 'content': 'Oh , special colour for the case .'},
#   {'speaker': 'Project Manager',
#    'content': "Well you got point five there . It's literally a case of whether or not this is correct . I'm not quite sure if they're {disfmarker} I don't think they mean point five Euros per button ."},
#   {'speaker': 'User Interface', 'content': 'Okay , well'},
#   {'speaker': 'Marketing', 'content': 'Mm-hmm .'},
#   {'speaker': 'User Interface',
#    'content': "l let's say that and then we can have our special coloured case"},
#   {'speaker': 'Project Manager', 'content': 'So'},
#   {'speaker': 'User Interface',
#    'content': 'and then we at least have {disfmarker} make it a little harder to lose .'},
#   {'speaker': 'Project Manager', 'content': 'There we go .'},
#   {'speaker': 'User Interface',
#    'content': 'Because most m most remotes are a fairly dingy colour that gets camouflaged under any pile of crap in a living room .'},
#   {'speaker': 'Marketing',
#    'content': "W what's the default colour ? White or black ?"},
#   {'speaker': 'Project Manager',
#    'content': "Black's probably the normal colour you'd say ,"},
#   {'speaker': 'User Interface', 'content': 'Or grey .'},
#   {'speaker': 'Project Manager', 'content': 'yeah .'},
#   {'speaker': 'Marketing', 'content': 'Right .'},
#   {'speaker': 'Project Manager',
#    'content': "I quite like that colour that you're fetching there ,"},
#   {'speaker': 'User Interface', 'content': 'Yellow . {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "it's uh definitely for make it glow in the dark even better ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': '{vocalsound} So will we go with that then ?'},
#   {'speaker': 'User Interface', 'content': 'Okay .'},
#   {'speaker': 'Project Manager',
#    'content': "It's not and we can see {disfmarker}"},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "we'll come back to uh your evaluation"},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Sure .'},
#   {'speaker': 'Project Manager',
#    'content': "which you're probably now going to pan us but there we go ."},
#   {'speaker': 'Marketing', 'content': 'Okay . Okay .'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing', 'content': 'So uh {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Just to give you an idea , um you want to go maybe a bit quickly as well , I'm not sure how much time . We've not hit the five minute mark warning yet ,"},
#   {'speaker': 'Marketing', 'content': 'Right okay . Okay .'},
#   {'speaker': 'Project Manager', 'content': 'but .'},
#   {'speaker': 'Industrial Designer',
#    'content': "Think it's ten minutes left . {vocalsound}"},
#   {'speaker': 'Project Manager', 'content': 'Ten .'},
#   {'speaker': 'Marketing',
#    'content': "'Kay . Ability to stop remotes from being lost or to find them once they are lost . Um . Okay ."},
#   {'speaker': 'Industrial Designer', 'content': 'Special colour .'},
#   {'speaker': 'Marketing', 'content': 'Special colour .'},
#   {'speaker': 'Project Manager', 'content': 'Mm mm four ?'},
#   {'speaker': 'Marketing', 'content': 'Uh uh four .'},
#   {'speaker': 'Project Manager', 'content': 'Three ? Mm .'},
#   {'speaker': 'User Interface',
#    'content': 'Three . I think we can do three .'},
#   {'speaker': 'Marketing',
#    'content': "Three if we're being generous , I feel ."},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface',
#    'content': "{vocalsound} Th the special colour doesn't {disfmarker} would I think make a difference ."},
#   {'speaker': 'Marketing',
#    'content': "Think we're being generous here with three ."},
#   {'speaker': 'Industrial Designer', 'content': 'Three .'},
#   {'speaker': 'User Interface',
#    'content': "It makes it stand out from {disfmarker} you know it's lost in a big pile of crap , it stands out from the rest of the crap . {vocalsound}"},
#   {'speaker': 'Marketing', 'content': 'Mm . Yeah . {vocalsound} Okay .'},
#   {'speaker': 'Project Manager', 'content': 'Okay .'},
#   {'speaker': 'Marketing',
#    'content': "Reduce the number of unused buttons . We're down to t two buttons , is it ?"},
#   {'speaker': 'User Interface', 'content': 'Two buttons and a joystick .'},
#   {'speaker': 'Project Manager', 'content': 'Two buttons .'},
#   {'speaker': 'Marketing', 'content': "Okay , so that's a one . You know ,"},
#   {'speaker': 'User Interface', 'content': 'Totally .'},
#   {'speaker': 'Marketing', 'content': "where that's {disfmarker}"},
#   {'speaker': 'Project Manager',
#    'content': "Yeah . I'd say we're doing well there ."},
#   {'speaker': 'Marketing',
#    'content': 'Okay , that was good . Easy to use interface , buttons menu , menus {gap}'},
#   {'speaker': 'Project Manager',
#    'content': '{vocalsound} {vocalsound} Mm-hmm .'},
#   {'speaker': 'Marketing',
#    'content': "that's yeah that's good . {vocalsound} 'Kay that's {disfmarker} we're not doing so badly . Um {vocalsound} easy to use {disfmarker} oh okay , let's forget that one . Fancy looking . {vocalsound}"},
#   {'speaker': 'Project Manager',
#    'content': '{vocalsound} As he models the {disfmarker}'},
#   {'speaker': 'User Interface', 'content': "It doesn't get much fancier ."},
#   {'speaker': 'Marketing',
#    'content': "Sure . And we could do whatever we like with the L_ L_C_D_ . Yeah let's just assume it's a good L_C_D_ display ."},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing', 'content': 'Maybe I was panicking for no reason .'},
#   {'speaker': 'Industrial Designer', 'content': 'Are we going one on {gap} ?'},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Yeah ,'},
#   {'speaker': 'Industrial Designer',
#    'content': "I'd say we go two , 'cause like f the fanciest would be the double curved ."},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Project Manager', 'content': "I'd {disfmarker}"},
#   {'speaker': 'Industrial Designer', 'content': "Wouldn't it ?"},
#   {'speaker': 'Marketing',
#    'content': "w maybe you'd be a bit too {disfmarker}"},
#   {'speaker': 'Project Manager', 'content': 'Yeah . {vocalsound}'},
#   {'speaker': 'Marketing', 'content': 'yeah . There we go . Yeah ,'},
#   {'speaker': 'Industrial Designer',
#    'content': 'With the articulators . With bells on it .'},
#   {'speaker': 'Marketing',
#    'content': "that's m that's that's better too . More accurate numbers . Technologically innovative . Well , we're getting rid of the locator thing"},
#   {'speaker': 'Project Manager', 'content': 'Which is a shame .'},
#   {'speaker': 'Marketing', 'content': 'which which'},
#   {'speaker': 'User Interface',
#    'content': "Mm . I'd give it a three for this {disfmarker} for that ."},
#   {'speaker': 'Marketing', 'content': 'yeah {vocalsound} {disfmarker}'},
#   {'speaker': 'Industrial Designer', 'content': 'No need for teletext .'},
#   {'speaker': 'Marketing', 'content': '{gap} .'},
#   {'speaker': 'User Interface',
#    'content': "Yeah . I mean the menus thing is something you don't normally see on um on a remote ,"},
#   {'speaker': 'Marketing', 'content': "'Kay ."},
#   {'speaker': 'User Interface',
#    'content': 'but {vocalsound} you see it in a lot of other places .'},
#   {'speaker': 'Marketing', 'content': 'Yeah , mobile phones .'},
#   {'speaker': 'Project Manager', 'content': 'Mm .'},
#   {'speaker': 'Marketing',
#    'content': "And y what you're doing is moving the menu from the television to the remote control , so it's {disfmarker}"},
#   {'speaker': 'User Interface', 'content': 'Mm-hmm .'},
#   {'speaker': 'Marketing',
#    'content': 'You say three ? I might go as far as two on that . Three .'},
#   {'speaker': 'User Interface', 'content': "I'd give it a three ."},
#   {'speaker': 'Project Manager',
#    'content': "I'd be tempted with three , yeah ."},
#   {'speaker': 'Marketing', 'content': 'Three . Okay .'},
#   {'speaker': 'Project Manager',
#    'content': "We'll get panned on the next one , anyway ."},
#   {'speaker': 'Marketing',
#    'content': 'Okay . Materials that people find pleasing .'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager', 'content': 'Yeah , w'},
#   {'speaker': 'Marketing',
#    'content': 'Sponginess is what they really would have wanted , apparently .'},
#   {'speaker': 'Project Manager',
#    'content': "It is , yeah . Don't blame them ."},
#   {'speaker': 'Marketing', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Um because of the way that we've minimalised the number of buttons and such ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "Plastic , it sucks . But it's no worse than any of the other pl remote controls we have ."},
#   {'speaker': 'Marketing',
#    'content': "That's true . It's not a step backwards ."},
#   {'speaker': 'Industrial Designer', 'content': '{gap} five ?'},
#   {'speaker': 'User Interface',
#    'content': "Mm-hmm . I'd s I I'd give it a six , to be honest ."},
#   {'speaker': 'Industrial Designer', 'content': 'Six ?'},
#   {'speaker': 'Project Manager',
#    'content': '{vocalsound} {vocalsound} {vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': "{vocalsound} Yeah , okay let's give it a six ."},
#   {'speaker': 'Industrial Designer', 'content': 'Six , {gap} .'},
#   {'speaker': 'Marketing',
#    'content': "{vocalsound} Okay , that's totally thrown everything off balance . Inspired by the latest interior and clothing fashion . W we could . What colour were we gonna make it ?"},
#   {'speaker': 'Industrial Designer',
#    'content': 'Put a leopard print on it . {vocalsound}'},
#   {'speaker': 'User Interface',
#    'content': 'Well I I I would sa I would say give a s give a selection of colours .'},
#   {'speaker': 'Marketing', 'content': '{vocalsound} I know ,'},
#   {'speaker': 'User Interface',
#    'content': 'Um we went with yellow we went with yellow for the prototype'},
#   {'speaker': 'Marketing', 'content': 'but {disfmarker}'},
#   {'speaker': 'User Interface',
#    'content': "'cause we had yellow . If I were buying one , I'd go for purple . Leopard print would be cool ."},
#   {'speaker': 'Marketing',
#    'content': "But um by this I think it's more a case of fruit and veg , {disfmarker}"},
#   {'speaker': 'Industrial Designer',
#    'content': "Yeah we gotta {gap} . I'd say the colour of the border there world {disfmarker} you'd find that , {gap} that's that'd stand out ."},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': 'Like yellow , yeah . It would also help keep the the product placement s'},
#   {'speaker': 'Industrial Designer', 'content': 'Logo , brand .'},
#   {'speaker': 'Project Manager', 'content': 'yeah .'},
#   {'speaker': 'Marketing', 'content': 'Mm .'},
#   {'speaker': 'Project Manager',
#    'content': 'Is it inspired by {gap} clothing fashion ?'},
#   {'speaker': 'Marketing',
#    'content': "But {disfmarker} Th th they're referring to the fruit and veg thing ."},
#   {'speaker': 'Industrial Designer', 'content': "Mm 'kay ."},
#   {'speaker': 'Project Manager', 'content': '{vocalsound} Yes .'},
#   {'speaker': 'Marketing',
#    'content': "Is this like a banana type colour ? Could we stretch {disfmarker} no still , it's not shaped like a banana is {disfmarker}"},
#   {'speaker': 'User Interface',
#    'content': "That's kinda {disfmarker} {gap} i"},
#   {'speaker': 'Project Manager', 'content': "It's kind o it"},
#   {'speaker': 'User Interface', 'content': "it won't be when it's been"},
#   {'speaker': 'Project Manager',
#    'content': 'probably {disfmarker} {vocalsound}'},
#   {'speaker': 'Marketing', 'content': "Oh is that 'cause it's flat ?"},
#   {'speaker': 'User Interface', 'content': 'budgeted .'},
#   {'speaker': 'Marketing',
#    'content': 'What is {disfmarker} what fruit or veg is flat ?'},
#   {'speaker': 'User Interface',
#    'content': "I I think s I I think this isn't {disfmarker} not particularly fruit and veggie . Um ."},
#   {'speaker': 'Marketing',
#    'content': 'Yeah . Or we might have to suffer badly for this one as well . {vocalsound}'},
#   {'speaker': 'Industrial Designer', 'content': 'Yellow courgette .'},
#   {'speaker': 'User Interface', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound} Well'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "I mean it's probably more fruit and veg than most other things out there bar fruit and veg , so , {vocalsound} what , four ?"},
#   {'speaker': 'Marketing',
#    'content': "Four ? Oh that's it's very ambitious ,"},
#   {'speaker': 'Project Manager', 'content': 'Is that being too generous ?'},
#   {'speaker': 'User Interface',
#    'content': "Mm . I'd {vocalsound} I'd I don't think fruit and veg is the sole criterion . {vocalsound} Is the sole criterion for being um fashion {gap} fashionable or inspired by current fashions ."},
#   {'speaker': 'Marketing', 'content': 'yeah , um .'},
#   {'speaker': 'Project Manager', 'content': 'Oh dear , {gap} .'},
#   {'speaker': 'Marketing', 'content': 'Sure . Inspired by {gap} .'},
#   {'speaker': 'User Interface',
#    'content': "Um I'd g I'd rate I'd rate this fairly highly from that point of view actually ."},
#   {'speaker': 'Industrial Designer',
#    'content': "Well this this what we're gonna t this is their motto , like ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Industrial Designer',
#    'content': "And we're we're not doing well on it ."},
#   {'speaker': 'Marketing',
#    'content': 'This is their strategy . I m imagine we actually had some money invested in this and the amount that we invest is gonna be proportional to the marks . Might {disfmarker} we might wanna be a bit more skepible sceptical about this one .'},
#   {'speaker': 'Project Manager', 'content': 'What would you think yourself ?'},
#   {'speaker': 'Marketing',
#    'content': "I would say {disfmarker} I mean it's it's not at all , right ? {vocalsound} In any way or shape or form ."},
#   {'speaker': 'Project Manager',
#    'content': "{vocalsound} Well , it's kind of curved"},
#   {'speaker': 'Marketing', 'content': "We didn't m"},
#   {'speaker': 'Project Manager',
#    'content': "and we can make it yellow , and that's pretty much banana like ."},
#   {'speaker': 'Marketing',
#    'content': 'Okay , the the yellow banana like thing is I think is okay .'},
#   {'speaker': 'Project Manager', 'content': "Si it's got a curve to it ."},
#   {'speaker': 'Marketing',
#    'content': 'Right five . Is that {vocalsound} sound reasonable ?'},
#   {'speaker': 'Project Manager',
#    'content': "Am I {disfmarker} do you think I'm stretching the uh the use of the banana ?"},
#   {'speaker': 'Industrial Designer', 'content': "Yeah , I'll go with five ."},
#   {'speaker': 'Marketing',
#    'content': "Five . {vocalsound} Yeah . 'Kay , so we have one , two , three , four , five , six , seven . So five , seven , ten , sixteen , twenty one . Which gives us an average of three . It's {disfmarker} well this would be in the middle . So we it's it's not bad . It's in the good section ."},
#   {'speaker': 'Project Manager',
#    'content': "It's not bad and considering the {vocalsound} {disfmarker} don't pick the pen . Um ."},
#   {'speaker': 'Marketing',
#    'content': "{vocalsound} Oops . Sorry . {vocalsound} I'm I'm sorry ."},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Y oh and you've knocked batteries out ."},
#   {'speaker': 'Marketing', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "{vocalsound} Um right okay it's {disfmarker} {vocalsound}"},
#   {'speaker': 'Industrial Designer',
#    'content': "'S bad design , that thing . {vocalsound}"},
#   {'speaker': 'Project Manager',
#    'content': 'considering the price we had to get this in , to have a positive {disfmarker} you know , even based on the four of us being heavily biased , um'},
#   {'speaker': 'Marketing', 'content': 'Mm-hmm . Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "{vocalsound} it was gonna be quite hard to get anything standing out I'd say possibly , based on um the the cost features ."},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Industrial Designer', 'content': 'Mm , yeah .'},
#   {'speaker': 'Marketing',
#    'content': "Even if we were to increase this entire thing by by seven , we were to go down a grade to to four , we would have to do {disfmarker} I mean we didn't we weren't that kinda optimistic too optim overly optimistic . You know like we didn't we didn't add we didn't subtract a whole seven points from these things , so I think we're definitely on the good bit ."},
#   {'speaker': 'User Interface', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': "Even if we gave this one seven and this one seven , that's still only three extra points over seven . You know , it's {disfmarker} yeah ,"},
#   {'speaker': 'User Interface',
#    'content': 'Mm . Personally , I think given that the product um only replaces a single remote control'},
#   {'speaker': 'Marketing',
#    'content': 'we did it w it was okay . It was good .'},
#   {'speaker': 'User Interface',
#    'content': "that you've already got , are people really gonna shell out twenty five Euros for something that's only marginally good ?"},
#   {'speaker': 'Industrial Designer',
#    'content': "Well , it depends who your {disfmarker} who's {disfmarker} what the target people are , like you'd say maybe the fashion conscious"},
#   {'speaker': 'Project Manager',
#    'content': "Maybe it's been targeted {disfmarker}"},
#   {'speaker': 'Industrial Designer',
#    'content': "women would be going , oh look at that , 's cool , it looks like a {disfmarker}"},
#   {'speaker': 'Marketing', 'content': 'Mm-hmm .'},
#   {'speaker': 'Industrial Designer',
#    'content': "it's yellow , looks like a banana , it's cool it's gotta {disfmarker} look good in the sitting room ."},
#   {'speaker': 'Project Manager', 'content': 'Hide it in the fruit basket .'},
#   {'speaker': 'Industrial Designer',
#    'content': "Rather than the L_C_D_ whereas uh more technical like like more uh people in with the latest technology {gap} it's good , it's got an L_C_D_ screen 's only got two buttons and a joystick . So , which which kind of people would be more likely to buy it ?"},
#   {'speaker': 'Project Manager',
#    'content': "Probably the people technologically . They're usually the ones that buy pointless stuff ."},
#   {'speaker': 'User Interface', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing', 'content': 'I think so .'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing',
#    'content': "I mean my mum still has not learnt how to use text messaging on her phone , and she's had it for a long time , you know . She uses it to make phone calls and that's it ."},
#   {'speaker': 'Industrial Designer', 'content': '{gap} .'},
#   {'speaker': 'Marketing',
#    'content': "Yeah . So I think if sh if my mum saw a remote control like this with only two buttons and a joystick , I mean that'll probably be the first one she decides not to buy , you know ."},
#   {'speaker': 'Project Manager', 'content': 'Mm-hmm .'},
#   {'speaker': 'Marketing',
#    'content': "She'd be like is this a remote control , I don't {disfmarker} how do you use it , and stuff like that . So even if it is really user friendly to us , but we're used to using menus all the time ."},
#   {'speaker': 'User Interface',
#    'content': "Mm-hmm . I s {vocalsound} I suppose one thing is that b because it's technically innovative , um for someone who's sort of technophobic , the fact that it simply looks unfamiliar would be daunting ."},
#   {'speaker': 'Marketing', 'content': 'Yeah . Yeah .'},
#   {'speaker': 'User Interface', 'content': 'Um .'},
#   {'speaker': 'Marketing',
#    'content': "I think it's totally uh radical to have a remote control with no no numbered buttons ,"},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah .'},
#   {'speaker': 'Marketing', 'content': 'yeah .'},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah .'},
#   {'speaker': 'Marketing', 'content': 'But like radical good , maybe .'},
#   {'speaker': 'Project Manager',
#    'content': "Okay . Um don't know how lo much longer we've got . At least five minutes I think . Um quickly we'll pop onto project evaluation . Um . So , we've got these uh four criteria here for uh satisfaction . Does anybody want to um um do you have any opinions on any of them ? For example um {disfmarker} we'll work backwards I suppose . The ability to work on this project using the technology we've been presented with . Um {gap} people made good use of the uh pen and paper ?"},
#   {'speaker': 'User Interface', 'content': 'Yeah ,'},
#   {'speaker': 'Project Manager', 'content': 'I would say {gap} {disfmarker}'},
#   {'speaker': 'User Interface', 'content': 'got notes and doodles .'},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Wrote nearly a page ,'},
#   {'speaker': 'Industrial Designer', 'content': 'Yeah .'},
#   {'speaker': 'Marketing', 'content': 'but not {gap} .'},
#   {'speaker': 'Project Manager',
#    'content': "I'm not quite sure what the advantage for us using a digital pen might be ."},
#   {'speaker': 'User Interface',
#    'content': "Well I think this is a {disfmarker} I think the digital pen's mostly for the benefit of the uh"},
#   {'speaker': 'Marketing', 'content': 'I think tracking .'},
#   {'speaker': 'User Interface',
#    'content': "of the researchers studying this . It's all p goes into their corpus ."},
#   {'speaker': 'Project Manager', 'content': 'It must {disfmarker}'},
#   {'speaker': 'User Interface',
#    'content': 'Though it would have been nice to be able to transfer the um transfer our n our paper notes onto the uh computer ourselves .'},
#   {'speaker': 'Marketing', 'content': 'Yeah , that woulda been pretty good .'},
#   {'speaker': 'Project Manager',
#    'content': "It does seem like the paper's still a heavy consideration for taking notes . So maybe this is literally just a way around it . Um I dunno . How are people satisfied with the teamwork we've managed to display today ?"},
#   {'speaker': 'User Interface', 'content': '{gap} .'},
#   {'speaker': 'Marketing', 'content': "I'd {disfmarker}"},
#   {'speaker': 'Industrial Designer', 'content': 'Good .'},
#   {'speaker': 'Marketing', 'content': 'yeah I liked it , yeah .'},
#   {'speaker': 'Project Manager',
#    'content': 'Leadership . As much as can be leadered in this uh thing .'},
#   {'speaker': 'Industrial Designer', 'content': 'Very good .'},
#   {'speaker': 'Marketing', 'content': 'I li yeah , top marks .'},
#   {'speaker': 'Project Manager',
#    'content': "Um last one we've got is room for creativity ."},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Well {vocalsound}'},
#   {'speaker': 'User Interface',
#    'content': '{vocalsound} Unti uh uh until uh until accounts came along ,'},
#   {'speaker': 'Project Manager',
#    'content': 'Now , I think we got {disfmarker}'},
#   {'speaker': 'User Interface', 'content': '{gap} squish .'},
#   {'speaker': 'Industrial Designer',
#    'content': "We're burs bursting with creativity ."},
#   {'speaker': 'Marketing', 'content': 'yeah . {vocalsound}'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound} Yeah'},
#   {'speaker': 'Marketing',
#    'content': "We we're not lacking in ideas , you know it's {disfmarker} that was not the problem ."},
#   {'speaker': 'Project Manager',
#    'content': "I think of {disfmarker} in the end , ideas that can be used {gap} sadly {gap} . Not so much that we weren't full of ideas , but of ones that are gonna allow us to actually build the thing . It's a bit of a pity ."},
#   {'speaker': 'Marketing', 'content': 'Mm-hmm .'},
#   {'speaker': 'Project Manager',
#    'content': 'Um I would have to agree on that . I think we needed a larger budget .'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "If you're going to aim your a um product maybe at the technological kind of sector , then you can afford to maybe jack the price up slightly from what it is ."},
#   {'speaker': 'User Interface', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': 'Because they will pay outrageous cash to {gap}'},
#   {'speaker': 'User Interface',
#    'content': 'Mm . I mean I th {vocalsound} I mean I think to r retaining the s the more sort of bio-morphic form in the articulation would gain more in s uh would gain more profit in sales than it would lose in uh'},
#   {'speaker': 'Project Manager', 'content': 'first on the market .'},
#   {'speaker': 'User Interface', 'content': 'in added expense .'},
#   {'speaker': 'Project Manager', 'content': 'Mm .'},
#   {'speaker': 'Industrial Designer',
#    'content': 'And the price was like {disfmarker} it was twice the w assembly cost . And would it have to be twice that ? It could be like coulda had the assembly {gap} like maybe fifteen Euro .'},
#   {'speaker': 'Project Manager', 'content': 'It could even {disfmarker}'},
#   {'speaker': 'Industrial Designer',
#    'content': "We'll still settle for twenty five {vocalsound} ."},
#   {'speaker': 'Project Manager', 'content': "That's true , yeah ."},
#   {'speaker': 'Industrial Designer', 'content': 'Maybe . {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "Um I suppose these are all that will have to be taken up with a at a different group at I guess . As to a {gap} the costs involved . But I mean we've got a a prototype ."},
#   {'speaker': 'User Interface', 'content': 'Such as it is .'},
#   {'speaker': 'Project Manager',
#    'content': "{vocalsound} So I dunno , I I think it's gone okay today , considering the information that we've had at our disposal , and um such ."},
#   {'speaker': 'Marketing',
#    'content': 'Maybe the counts wou woulda been better if we had a list or more {disfmarker} Yeah , to begin with .'},
#   {'speaker': 'Industrial Designer', 'content': 'In the beginning , yeah .'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': 'Probably would have {disfmarker} mean we could have come up with a lot more solid design in the end ,'},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': 'I would have to agree . It is very much a pity to um get so far into the stage and then find out that maybe some of your ideas are just a bit too expensive . Always hard to tell until you know the costs . Um . Okay . Are the costs within budget ? Well ,'},
#   {'speaker': 'Industrial Designer', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': 'they are now that we have our slightly less than capable product .'},
#   {'speaker': 'Marketing', 'content': 'Okay .'},
#   {'speaker': 'Project Manager',
#    'content': "We've evaluated it , and we can say that we came out with a value of three ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'User Interface',
#    'content': 'Actually I want th one thing I would say {disfmarker}'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface',
#    'content': 'I mean something that could perhaps be part of the product mm the um m product testing market research process would be to uh produce mock-ups of both versions and see just how much of a difference the over {gap} going over-budget um m would make to sales .'},
#   {'speaker': 'Project Manager', 'content': "It's {disfmarker} yeah ?"},
#   {'speaker': 'Marketing',
#    'content': 'And like response from consumers {gap} .'},
#   {'speaker': 'User Interface',
#    'content': 'And we could even you know , market two versions .'},
#   {'speaker': 'Project Manager', 'content': '{vocalsound}'},
#   {'speaker': 'Marketing', 'content': '{vocalsound}'},
#   {'speaker': 'User Interface',
#    'content': 'Wee cheapie version with the nice bio-morphic rubber . {vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': 'And then the final one where you get to call it Hal .'},
#   {'speaker': 'User Interface', 'content': 'Yes .'},
#   {'speaker': 'Project Manager', 'content': "But we'll go into that later ."},
#   {'speaker': 'Marketing', 'content': '{vocalsound} Sure .'},
#   {'speaker': 'Project Manager', 'content': 'Right um'},
#   {'speaker': 'Marketing', 'content': '{vocalsound}'},
#   {'speaker': 'Project Manager',
#    'content': "is there anything else that anybody would like to to add , um {gap} anything they think that's not been covered , before I quickly write up a final report . Um I dunno , I mean we've got a product . We maybe aren't as happy with it as we'd like to be , but we've got something we think we can maybe stick onto the the market and sell . And of course something we have been avoiding talking about 'cause of we've no information is selling them directly to the manufacturers . There is a huge market ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'Project Manager',
#    'content': "I mean we've briefly touched on it but we've no more knowledge then there's little we can say on that ."},
#   {'speaker': 'Marketing', 'content': 'Yeah .'},
#   {'speaker': 'User Interface', 'content': 'Mm .'},
#   {'speaker': 'Project Manager',
#    'content': "Yeah . So um unless anybody's got anything they'd like to add , we can maybe round this up slightly earlier than we'd need to and then we can finish up the writing and such ."},
#   {'speaker': 'User Interface', 'content': 'And I can get my bus . Okay .'},
#   {'speaker': 'Project Manager', 'content': 'Yeah ?'},
#   {'speaker': 'Marketing', 'content': "Yeah . Okay , let's {disfmarker}"},
#   {'speaker': 'Project Manager',
#    'content': 'Uh thank you for your participation .'},
#   {'speaker': 'Marketing', 'content': 'Thank you .'},
#   {'speaker': 'User Interface', 'content': 'Thank you .'},
#   {'speaker': 'Marketing',
#    'content': "{vocalsound} I was actually kind of upset you know at the budget , and that we had to cut a lot of stuff . It's like man , we we can't have the locator thing . And s yeah that's just bad . Do you think maybe {gap} the prices were were made ?"},
#   {'speaker': 'Project Manager',
#    'content': 'That {gap} a question we can ask {gap} . {vocalsound}'}])

# %%
import pprint

# shape: [["sentence 1", "sentence 2"], ["sentence3", "sentence4"]]
text_segments = []
for topic in topic_list:
    prev_end_span = -1
    for text_span in topic["relevant_text_span"]:
        start_of_span = int(text_span[0])
        end_of_span = int(text_span[-1])

        # MISSING TOPIC CASE
        # this means that there are some sentences without a topic
        # for example, [0, 19] and [24, 29], where 20 - 23 are missing
        if start_of_span != (prev_end_span + 1):
            missing_topic_meeting = meeting_transcripts[
                prev_end_span + 1 : start_of_span - 1
            ]
            missing_topic_full_segment = []
            if len(missing_topic_meeting) != 0:
                for segment in missing_topic_meeting:
                    # clean the text before insertion
                    cleaned_content = clean_data(segment["content"])
                    # get the content for the segment and throw it into the list of segments
                    missing_topic_full_segment.append(cleaned_content)
                text_segments.append(missing_topic_full_segment)

        # TOPIC CASE
        topic_meeting = meeting_transcripts[start_of_span:end_of_span]
        if "meeting" not in topic:
            topic["meeting"] = []
        topic["meeting"].append(topic_meeting)

        full_segment = []
        for segment in topic_meeting:
            # clean the text before insertion
            cleaned_content = clean_data(segment["content"])
            # get the content for the segment and throw it into the list of segments
            full_segment.append(cleaned_content)

        text_segments.append(full_segment)

        # make sure we have the previous end span for sentences that don't have topics
        prev_end_span = end_of_span

pprint.pprint(text_segments)
# Out:
# [["That should hopefully do the trick , um . 'Kay . Sorry about the small "
#   "delay . Falling a little bit behind schedule . And that's uh fifteen twenty "
#   'five . Okay . So just to try and roughly go over what we agreed in the last '
#   "one , um we're gonna go for something uh uh how was it ? Uh The new black , "
#   'I believe .',
#   ' .',
#   "Um something that looks good 'cause that seems to be in preference to "
#   'actual functionality in the end , though we should never avoid '
#   'functionality , of course . Uh many of our components are gonna be standard '
#   ', off the shelf , but it seemed like we were gonna require at least an '
#   'advanced chip and we were still very much for the idea of using an L_C_D_ '
#   'display . Um other things were we were hoping to use rubber , most likely '
#   'gonna be double curved , etcetera . Okay . So um due to your hard work , we '
#   'might as well let the uh two designers go first , and uh show us the '
#   'prototype .',
#   "Okay , it's a ",
#   "Quite how the best way to do this is , I'm not sure ,",
#   '',
#   ' I think if we both step up',
#   'but ',
#   'and uh outline our ideas . Okay . Now do  uh doing the prototype gave us a '
#   'bit more insight into the ergonomics of the design . Um for one thing , it '
#   'turned out that the only point at which it needs to be articulated for '
#   'handedness is um is h i is down here for the uh L_E_D_ . As it turned out , '
#   'the whole thing transfers from the right to left hand fairly well from the '
#   'point of view of operating the uh function buttons and joystick , though it '
#   'might be an idea to be able to a adjust the positions for the base of the '
#   'joystick just a little bit for uh ',
#   'Okay .',
#   ' ju just a thought . You could simply have a slightly ovoid shaped joystick '
#   'that could then just be turn uh twisted round , so that the uh sticky uh so '
#   'that the bit that sticks out a bit more is on one side or the other . But '
#   'as you as you see with the uh  with holding it in the left hand , the L_ uh '
#   'the L_C_D_ is nowhere useful , so that would need to be articulated uh if '
#   "we're going to retain  ergonomic design . Um now I I got your note about uh "
#   'keeping the cost down .',
#   "I'm afraid yeah .",
#   'Yeah .',
#   "We'll go into that a bit more ,",
#   ' this design could be done with um with uh plastic casing .',
#   'but please go on .',
#   'Though I would recommend around the grip part here in the middle , having '
#   'maybe just a rubber grip over that which would allow for a slightly more '
#   'sort of bio-morphic form , and a bit more ergonomic as well . As for the um '
#   'as for the single curve , um well this edge and this edge , like I say it '
#   "would be nice to have some curvature to it , but it's not absolutely "
#   "necessary . Really the curve that's most needed is the underside so that "
#   'the jo so that the joystick rests over the the edge of the hand like this . '
#   'Um and you have the uh transmitter here and a wee speaker for the uh for '
#   'the uh for the uh fi uh for the remote control finder . So .',
#   '',
#   'Any further comments ?',
#   "Um obviously it's gonna be bulkier than how it looks , because it's gonna "
#   'be flat on one side , so the L_C_D_ will be s sticking down like this , '
#   "won't it ?",
#   'Mm-hmm . Yeah .',
#   "'Cause it  you can't get it curved .",
#   'Yeah , I mean the',
#   'Uh because of costs .',
#   'uh  Yeah .',
#   "And it's plastic as well , so it won't be as comfortable on the hand .",
#   'Yeah . I mean with the with the rubber design it could i you know it could '
#   "pretty much mould very much to the to the user's hand .",
#   'Mm .',
#   'One nice wee feature if we could if we could still do the rubber , I though '
#   'of was to have  the uh rubber extend beyond the end of the uh  of the rigid '
#   'substructure . So it has a wee sort of tail that you just drape over your '
#   'wrist so it stays in position nicely .',
#   '',
#   'Mm . Lovely . Um .',
#   'Yeah ,  . ',
#   'Okay , yeah . Great . Um .',
#   "Right . Yeah I've got a  if you load up my evaluation document .",
#   'Yeah , okay  .',
#   'Okay .',
#   'Excellent work .',
#   'Mm .'],
#  ["That should hopefully do the trick , um . 'Kay . Sorry about the small "
#   "delay . Falling a little bit behind schedule . And that's uh fifteen twenty "
#   'five . Okay . So just to try and roughly go over what we agreed in the last '
#   "one , um we're gonna go for something uh uh how was it ? Uh The new black , "
#   'I believe .',
#   ' .',
#   "Um something that looks good 'cause that seems to be in preference to "
#   'actual functionality in the end , though we should never avoid '
#   'functionality , of course . Uh many of our components are gonna be standard '
#   ', off the shelf , but it seemed like we were gonna require at least an '
#   'advanced chip and we were still very much for the idea of using an L_C_D_ '
#   'display . Um other things were we were hoping to use rubber , most likely '
#   'gonna be double curved , etcetera . Okay . So um due to your hard work , we '
#   'might as well let the uh two designers go first , and uh show us the '
#   'prototype .',
#   "Okay , it's a ",
#   "Quite how the best way to do this is , I'm not sure ,",
#   '',
#   ' I think if we both step up',
#   'but ',
#   'and uh outline our ideas . Okay . Now do  uh doing the prototype gave us a '
#   'bit more insight into the ergonomics of the design . Um for one thing , it '
#   'turned out that the only point at which it needs to be articulated for '
#   'handedness is um is h i is down here for the uh L_E_D_ . As it turned out , '
#   'the whole thing transfers from the right to left hand fairly well from the '
#   'point of view of operating the uh function buttons and joystick , though it '
#   'might be an idea to be able to a adjust the positions for the base of the '
#   'joystick just a little bit for uh ',
#   'Okay .',
#   ' ju just a thought . You could simply have a slightly ovoid shaped joystick '
#   'that could then just be turn uh twisted round , so that the uh sticky uh so '
#   'that the bit that sticks out a bit more is on one side or the other . But '
#   'as you as you see with the uh  with holding it in the left hand , the L_ uh '
#   'the L_C_D_ is nowhere useful , so that would need to be articulated uh if '
#   "we're going to retain  ergonomic design . Um now I I got your note about uh "
#   'keeping the cost down .',
#   "I'm afraid yeah .",
#   'Yeah .',
#   "We'll go into that a bit more ,",
#   ' this design could be done with um with uh plastic casing .',
#   'but please go on .',
#   'Though I would recommend around the grip part here in the middle , having '
#   'maybe just a rubber grip over that which would allow for a slightly more '
#   'sort of bio-morphic form , and a bit more ergonomic as well . As for the um '
#   'as for the single curve , um well this edge and this edge , like I say it '
#   "would be nice to have some curvature to it , but it's not absolutely "
#   "necessary . Really the curve that's most needed is the underside so that "
#   'the jo so that the joystick rests over the the edge of the hand like this . '
#   'Um and you have the uh transmitter here and a wee speaker for the uh for '
#   'the uh for the uh fi uh for the remote control finder . So .',
#   '',
#   'Any further comments ?',
#   "Um obviously it's gonna be bulkier than how it looks , because it's gonna "
#   'be flat on one side , so the L_C_D_ will be s sticking down like this , '
#   "won't it ?",
#   'Mm-hmm . Yeah .',
#   "'Cause it  you can't get it curved .",
#   'Yeah , I mean the',
#   'Uh because of costs .',
#   'uh  Yeah .',
#   "And it's plastic as well , so it won't be as comfortable on the hand .",
#   'Yeah . I mean with the with the rubber design it could i you know it could '
#   "pretty much mould very much to the to the user's hand .",
#   'Mm .',
#   'One nice wee feature if we could if we could still do the rubber , I though '
#   'of was to have  the uh rubber extend beyond the end of the uh  of the rigid '
#   'substructure . So it has a wee sort of tail that you just drape over your '
#   'wrist so it stays in position nicely .',
#   '',
#   'Mm . Lovely . Um .',
#   'Yeah ,  . ',
#   'Okay , yeah . Great . Um .',
#   "Right . Yeah I've got a  if you load up my evaluation document .",
#   'Yeah , okay  .',
#   'Okay .',
#   'Excellent work .',
#   'Mm .'],
#  ['Uh evaluation .  Basic point uh have a list of criteria that we need to '
#   "rate the prototype by .  Um then we will  it's a seven s um seven seven "
#   'step kinda evaluation process . So um not seven steps , seven scale . So '
#   "after we've finished doing all the ratings for each criteria , we average "
#   'that and that will give us some type of uh confidence in our prototype . '
#   "And uh the criteria  based on Real Reactions' kinda goals and policies , "
#   'marketing strategies , and also those I put together from the user '
#   "requirements phase . 'Kay . Um if you flip the   So , those are the "
#   "criteria . And uh perhaps I could have put 'em a bit better , but you "
#   "notice a few things that we've totally abandoned , which means  that uh the "
#   'product will score very badly on some of those points .',
#   '',
#   ' Put it mildly . So we have um true ? One , t Seven , eight , oh . Fourth . '
#   "Okay , so we have to go through each point . If we imagine it's actually "
#   'straight , and just give it a a score . So um how well would you say the '
#   'prototype is uh how well have we realised the dream of being able to stop '
#   'remotes from from being lost , or to be able to find them once they are '
#   'lost . I mean , uh is the homing thing still  the locator , is that still ',
#   "Yeah , that's still part of the design .",
#   'Sure . And Adam , we can keep that in ?',
#   "Yeah , I believe so . So I mean I don't think anybody could actually stop a "
#   'remote being lost ,',
#   'Okay .',
#   "'cause that would mean doing something about the human element ,",
#   ' Sure .',
#   "but I'd like to think that we've done something about finding the damn "
#   'thing once we have .',
#   'T',
#   'Mm . Mm . And making it a bright colour helps',
#   'Sure .',
#   'with the  personally I would have gone for purple  . ',
#   '',
#   'Mm . Bright colour . So we still have that noise thing , yeah ?',
#   'Mm-hmm .',
#   'Os on a scale of one to seven , how would you guys rate it for finding  '
#   "finding it once it's lost ?",
#   "I'd say number one .",
#   'Number one ?',
#   'One . Yeah . ',
#   'Okay . Number number one for the first criteria .',
#   "I think w if it was just the sounder then th  I mean something I've found "
#   'with uh w w with say tr trying to find uh a cordless phone or a m mobile , '
#   "you can hear it , but you can't quite pin it dow pin down where it is .",
#   'Yeah you can tell what room the mobile is ',
#   'Bu',
#   "What about  what if the the volume on the T_V_'s turned up massively and uh "
#   "you just wanna turn down the volume  can't find remote . Suppose you have "
#   'to go to the T_V_ and do it manually . Mm .',
#   'Yeah .',
#   'Yeah .',
#   'Mm . Um',
#   'Yeah .',
#   "Like y you wouldn't hear the speaker  .",
#   'Mm-hmm .',
#   "just before we go through all of the steps here , um well what we'll do is",
#   'You wanna say something ?',
#   "um if we can look at the criteria you're gonna evaluate , and then we'll "
#   "come back to the product evaluation if that's alright .",
#   "That's fine .",
#   'Yeah , is that ',
#   "Oh that's that's fine .",
#   'Um so is there anything here that you that you wanted to cover as in the '
#   "criteria that you've covered ? And then we'll come back pretty much "
#   'promptly to this .',
#   'What do you mean cr is there anything I wanna ',
#   'I is there any of these criteria that need any explaining ? Or is there '
#   'anything that yous thought tha really would stand out compared to the '
#   'others ?',
#   'Um , a few .  Something I neglected from my initial research is that Real '
#   'Reactions has a a goal strategy that all of the products be inspired by '
#   'material fashion , and clothing fashion . That is why fruit and veg being '
#   'popular in the home and in clothing was important and they want all their '
#   'products to be somehow inspired by current trends in fashion . So they say '
#   "we put the fashion in electronics , well they really mean it they they're "
#   'very big on fashion ,',
#   'Okay .',
#   "so . That's this bit right here . And uh this bit is this one easy to use "
#   "for visitors or for anybody ? I guess it's just the same as saying easy to "
#   "use interface , so it's kinda condensed into one . And we can come back to "
#   'it , you said .',
#   'Okay .',
#   'So .',
#   'No and which we will do very very shortly . Um . Okay . Slight problem we '
#   'had was that we have an amazing four Euros over budget for what we were '
#   'hoping to do . Um most of it stems from the use of the L_C_D_ which I think '
#   'in the end accounted for about half of our expenditure because of course we '
#   'required a chip as well . Um the only way to get this down was either to '
#   "ditch the a L_C_D_ , at which point we've removed a large part of how we "
#   'were gonna interface ,  require more buttons , etcetera . Or what we did '
#   'was that we um we as in I as I was quickly going over it was altering the '
#   'actual structure . Um changing it to plastic and a solid unit with a single '
#   'curve design would allow us to come back into the um proposed costs and '
#   "we're just scraping it in , we've got point two of a Euro left over there . "
#   "So we're just managing it really . Even then as well , um there was no "
#   "criteria technically defined for a joystick so I've used what I think's "
#   "appropriate . With any luck that won't mean that we've incurred more cost "
#   'than we can actually afford to . It blows a lot of our really good ideas '
#   'kind of slightly to one side , for example the possibility of having a '
#   'U_S_B_ connection is definitely not viable now . Um .',
#   'Different languages ?',
#   "That should still be viable . We've got an advanced chip , we've got the "
#   'use of the L_C_D_ . So being able to communicate in multiple languages is '
#   'still very much a possibility .',
#   'Yeah . ',
#   "Um but what's something we need to decide on is how we're gonna go from "
#   'here .  We do need to try and come up with an idea which could be continued '
#   'with other people if need be . Um . We can I can bring the excel up sheet '
#   'up and uh show you if you wish um . I really think as m much as it pains me '
#   'is that we might have to go with plastic and some kind of solid design , '
#   "possibly meaning that the L_C_D_ wouldn't be in this perfect place . It "
#   'might be s stuck like slightly between what would be good for left handed '
#   'and what would be good for a right handed person .',
#   'Mm-hmm I suppose o one thing that could be done is h  is have it um '
#   'circular and have it s  so that the uh the pink  actually goes a bit over '
#   'the pinkie finger . Mm .',
#   'Okay .',
#   'Mm .',
#   'So that uh th',
#   'It very much is about making concessions , unfortunately . Um .',
#   'Mm .',
#   'Do you have any data on how much um different prints cost ? I mean can you '
#   'get the entire thing printed with a design um ?',
#   'Um b b b da is  you mean on the plastic , or ?',
#   ' .',
#   "Let's have a look . You now have as much information as I do .  Um .",
#   'Yeah , yeah .',
#   'So as you can see here , for example , the battery really not very little '
#   "choice in that one . We've gone for one of the cheaper options as well . "
#   "Unfortunately we require the advanced chip if we're gonna do what we're "
#   "needing to . I've said single curved . We really do need it to be that way "
#   'for the ergonomics of it . Um plastic for some reason incurs no cost , '
#   "which I've had to very much make advantage of , despite the fact that "
#   "rubber's only got a value of two Euros per unit . Problem comes here as you "
#   "can see in the interface . Um if I've read this thing correctly , then we "
#   "can save point five of a Euro here in that it's not per push button . That "
#   'might make sense , because then a numeric keypad would come in at um what , '
#   'four point five Euros , which is an awful lot , so that could well be wrong '
#   ". Even if we save point five there , it would just mean that we're most "
#   'likely placing it in actually just gaining a colour for the unit , which '
#   'has had to be put to one side . As you can see , the use of an L_C_ display '
#   'um advanced chip and what would determine the scroll wheel here as well '
#   "because it's an integrated scroll scroll wheel push button that wasn't "
#   'quite what I think they had in mind with a joystick .',
#   'Why would why would that be more expensive than an individual push button '
#   "and scroll wheel together ? That's quite significantly expensive .",
#   "I  that's something you'll have to take up with the bean counters . Um",
#   ' .',
#   '',
#   'Mm .  yeah .',
#   "as you can see I mean that's taken up well over half of the price .",
#   'Yeah .',
#   "So um I'm very much open to suggestions of where we go , but because we "
#   'need to shed what was four Euros off of the um the price of for what we '
#   'really desired , this one comes in under price as you can see , but this '
#   'was the one that sacrificed the material for the case and for the actual '
#   'case design .',
#   "We don't even have uh speakers here . The  like uh we uh  what about "
#   'speakers and transmitters and stuff like that ? Have we factored that in ?',
#   'Mm .',
#   "Uh no , we haven't , not ",
#   "Transmitter , receiver , speakers . Plus the extra device itself that's "
#   'gonna be on a T_V_ .',
#   '',
#   'Is that gonna be a button , or ',
#   "That'll  it literally would just be a button .",
#   'Yeah .',
#   'We might have to ',
#   "That's too expensive  isn't it ?",
#   'It looks like almost nothing  Mm . Oh good call , I missed that .',
#   "I I mean it's not on here , but um .",
#   " that's a very valid point .",
#   'Did they s do we have to use an advanced chip for the L_C_D_ ?',
#   'Yeah .',
#   "Okay . Well that's  yeah .",
#   "So if we're gonna go with the L_C_ display , then that's ",
#   "What's a hand dyna dynamo ? You have to wind it up ?",
#   'I believe so , yeah .',
#   '',
#   '',
#   'That would probably not be in keeping with the um the fashion statement and '
#   'such ,',
#   ' Technology . Yeah .',
#   'Fashion .',
#   'yeah .',
#   'Okay .',
#   'So basically the only new thing is the L_C_D_ on the remote now .',
#   'Being manipulated by the joystick , yeah .',
#   'Oh , and joystick , yeah .',
#   "Which I'm defining as scroll wheel . Um .",
#   "And we couldn't replace the joystick , right ? Because we would need four "
#   'extra buttons to replace it , up down left and right , and that would be '
#   'more expensive than a  but is a scroll wheel not just back and forward ?',
#   'Mm .',
#   "Yeah it's just because there was no actual definition for what a joystick "
#   "might be , that that's what I've labelled it for the purposes of this "
#   'evaluation .',
#   'So  The L_C_D_ basically is the big selling point of',
#   'If we remove the L_C_ display , we could save ourselves',
#   'the remote .',
#   'a fair amount . Which you could  ',
#   "But that's what makes it uh original though ,",
#   'Mm . I think  if we remove the the L_C_ display then there was absolutely '
#   'no point to any of these meetings',
#   'Yeah . ',
#   "isn't it ?",
#   'and we just  we could just put our branding on any other remote control .',
#   'Yeah . Yeah . Um . Uh k',
#   "It's a shame . We should possibly have  If we could've increased the price "
#   "we could've manufactured that and we could've got something far closer to "
#   'what we were hoping to .',
#   "Does this does this bear in mind that  I mean it's a bit ridiculous that "
#   "they're gonna charge us what is it , like this much money for three million "
#   "if we're gonna buy three million components ,",
#   "Again , you'll have to argue with the accountants on that one .",
#   'you know .',
#   "Um but for the purposes of this meeting , I'm  we're gonna have to stick "
#   'with these figures .',
#   "Mm . 'Kay .",
#   "So , I would say that it would seem like the general opinion is we're gonna "
#   "keep the L_C_ display 'cause it's about what really separates us ,  despite "
#   "the cost it's gonna incur . Um",
#   'I think so .',
#   'are people maybe not happy with , but are willing to go ahead with this in '
#   'going for a plastic solid case , to keep the L_C_D_ ?',
#   'Mm-hmm . Um yeah  I mean one thing , I mean ho uh how much extra would it '
#   'be to to keep I mean  keep the um the articulation ?',
#   "It's hard to tell . Um I would say that you're at least gonna take double "
#   'curved ,',
#   "This is what I'm wondering .",
#   "and even then I'm not quite sure if that's incorporating the idea of "
#   'articulation .',
#   'Oh',
#   'Yeah .',
#   "no , I think I I it d that it needn't require it to be double curved .",
#   'It can be s yeah , it can still be single curved ,',
#   "It's uh it's just  it's just  it's just that the case would come in t  "
#   'would be made in two parts and then joined together with an articulation .',
#   'but ',
#   'Single curved with articulation ?',
#   'You just  .',
#   'Could we could we not get rid of the curvy the curvous the curvaceousness '
#   "and focus on the menu being the best interface ? 'Cause like we  do we have "
#   're restrictions on software ?',
#   "That's what we need for the joystick I think though .",
#   'Mm . Yeah , I mean',
#   'Oh but there has to be ',
#   'and  I mean the uh I mean if you look uh if you look closer at the uh at '
#   'the prototype here , the lines here along the grip are actually quite '
#   'straight . Um I mean  yeah ,',
#   ' But the curves all o over  hand ,',
#   "on the  on the L_C_D_ I mean although we've done it with a curve it",
#   'is it ?',
#   "could just as easily be done um without curves . The curve that's really "
#   'needed is up here ,',
#   ' joystick .',
#   'to put uh to keep the joystick in a good ergonomic position for it to have '
#   'it rest on the top of the hand .',
#   'Okay . Sure . Okay , my bad .',
#   "We wouldn't actually save a lot by reducing it anyway , so I mean for the "
#   'purposes of this meeting maybe we can state that single curve still allows '
#   'articulation .',
#   'Mm .',
#   'Um unless we hear otherwise we could go ahead with that proposal .',
#   'So I think the product is not gonna perform so well for my criteria .',
#   'Which is what we can get onto now . As long as  so are we gonna say   w we '
#   "have to keep an eye on the time as well , but we're gonna say um single "
#   'curved design  ',
#   'Oh , wait a minute . Sample speaker ? What is a sample speaker ? Is that '
#   'somewhat similar to what we want ?',
#   'It could well be ,',
#   'Mm no',
#   'but at a cost of ',
#   "that's that voice response thing that we got the email about .",
#   'Costs four .',
#   'Yeah .',
#   'But I thought it was just completely pointless .',
#   'You got a email about voice response ?',
#   'Yeah .',
#   'I did not ,',
#   'Alright .',
#   'so .',
#   'B i basically it was  saying that our labs had come up with a chip that you '
#   'could , you know , say hello to , and it would say hello back in a friendly '
#   'female voice  . ',
#   "Okay , yeah we'll definitely won't go with that one .",
#   "We won't go with that one , did you say ?",
#   "Yeah , that's voice recognition , so .",
#   'I mean I  we  Okay , okay .',
#   'Um . So , okay yeah , battery definitely , ',
#   "So it looks like we're gonna get rid of the whole loca  locator thing .",
#   'It looks like it unless we can manage to put it in under point two Euros , '
#   'um .',
#   'Yeah .',
#   ' Okay .  Okay .',
#   'Mm-hmm .',
#   "Maybe even slight well oh yeah , pretty much point two Euros , I'd say . So "
#   "we'll leave that one for now .  we'll just have ",
#   'Are we going for a special colour at all ?',
#   "It's uh a case of um I'm uh slightly unsure . One  point five of a Euro for "
#   "one push button doesn't sound quite right . So maybe it's a case of a push "
#   'button is maybe one or more . Um .',
#   'Mm .',
#   'Well',
#   'At which point if ',
#   'I was  for a case . Or had you already incorporated that ?',
#   'Oh , special colour for the case .',
#   "Well you got point five there . It's literally a case of whether or not "
#   "this is correct . I'm not quite sure if they're  I don't think they mean "
#   'point five Euros per button .',
#   'Okay , well',
#   'Mm-hmm .',
#   "l let's say that and then we can have our special coloured case",
#   'So',
#   'and then we at least have  make it a little harder to lose .',
#   'There we go .',
#   'Because most m most remotes are a fairly dingy colour that gets camouflaged '
#   'under any pile of crap in a living room .',
#   "W what's the default colour ? White or black ?",
#   "Black's probably the normal colour you'd say ,",
#   'Or grey .',
#   'yeah .',
#   'Right .',
#   "I quite like that colour that you're fetching there ,",
#   'Yellow . ',
#   "it's uh definitely for make it glow in the dark even better .",
#   'Yeah .',
#   ' So will we go with that then ?',
#   'Okay .',
#   "It's not and we can see ",
#   'Yeah .',
#   "we'll come back to uh your evaluation",
#   ' Sure .',
#   "which you're probably now going to pan us but there we go .",
#   'Okay . Okay .',
#   '',
#   'So uh ',
#   'Just to give you an idea , um you want to go maybe a bit quickly as well , '
#   "I'm not sure how much time . We've not hit the five minute mark warning yet "
#   ',',
#   'Right okay . Okay .',
#   'but .',
#   "Think it's ten minutes left . "],
#  ["That should hopefully do the trick , um . 'Kay . Sorry about the small "
#   "delay . Falling a little bit behind schedule . And that's uh fifteen twenty "
#   'five . Okay . So just to try and roughly go over what we agreed in the last '
#   "one , um we're gonna go for something uh uh how was it ? Uh The new black , "
#   'I believe .',
#   ' .',
#   "Um something that looks good 'cause that seems to be in preference to "
#   'actual functionality in the end , though we should never avoid '
#   'functionality , of course . Uh many of our components are gonna be standard '
#   ', off the shelf , but it seemed like we were gonna require at least an '
#   'advanced chip and we were still very much for the idea of using an L_C_D_ '
#   'display . Um other things were we were hoping to use rubber , most likely '
#   'gonna be double curved , etcetera . Okay . So um due to your hard work , we '
#   'might as well let the uh two designers go first , and uh show us the '
#   'prototype .',
#   "Okay , it's a ",
#   "Quite how the best way to do this is , I'm not sure ,",
#   '',
#   ' I think if we both step up',
#   'but ',
#   'and uh outline our ideas . Okay . Now do  uh doing the prototype gave us a '
#   'bit more insight into the ergonomics of the design . Um for one thing , it '
#   'turned out that the only point at which it needs to be articulated for '
#   'handedness is um is h i is down here for the uh L_E_D_ . As it turned out , '
#   'the whole thing transfers from the right to left hand fairly well from the '
#   'point of view of operating the uh function buttons and joystick , though it '
#   'might be an idea to be able to a adjust the positions for the base of the '
#   'joystick just a little bit for uh ',
#   'Okay .',
#   ' ju just a thought . You could simply have a slightly ovoid shaped joystick '
#   'that could then just be turn uh twisted round , so that the uh sticky uh so '
#   'that the bit that sticks out a bit more is on one side or the other . But '
#   'as you as you see with the uh  with holding it in the left hand , the L_ uh '
#   'the L_C_D_ is nowhere useful , so that would need to be articulated uh if '
#   "we're going to retain  ergonomic design . Um now I I got your note about uh "
#   'keeping the cost down .',
#   "I'm afraid yeah .",
#   'Yeah .',
#   "We'll go into that a bit more ,",
#   ' this design could be done with um with uh plastic casing .',
#   'but please go on .',
#   'Though I would recommend around the grip part here in the middle , having '
#   'maybe just a rubber grip over that which would allow for a slightly more '
#   'sort of bio-morphic form , and a bit more ergonomic as well . As for the um '
#   'as for the single curve , um well this edge and this edge , like I say it '
#   "would be nice to have some curvature to it , but it's not absolutely "
#   "necessary . Really the curve that's most needed is the underside so that "
#   'the jo so that the joystick rests over the the edge of the hand like this . '
#   'Um and you have the uh transmitter here and a wee speaker for the uh for '
#   'the uh for the uh fi uh for the remote control finder . So .',
#   '',
#   'Any further comments ?',
#   "Um obviously it's gonna be bulkier than how it looks , because it's gonna "
#   'be flat on one side , so the L_C_D_ will be s sticking down like this , '
#   "won't it ?",
#   'Mm-hmm . Yeah .',
#   "'Cause it  you can't get it curved .",
#   'Yeah , I mean the',
#   'Uh because of costs .',
#   'uh  Yeah .',
#   "And it's plastic as well , so it won't be as comfortable on the hand .",
#   'Yeah . I mean with the with the rubber design it could i you know it could '
#   "pretty much mould very much to the to the user's hand .",
#   'Mm .',
#   'One nice wee feature if we could if we could still do the rubber , I though '
#   'of was to have  the uh rubber extend beyond the end of the uh  of the rigid '
#   'substructure . So it has a wee sort of tail that you just drape over your '
#   'wrist so it stays in position nicely .',
#   '',
#   'Mm . Lovely . Um .',
#   'Yeah ,  . ',
#   'Okay , yeah . Great . Um .',
#   "Right . Yeah I've got a  if you load up my evaluation document .",
#   'Yeah , okay  .',
#   'Okay .',
#   'Excellent work .',
#   'Mm .',
#   'Um .',
#   'Uh evaluation .  Basic point uh have a list of criteria that we need to '
#   "rate the prototype by .  Um then we will  it's a seven s um seven seven "
#   'step kinda evaluation process . So um not seven steps , seven scale . So '
#   "after we've finished doing all the ratings for each criteria , we average "
#   'that and that will give us some type of uh confidence in our prototype . '
#   "And uh the criteria  based on Real Reactions' kinda goals and policies , "
#   'marketing strategies , and also those I put together from the user '
#   "requirements phase . 'Kay . Um if you flip the   So , those are the "
#   "criteria . And uh perhaps I could have put 'em a bit better , but you "
#   "notice a few things that we've totally abandoned , which means  that uh the "
#   'product will score very badly on some of those points .',
#   '',
#   ' Put it mildly . So we have um true ? One , t Seven , eight , oh . Fourth . '
#   "Okay , so we have to go through each point . If we imagine it's actually "
#   'straight , and just give it a a score . So um how well would you say the '
#   'prototype is uh how well have we realised the dream of being able to stop '
#   'remotes from from being lost , or to be able to find them once they are '
#   'lost . I mean , uh is the homing thing still  the locator , is that still ',
#   "Yeah , that's still part of the design .",
#   'Sure . And Adam , we can keep that in ?',
#   "Yeah , I believe so . So I mean I don't think anybody could actually stop a "
#   'remote being lost ,',
#   'Okay .',
#   "'cause that would mean doing something about the human element ,",
#   ' Sure .',
#   "but I'd like to think that we've done something about finding the damn "
#   'thing once we have .',
#   'T',
#   'Mm . Mm . And making it a bright colour helps',
#   'Sure .',
#   'with the  personally I would have gone for purple  . ',
#   '',
#   'Mm . Bright colour . So we still have that noise thing , yeah ?',
#   'Mm-hmm .',
#   'Os on a scale of one to seven , how would you guys rate it for finding  '
#   "finding it once it's lost ?",
#   "I'd say number one .",
#   'Number one ?',
#   'One . Yeah . ',
#   'Okay . Number number one for the first criteria .',
#   "I think w if it was just the sounder then th  I mean something I've found "
#   'with uh w w with say tr trying to find uh a cordless phone or a m mobile , '
#   "you can hear it , but you can't quite pin it dow pin down where it is .",
#   'Yeah you can tell what room the mobile is ',
#   'Bu',
#   "What about  what if the the volume on the T_V_'s turned up massively and uh "
#   "you just wanna turn down the volume  can't find remote . Suppose you have "
#   'to go to the T_V_ and do it manually . Mm .',
#   'Yeah .',
#   'Yeah .',
#   'Mm . Um',
#   'Yeah .',
#   "Like y you wouldn't hear the speaker  .",
#   'Mm-hmm .',
#   "just before we go through all of the steps here , um well what we'll do is",
#   'You wanna say something ?',
#   "um if we can look at the criteria you're gonna evaluate , and then we'll "
#   "come back to the product evaluation if that's alright .",
#   "That's fine .",
#   'Yeah , is that ',
#   "Oh that's that's fine .",
#   'Um so is there anything here that you that you wanted to cover as in the '
#   "criteria that you've covered ? And then we'll come back pretty much "
#   'promptly to this .',
#   'What do you mean cr is there anything I wanna ',
#   'I is there any of these criteria that need any explaining ? Or is there '
#   'anything that yous thought tha really would stand out compared to the '
#   'others ?',
#   'Um , a few .  Something I neglected from my initial research is that Real '
#   'Reactions has a a goal strategy that all of the products be inspired by '
#   'material fashion , and clothing fashion . That is why fruit and veg being '
#   'popular in the home and in clothing was important and they want all their '
#   'products to be somehow inspired by current trends in fashion . So they say '
#   "we put the fashion in electronics , well they really mean it they they're "
#   'very big on fashion ,',
#   'Okay .',
#   "so . That's this bit right here . And uh this bit is this one easy to use "
#   "for visitors or for anybody ? I guess it's just the same as saying easy to "
#   "use interface , so it's kinda condensed into one . And we can come back to "
#   'it , you said .',
#   'Okay .',
#   'So .',
#   'No and which we will do very very shortly . Um . Okay . Slight problem we '
#   'had was that we have an amazing four Euros over budget for what we were '
#   'hoping to do . Um most of it stems from the use of the L_C_D_ which I think '
#   'in the end accounted for about half of our expenditure because of course we '
#   'required a chip as well . Um the only way to get this down was either to '
#   "ditch the a L_C_D_ , at which point we've removed a large part of how we "
#   'were gonna interface ,  require more buttons , etcetera . Or what we did '
#   'was that we um we as in I as I was quickly going over it was altering the '
#   'actual structure . Um changing it to plastic and a solid unit with a single '
#   'curve design would allow us to come back into the um proposed costs and '
#   "we're just scraping it in , we've got point two of a Euro left over there . "
#   "So we're just managing it really . Even then as well , um there was no "
#   "criteria technically defined for a joystick so I've used what I think's "
#   "appropriate . With any luck that won't mean that we've incurred more cost "
#   'than we can actually afford to . It blows a lot of our really good ideas '
#   'kind of slightly to one side , for example the possibility of having a '
#   'U_S_B_ connection is definitely not viable now . Um .',
#   'Different languages ?',
#   "That should still be viable . We've got an advanced chip , we've got the "
#   'use of the L_C_D_ . So being able to communicate in multiple languages is '
#   'still very much a possibility .',
#   'Yeah . ',
#   "Um but what's something we need to decide on is how we're gonna go from "
#   'here .  We do need to try and come up with an idea which could be continued '
#   'with other people if need be . Um . We can I can bring the excel up sheet '
#   'up and uh show you if you wish um . I really think as m much as it pains me '
#   'is that we might have to go with plastic and some kind of solid design , '
#   "possibly meaning that the L_C_D_ wouldn't be in this perfect place . It "
#   'might be s stuck like slightly between what would be good for left handed '
#   'and what would be good for a right handed person .',
#   'Mm-hmm I suppose o one thing that could be done is h  is have it um '
#   'circular and have it s  so that the uh the pink  actually goes a bit over '
#   'the pinkie finger . Mm .',
#   'Okay .',
#   'Mm .',
#   'So that uh th',
#   'It very much is about making concessions , unfortunately . Um .',
#   'Mm .',
#   'Do you have any data on how much um different prints cost ? I mean can you '
#   'get the entire thing printed with a design um ?',
#   'Um b b b da is  you mean on the plastic , or ?',
#   ' .',
#   "Let's have a look . You now have as much information as I do .  Um .",
#   'Yeah , yeah .',
#   'So as you can see here , for example , the battery really not very little '
#   "choice in that one . We've gone for one of the cheaper options as well . "
#   "Unfortunately we require the advanced chip if we're gonna do what we're "
#   "needing to . I've said single curved . We really do need it to be that way "
#   'for the ergonomics of it . Um plastic for some reason incurs no cost , '
#   "which I've had to very much make advantage of , despite the fact that "
#   "rubber's only got a value of two Euros per unit . Problem comes here as you "
#   "can see in the interface . Um if I've read this thing correctly , then we "
#   "can save point five of a Euro here in that it's not per push button . That "
#   'might make sense , because then a numeric keypad would come in at um what , '
#   'four point five Euros , which is an awful lot , so that could well be wrong '
#   ". Even if we save point five there , it would just mean that we're most "
#   'likely placing it in actually just gaining a colour for the unit , which '
#   'has had to be put to one side . As you can see , the use of an L_C_ display '
#   'um advanced chip and what would determine the scroll wheel here as well '
#   "because it's an integrated scroll scroll wheel push button that wasn't "
#   'quite what I think they had in mind with a joystick .',
#   'Why would why would that be more expensive than an individual push button '
#   "and scroll wheel together ? That's quite significantly expensive .",
#   "I  that's something you'll have to take up with the bean counters . Um",
#   ' .',
#   '',
#   'Mm .  yeah .',
#   "as you can see I mean that's taken up well over half of the price .",
#   'Yeah .',
#   "So um I'm very much open to suggestions of where we go , but because we "
#   'need to shed what was four Euros off of the um the price of for what we '
#   'really desired , this one comes in under price as you can see , but this '
#   'was the one that sacrificed the material for the case and for the actual '
#   'case design .',
#   "We don't even have uh speakers here . The  like uh we uh  what about "
#   'speakers and transmitters and stuff like that ? Have we factored that in ?',
#   'Mm .',
#   "Uh no , we haven't , not ",
#   "Transmitter , receiver , speakers . Plus the extra device itself that's "
#   'gonna be on a T_V_ .',
#   '',
#   'Is that gonna be a button , or ',
#   "That'll  it literally would just be a button .",
#   'Yeah .',
#   'We might have to ',
#   "That's too expensive  isn't it ?",
#   'It looks like almost nothing  Mm . Oh good call , I missed that .',
#   "I I mean it's not on here , but um .",
#   " that's a very valid point .",
#   'Did they s do we have to use an advanced chip for the L_C_D_ ?',
#   'Yeah .',
#   "Okay . Well that's  yeah .",
#   "So if we're gonna go with the L_C_ display , then that's ",
#   "What's a hand dyna dynamo ? You have to wind it up ?",
#   'I believe so , yeah .',
#   '',
#   '',
#   'That would probably not be in keeping with the um the fashion statement and '
#   'such ,',
#   ' Technology . Yeah .',
#   'Fashion .',
#   'yeah .',
#   'Okay .',
#   'So basically the only new thing is the L_C_D_ on the remote now .',
#   'Being manipulated by the joystick , yeah .',
#   'Oh , and joystick , yeah .',
#   "Which I'm defining as scroll wheel . Um .",
#   "And we couldn't replace the joystick , right ? Because we would need four "
#   'extra buttons to replace it , up down left and right , and that would be '
#   'more expensive than a  but is a scroll wheel not just back and forward ?',
#   'Mm .',
#   "Yeah it's just because there was no actual definition for what a joystick "
#   "might be , that that's what I've labelled it for the purposes of this "
#   'evaluation .',
#   'So  The L_C_D_ basically is the big selling point of',
#   'If we remove the L_C_ display , we could save ourselves',
#   'the remote .',
#   'a fair amount . Which you could  ',
#   "But that's what makes it uh original though ,",
#   'Mm . I think  if we remove the the L_C_ display then there was absolutely '
#   'no point to any of these meetings',
#   'Yeah . ',
#   "isn't it ?",
#   'and we just  we could just put our branding on any other remote control .',
#   'Yeah . Yeah . Um . Uh k',
#   "It's a shame . We should possibly have  If we could've increased the price "
#   "we could've manufactured that and we could've got something far closer to "
#   'what we were hoping to .',
#   "Does this does this bear in mind that  I mean it's a bit ridiculous that "
#   "they're gonna charge us what is it , like this much money for three million "
#   "if we're gonna buy three million components ,",
#   "Again , you'll have to argue with the accountants on that one .",
#   'you know .',
#   "Um but for the purposes of this meeting , I'm  we're gonna have to stick "
#   'with these figures .',
#   "Mm . 'Kay .",
#   "So , I would say that it would seem like the general opinion is we're gonna "
#   "keep the L_C_ display 'cause it's about what really separates us ,  despite "
#   "the cost it's gonna incur . Um",
#   'I think so .',
#   'are people maybe not happy with , but are willing to go ahead with this in '
#   'going for a plastic solid case , to keep the L_C_D_ ?',
#   'Mm-hmm . Um yeah  I mean one thing , I mean ho uh how much extra would it '
#   'be to to keep I mean  keep the um the articulation ?',
#   "It's hard to tell . Um I would say that you're at least gonna take double "
#   'curved ,',
#   "This is what I'm wondering .",
#   "and even then I'm not quite sure if that's incorporating the idea of "
#   'articulation .',
#   'Oh',
#   'Yeah .',
#   "no , I think I I it d that it needn't require it to be double curved .",
#   'It can be s yeah , it can still be single curved ,',
#   "It's uh it's just  it's just  it's just that the case would come in t  "
#   'would be made in two parts and then joined together with an articulation .',
#   'but ',
#   'Single curved with articulation ?',
#   'You just  .',
#   'Could we could we not get rid of the curvy the curvous the curvaceousness '
#   "and focus on the menu being the best interface ? 'Cause like we  do we have "
#   're restrictions on software ?',
#   "That's what we need for the joystick I think though .",
#   'Mm . Yeah , I mean',
#   'Oh but there has to be ',
#   'and  I mean the uh I mean if you look uh if you look closer at the uh at '
#   'the prototype here , the lines here along the grip are actually quite '
#   'straight . Um I mean  yeah ,',
#   ' But the curves all o over  hand ,',
#   "on the  on the L_C_D_ I mean although we've done it with a curve it",
#   'is it ?',
#   "could just as easily be done um without curves . The curve that's really "
#   'needed is up here ,',
#   ' joystick .',
#   'to put uh to keep the joystick in a good ergonomic position for it to have '
#   'it rest on the top of the hand .',
#   'Okay . Sure . Okay , my bad .',
#   "We wouldn't actually save a lot by reducing it anyway , so I mean for the "
#   'purposes of this meeting maybe we can state that single curve still allows '
#   'articulation .',
#   'Mm .',
#   'Um unless we hear otherwise we could go ahead with that proposal .',
#   'So I think the product is not gonna perform so well for my criteria .',
#   'Which is what we can get onto now . As long as  so are we gonna say   w we '
#   "have to keep an eye on the time as well , but we're gonna say um single "
#   'curved design  ',
#   'Oh , wait a minute . Sample speaker ? What is a sample speaker ? Is that '
#   'somewhat similar to what we want ?',
#   'It could well be ,',
#   'Mm no',
#   'but at a cost of ',
#   "that's that voice response thing that we got the email about .",
#   'Costs four .',
#   'Yeah .',
#   'But I thought it was just completely pointless .',
#   'You got a email about voice response ?',
#   'Yeah .',
#   'I did not ,',
#   'Alright .',
#   'so .',
#   'B i basically it was  saying that our labs had come up with a chip that you '
#   'could , you know , say hello to , and it would say hello back in a friendly '
#   'female voice  . ',
#   "Okay , yeah we'll definitely won't go with that one .",
#   "We won't go with that one , did you say ?",
#   "Yeah , that's voice recognition , so .",
#   'I mean I  we  Okay , okay .',
#   'Um . So , okay yeah , battery definitely , ',
#   "So it looks like we're gonna get rid of the whole loca  locator thing .",
#   'It looks like it unless we can manage to put it in under point two Euros , '
#   'um .',
#   'Yeah .',
#   ' Okay .  Okay .',
#   'Mm-hmm .',
#   "Maybe even slight well oh yeah , pretty much point two Euros , I'd say . So "
#   "we'll leave that one for now .  we'll just have ",
#   'Are we going for a special colour at all ?',
#   "It's uh a case of um I'm uh slightly unsure . One  point five of a Euro for "
#   "one push button doesn't sound quite right . So maybe it's a case of a push "
#   'button is maybe one or more . Um .',
#   'Mm .',
#   'Well',
#   'At which point if ',
#   'I was  for a case . Or had you already incorporated that ?',
#   'Oh , special colour for the case .',
#   "Well you got point five there . It's literally a case of whether or not "
#   "this is correct . I'm not quite sure if they're  I don't think they mean "
#   'point five Euros per button .',
#   'Okay , well',
#   'Mm-hmm .',
#   "l let's say that and then we can have our special coloured case",
#   'So',
#   'and then we at least have  make it a little harder to lose .',
#   'There we go .',
#   'Because most m most remotes are a fairly dingy colour that gets camouflaged '
#   'under any pile of crap in a living room .',
#   "W what's the default colour ? White or black ?",
#   "Black's probably the normal colour you'd say ,",
#   'Or grey .',
#   'yeah .',
#   'Right .',
#   "I quite like that colour that you're fetching there ,",
#   'Yellow . ',
#   "it's uh definitely for make it glow in the dark even better .",
#   'Yeah .',
#   ' So will we go with that then ?',
#   'Okay .',
#   "It's not and we can see ",
#   'Yeah .',
#   "we'll come back to uh your evaluation",
#   ' Sure .',
#   "which you're probably now going to pan us but there we go .",
#   'Okay . Okay .',
#   '',
#   'So uh ',
#   'Just to give you an idea , um you want to go maybe a bit quickly as well , '
#   "I'm not sure how much time . We've not hit the five minute mark warning yet "
#   ',',
#   'Right okay . Okay .',
#   'but .',
#   "Think it's ten minutes left . "],
#  ["'Kay . Ability to stop remotes from being lost or to find them once they "
#   'are lost . Um . Okay .',
#   'Special colour .',
#   'Special colour .',
#   'Mm mm four ?',
#   'Uh uh four .',
#   'Three ? Mm .',
#   'Three . I think we can do three .',
#   "Three if we're being generous , I feel .",
#   '',
#   " Th the special colour doesn't  would I think make a difference .",
#   "Think we're being generous here with three .",
#   'Three .',
#   "It makes it stand out from  you know it's lost in a big pile of crap , it "
#   'stands out from the rest of the crap . ',
#   'Mm . Yeah .  Okay .',
#   'Okay .',
#   "Reduce the number of unused buttons . We're down to t two buttons , is it ?",
#   'Two buttons and a joystick .',
#   'Two buttons .',
#   "Okay , so that's a one . You know ,",
#   'Totally .',
#   "where that's ",
#   "Yeah . I'd say we're doing well there .",
#   'Okay , that was good . Easy to use interface , buttons menu , menus ',
#   '  Mm-hmm .',
#   "that's yeah that's good .  'Kay that's  we're not doing so badly . Um  easy "
#   "to use  oh okay , let's forget that one . Fancy looking . ",
#   ' As he models the ',
#   "It doesn't get much fancier .",
#   "Sure . And we could do whatever we like with the L_ L_C_D_ . Yeah let's "
#   "just assume it's a good L_C_D_ display .",
#   '',
#   'Maybe I was panicking for no reason .',
#   'Are we going one on  ?',
# ...
#   'So',
#   'and then we at least have  make it a little harder to lose .',
#   'There we go .',
#   'Because most m most remotes are a fairly dingy colour that gets camouflaged '
#   'under any pile of crap in a living room .',
#   "W what's the default colour ? White or black ?",
#   "Black's probably the normal colour you'd say ,",
#   'Or grey .',
#   'yeah .',
#   'Right .',
#   "I quite like that colour that you're fetching there ,",
#   'Yellow . ',
#   "it's uh definitely for make it glow in the dark even better .",
#   'Yeah .',
#   ' So will we go with that then ?',
#   'Okay .',
#   "It's not and we can see ",
#   'Yeah .',
#   "we'll come back to uh your evaluation",
#   ' Sure .',
#   "which you're probably now going to pan us but there we go .",
#   'Okay . Okay .',
#   '',
#   'So uh ',
#   'Just to give you an idea , um you want to go maybe a bit quickly as well , '
#   "I'm not sure how much time . We've not hit the five minute mark warning yet "
#   ',',
#   'Right okay . Okay .',
#   'but .',
#   "Think it's ten minutes left . ",
#   'Ten .',
#   "'Kay . Ability to stop remotes from being lost or to find them once they "
#   'are lost . Um . Okay .',
#   'Special colour .',
#   'Special colour .',
#   'Mm mm four ?',
#   'Uh uh four .',
#   'Three ? Mm .',
#   'Three . I think we can do three .',
#   "Three if we're being generous , I feel .",
#   '',
#   " Th the special colour doesn't  would I think make a difference .",
#   "Think we're being generous here with three .",
#   'Three .',
#   "It makes it stand out from  you know it's lost in a big pile of crap , it "
#   'stands out from the rest of the crap . ',
#   'Mm . Yeah .  Okay .',
#   'Okay .',
#   "Reduce the number of unused buttons . We're down to t two buttons , is it ?",
#   'Two buttons and a joystick .',
#   'Two buttons .',
#   "Okay , so that's a one . You know ,",
#   'Totally .',
#   "where that's ",
#   "Yeah . I'd say we're doing well there .",
#   'Okay , that was good . Easy to use interface , buttons menu , menus ',
#   '  Mm-hmm .',
#   "that's yeah that's good .  'Kay that's  we're not doing so badly . Um  easy "
#   "to use  oh okay , let's forget that one . Fancy looking . ",
#   ' As he models the ',
#   "It doesn't get much fancier .",
#   "Sure . And we could do whatever we like with the L_ L_C_D_ . Yeah let's "
#   "just assume it's a good L_C_D_ display .",
#   '',
#   'Maybe I was panicking for no reason .',
#   'Are we going one on  ?',
#   ' Yeah ,',
#   "I'd say we go two , 'cause like f the fanciest would be the double curved .",
#   'Mm .',
#   "I'd ",
#   "Wouldn't it ?",
#   "w maybe you'd be a bit too ",
#   'Yeah . ',
#   'yeah . There we go . Yeah ,',
#   'With the articulators . With bells on it .',
#   "that's m that's that's better too . More accurate numbers . Technologically "
#   "innovative . Well , we're getting rid of the locator thing",
#   'Which is a shame .',
#   'which which',
#   "Mm . I'd give it a three for this  for that .",
#   'yeah  ',
#   'No need for teletext .',
#   ' .',
#   "Yeah . I mean the menus thing is something you don't normally see on um on "
#   'a remote ,',
#   "'Kay .",
#   'but  you see it in a lot of other places .',
#   'Yeah , mobile phones .',
#   'Mm .',
#   "And y what you're doing is moving the menu from the television to the "
#   "remote control , so it's ",
#   'Mm-hmm .',
#   'You say three ? I might go as far as two on that . Three .',
#   "I'd give it a three .",
#   "I'd be tempted with three , yeah .",
#   'Three . Okay .',
#   "We'll get panned on the next one , anyway .",
#   'Okay . Materials that people find pleasing .',
#   '',
#   'Yeah , w',
#   'Sponginess is what they really would have wanted , apparently .',
#   "It is , yeah . Don't blame them .",
#   '',
#   "Um because of the way that we've minimalised the number of buttons and such "
#   '.',
#   'Yeah .',
#   "Plastic , it sucks . But it's no worse than any of the other pl remote "
#   'controls we have .',
#   "That's true . It's not a step backwards .",
#   ' five ?',
#   "Mm-hmm . I'd s I I'd give it a six , to be honest .",
#   'Six ?',
#   '  ',
#   " Yeah , okay let's give it a six .",
#   'Six ,  .',
#   " Okay , that's totally thrown everything off balance . Inspired by the "
#   'latest interior and clothing fashion . W we could . What colour were we '
#   'gonna make it ?',
#   'Put a leopard print on it . ',
#   'Well I I I would sa I would say give a s give a selection of colours .',
#   ' I know ,',
#   'Um we went with yellow we went with yellow for the prototype',
#   'but ',
#   "'cause we had yellow . If I were buying one , I'd go for purple . Leopard "
#   'print would be cool .',
#   "But um by this I think it's more a case of fruit and veg , ",
#   "Yeah we gotta  . I'd say the colour of the border there world  you'd find "
#   "that ,  that's that'd stand out .",
#   ' Yeah .',
#   'Like yellow , yeah . It would also help keep the the product placement s',
#   'Logo , brand .',
#   'yeah .',
#   'Mm .',
#   'Is it inspired by  clothing fashion ?',
#   "But  Th th they're referring to the fruit and veg thing .",
#   "Mm 'kay .",
#   ' Yes .',
#   "Is this like a banana type colour ? Could we stretch  no still , it's not "
#   'shaped like a banana is ',
#   "That's kinda   i",
#   "It's kind o it",
#   "it won't be when it's been",
#   'probably  ',
#   "Oh is that 'cause it's flat ?",
#   'budgeted .',
#   'What is  what fruit or veg is flat ?',
#   "I I think s I I think this isn't  not particularly fruit and veggie . Um .",
#   'Yeah . Or we might have to suffer badly for this one as well . ',
#   'Yellow courgette .',
#   '',
#   ' Well',
#   '',
#   "I mean it's probably more fruit and veg than most other things out there "
#   'bar fruit and veg , so ,  what , four ?',
#   "Four ? Oh that's it's very ambitious ,",
#   'Is that being too generous ?',
#   "Mm . I'd  I'd I don't think fruit and veg is the sole criterion .  Is the "
#   'sole criterion for being um fashion  fashionable or inspired by current '
#   'fashions .',
#   'yeah , um .',
#   'Oh dear ,  .',
#   'Sure . Inspired by  .',
#   "Um I'd g I'd rate I'd rate this fairly highly from that point of view "
#   'actually .',
#   "Well this this what we're gonna t this is their motto , like .",
#   'Yeah .',
#   "And we're we're not doing well on it .",
#   'This is their strategy . I m imagine we actually had some money invested in '
#   'this and the amount that we invest is gonna be proportional to the marks . '
#   'Might  we might wanna be a bit more skepible sceptical about this one .',
#   'What would you think yourself ?',
#   "I would say  I mean it's it's not at all , right ?  In any way or shape or "
#   'form .',
#   " Well , it's kind of curved",
#   "We didn't m",
#   "and we can make it yellow , and that's pretty much banana like .",
#   'Okay , the the yellow banana like thing is I think is okay .',
#   "Si it's got a curve to it .",
#   'Right five . Is that  sound reasonable ?',
#   "Am I  do you think I'm stretching the uh the use of the banana ?",
#   "Yeah , I'll go with five .",
#   "Five .  Yeah . 'Kay , so we have one , two , three , four , five , six , "
#   'seven . So five , seven , ten , sixteen , twenty one . Which gives us an '
#   "average of three . It's  well this would be in the middle . So we it's it's "
#   "not bad . It's in the good section .",
#   "It's not bad and considering the   don't pick the pen . Um .",
#   " Oops . Sorry .  I'm I'm sorry .",
#   '',
#   "Y oh and you've knocked batteries out .",
#   '',
#   " Um right okay it's  ",
#   "'S bad design , that thing . ",
#   'considering the price we had to get this in , to have a positive  you know '
#   ', even based on the four of us being heavily biased , um',
#   'Mm-hmm . Yeah .',
#   " it was gonna be quite hard to get anything standing out I'd say possibly , "
#   'based on um the the cost features .',
#   'Mm .',
#   'Mm , yeah .',
#   'Even if we were to increase this entire thing by by seven , we were to go '
#   "down a grade to to four , we would have to do  I mean we didn't we weren't "
#   "that kinda optimistic too optim overly optimistic . You know like we didn't "
#   "we didn't add we didn't subtract a whole seven points from these things , "
#   "so I think we're definitely on the good bit .",
#   '',
#   "Even if we gave this one seven and this one seven , that's still only three "
#   "extra points over seven . You know , it's  yeah ,",
#   'Mm . Personally , I think given that the product um only replaces a single '
#   'remote control',
#   'we did it w it was okay . It was good .',
#   "that you've already got , are people really gonna shell out twenty five "
#   "Euros for something that's only marginally good ?",
#   "Well , it depends who your  who's  what the target people are , like you'd "
#   'say maybe the fashion conscious',
#   "Maybe it's been targeted ",
#   "women would be going , oh look at that , 's cool , it looks like a ",
#   'Mm-hmm .',
#   "it's yellow , looks like a banana , it's cool it's gotta  look good in the "
#   'sitting room .',
#   'Hide it in the fruit basket .',
#   'Rather than the L_C_D_ whereas uh more technical like like more uh people '
#   "in with the latest technology  it's good , it's got an L_C_D_ screen 's "
#   'only got two buttons and a joystick . So , which which kind of people would '
#   'be more likely to buy it ?',
#   "Probably the people technologically . They're usually the ones that buy "
#   'pointless stuff .',
#   '',
#   'I think so .',
#   '',
#   'I mean my mum still has not learnt how to use text messaging on her phone , '
#   "and she's had it for a long time , you know . She uses it to make phone "
#   "calls and that's it .",
#   ' .',
#   'Yeah . So I think if sh if my mum saw a remote control like this with only '
#   "two buttons and a joystick , I mean that'll probably be the first one she "
#   'decides not to buy , you know .',
#   'Mm-hmm .',
#   "She'd be like is this a remote control , I don't  how do you use it , and "
#   "stuff like that . So even if it is really user friendly to us , but we're "
#   'used to using menus all the time .',
#   "Mm-hmm . I s  I suppose one thing is that b because it's technically "
#   "innovative , um for someone who's sort of technophobic , the fact that it "
#   'simply looks unfamiliar would be daunting .',
#   'Yeah . Yeah .',
#   'Um .',
#   "I think it's totally uh radical to have a remote control with no no "
#   'numbered buttons ,',
#   'Yeah .',
#   'yeah .',
#   'Yeah .'],
#  ["Okay . Um don't know how lo much longer we've got . At least five minutes I "
#   "think . Um quickly we'll pop onto project evaluation . Um . So , we've got "
#   'these uh four criteria here for uh satisfaction . Does anybody want to um '
#   "um do you have any opinions on any of them ? For example um  we'll work "
#   'backwards I suppose . The ability to work on this project using the '
#   "technology we've been presented with . Um  people made good use of the uh "
#   'pen and paper ?',
#   'Yeah ,',
#   'I would say  ',
#   'got notes and doodles .',
#   ' Wrote nearly a page ,',
#   'Yeah .',
#   'but not  .',
#   "I'm not quite sure what the advantage for us using a digital pen might be .",
#   "Well I think this is a  I think the digital pen's mostly for the benefit of "
#   'the uh',
#   'I think tracking .',
#   "of the researchers studying this . It's all p goes into their corpus .",
#   'It must ',
#   'Though it would have been nice to be able to transfer the um transfer our n '
#   'our paper notes onto the uh computer ourselves .',
#   'Yeah , that woulda been pretty good .',
#   "It does seem like the paper's still a heavy consideration for taking notes "
#   '. So maybe this is literally just a way around it . Um I dunno . How are '
#   "people satisfied with the teamwork we've managed to display today ?",
#   ' .',
#   "I'd ",
#   'Good .',
#   'yeah I liked it , yeah .',
#   'Leadership . As much as can be leadered in this uh thing .',
#   'Very good .',
#   'I li yeah , top marks .',
#   "Um last one we've got is room for creativity .",
#   ' Well ',
#   ' Unti uh uh until uh until accounts came along ,',
#   'Now , I think we got ',
#   ' squish .',
#   "We're burs bursting with creativity .",
#   'yeah . ',
#   ' Yeah',
#   "We we're not lacking in ideas , you know it's  that was not the problem .",
#   'I think of  in the end , ideas that can be used  sadly  . Not so much that '
#   "we weren't full of ideas , but of ones that are gonna allow us to actually "
#   "build the thing . It's a bit of a pity .",
#   'Mm-hmm .',
#   'Um I would have to agree on that . I think we needed a larger budget .',
#   'Yeah .',
#   "If you're going to aim your a um product maybe at the technological kind of "
#   'sector , then you can afford to maybe jack the price up slightly from what '
#   'it is .',
#   'Yeah .',
#   'Because they will pay outrageous cash to ',
#   'Mm . I mean I th  I mean I think to r retaining the s the more sort of '
#   'bio-morphic form in the articulation would gain more in s uh would gain '
#   'more profit in sales than it would lose in uh',
#   'first on the market .',
#   'in added expense .',
#   'Mm .',
#   'And the price was like  it was twice the w assembly cost . And would it '
#   'have to be twice that ? It could be like coulda had the assembly  like '
#   'maybe fifteen Euro .',
#   'It could even ',
#   "We'll still settle for twenty five  .",
#   "That's true , yeah .",
#   'Maybe . ',
#   'Um I suppose these are all that will have to be taken up with a at a '
#   "different group at I guess . As to a  the costs involved . But I mean we've "
#   'got a a prototype .',
#   'Such as it is .',
#   " So I dunno , I I think it's gone okay today , considering the information "
#   "that we've had at our disposal , and um such .",
#   'Maybe the counts wou woulda been better if we had a list or more  Yeah , to '
#   'begin with .',
#   'In the beginning , yeah .',
#   'Yeah .',
#   'Probably would have  mean we could have come up with a lot more solid '
#   'design in the end ,',
#   'Yeah .',
#   'I would have to agree . It is very much a pity to um get so far into the '
#   'stage and then find out that maybe some of your ideas are just a bit too '
#   'expensive . Always hard to tell until you know the costs . Um . Okay . Are '
#   'the costs within budget ? Well ,',
#   '',
#   'they are now that we have our slightly less than capable product .',
#   'Okay .',
#   "We've evaluated it , and we can say that we came out with a value of three "
#   '.',
#   'Yeah .',
#   'Actually I want th one thing I would say ',
#   '',
#   'I mean something that could perhaps be part of the product mm the um m '
#   'product testing market research process would be to uh produce mock-ups of '
#   'both versions and see just how much of a difference the over  going '
#   'over-budget um m would make to sales .',
#   "It's  yeah ?",
#   'And like response from consumers  .',
#   'And we could even you know , market two versions .',
#   '',
#   '',
#   'Wee cheapie version with the nice bio-morphic rubber . ',
#   'And then the final one where you get to call it Hal .',
#   'Yes .',
#   "But we'll go into that later .",
#   ' Sure .',
#   'Right um',
#   '',
#   'is there anything else that anybody would like to to add , um  anything '
#   "they think that's not been covered , before I quickly write up a final "
#   "report . Um I dunno , I mean we've got a product . We maybe aren't as happy "
#   "with it as we'd like to be , but we've got something we think we can maybe "
#   'stick onto the the market and sell . And of course something we have been '
#   "avoiding talking about 'cause of we've no information is selling them "
#   'directly to the manufacturers . There is a huge market .',
#   'Yeah .',
#   "I mean we've briefly touched on it but we've no more knowledge then there's "
#   'little we can say on that .',
#   'Yeah .',
#   'Mm .',
#   "Yeah . So um unless anybody's got anything they'd like to add , we can "
#   "maybe round this up slightly earlier than we'd need to and then we can "
#   'finish up the writing and such .',
#   'And I can get my bus . Okay .',
#   'Yeah ?',
#   "Yeah . Okay , let's ",
#   'Uh thank you for your participation .',
#   'Thank you .',
#   'Thank you .',
#   ' I was actually kind of upset you know at the budget , and that we had to '
#   "cut a lot of stuff . It's like man , we we can't have the locator thing . "
#   "And s yeah that's just bad . Do you think maybe  the prices were were made "
#   '?']]

# %% [markdown]
# ### Preprocess all the data for text segmentation

# %%
def preprocess_text_segmentation(data):
    # shape: [["sentence 1", "sentence 2"], ["sentence3", "sentence4"]]
    text_segments = []
    for sample in data:
        # get the topic list and meeting transcript from the current sample
        topic_list = sample["topic_list"]
        meeting_transcripts = sample["meeting_transcripts"]

        for topic in topic_list:
            prev_end_span = -1
            for text_span in topic["relevant_text_span"]:
                # for this specific topic, get the relevant start and end spans
                start_of_span = int(text_span[0])
                end_of_span = int(text_span[-1])

                # MISSING TOPIC CASE
                # this means that there are some sentences without a topic
                # for example, [0, 19] and [24, 29], where 20 - 23 are missing
                if start_of_span != (prev_end_span + 1):
                    missing_topic_meeting = meeting_transcripts[
                        prev_end_span + 1 : start_of_span - 1
                    ]
                    if len(missing_topic_meeting) != 0:
                        missing_topic_full_segment = []
                        for segment in missing_topic_meeting:
                            tokenized_content = segment["content"]
                            # clean the text before insertion
                            cleaned_content = clean_data(tokenized_content)
                            # get the content for the segment and throw it into the list of segments
                            missing_topic_full_segment.append(cleaned_content)
                        text_segments.append(missing_topic_full_segment)

                # REAL TOPIC CASE
                topic_meeting = meeting_transcripts[start_of_span:end_of_span]
                if "meeting" not in topic:
                    topic["meeting"] = []
                topic["meeting"].append(topic_meeting)

                full_segment = []
                for segment in topic_meeting:
                    # get the content for the segment and throw it into the list of segments
                    full_segment.append(segment["content"])

                text_segments.append(full_segment)
    
    return text_segments

# %%
len(text_segments)
# Out:
# 7

# %%
print([len(s) for s in text_segments])
# Out:
# [38, 38, 215, 254, 171, 426, 89]

# %%
# average number of strings in each segment
print(sum([len(s) for s in text_segments]) / len(text_segments))
# Out:
# 175.85714285714286

# %% [markdown]
# ### Save the data to a file

# %% [markdown]
# All meetings

# %%
import pickle

file_name = "./all_meetings_text_segments_train.pkl"

# %%
open_file = open(file_name, "wb")
pickle.dump(text_segments, open_file)
open_file.close()

# %%
# open_file = open(file_name, "rb")
# loaded_list = pickle.load(open_file)
# open_file.close()
# loaded_list

# %% [markdown]
# Academic meetings

# %%
# read the dataset
# please enter the path of your data
split = "test"
data_path = "./data/Academic/jsonl/" + split + ".jsonl"
academic_data = []
with open(data_path) as f:
    for line in f:
        academic_data.append(json.loads(line))
n_meetings = len(academic_data)
print("Total {} meetings in the {} set.".format(n_meetings, split))
# Out:
# Total 9 meetings in the test set.

# %%
academic_text_segments = preprocess_text_segmentation(academic_data)

# %%
file_name = f"./academic_meetings_text_segments_{split}.pkl"
open_file = open(file_name, "wb")
pickle.dump(academic_text_segments, open_file)
open_file.close()

# %% [markdown]
# Committee meetings

# %%
# read the dataset
# please enter the path of your data
split = "test"
data_path = "./data/Committee/jsonl/" + split + ".jsonl"
committee_data = []
with open(data_path) as f:
    for line in f:
        committee_data.append(json.loads(line))
n_meetings = len(committee_data)
print("Total {} meetings in the {} set.".format(n_meetings, split))
# Out:
# Total 6 meetings in the test set.

# %%
committee_text_segments = preprocess_text_segmentation(committee_data)

# %%
file_name = f"./committee_meetings_text_segments_{split}.pkl"
open_file = open(file_name, "wb")
pickle.dump(committee_text_segments, open_file)
open_file.close()

# %% [markdown]
# Product meetings

# %%
# read the dataset
# please enter the path of your data
split = "test"
data_path = "./data/Product/jsonl/" + split + ".jsonl"
product_data = []
with open(data_path) as f:
    for line in f:
        product_data.append(json.loads(line))
n_meetings = len(product_data)
print("Total {} meetings in the {} set.".format(n_meetings, split))
# Out:
# Total 20 meetings in the test set.

# %%
product_text_segments = preprocess_text_segmentation(product_data)

# %%
file_name = f"./product_meetings_text_segments_{split}.pkl"
open_file = open(file_name, "wb")
pickle.dump(product_text_segments, open_file)
open_file.close()

# %%
product_text_segments
# Out:
# [["Here we go . Welcome everybody . Um , I'm Abigail Claflin . You can call me Abbie . 'S see . PowerPoint , that's not it . There we go . So this is our kick off meeting . Um and I guess we should all get acquainted  .  Let's  shall we all introduce ourselves ?",
#   "Hi I'm Chiara , I'm the um Marketing Expert . Um , would you like me to talk about my aims at the moment , or would you like me to just say my name and then we can talk about business later ?",
#   "I think we'll get around to that , yeah . So this is just introductions yeah .",
#   "We'll get round to that later . My name is Chiara and I'm the Marketing Expert .",
#   "Okay . I forgot to s say I'm the Project Manager but I figured you all knew that already ,",
#   '',
#   '',
#   ' um so .',
#   " I'm Stephanie and I am the User Interface Designer ."],
#  ["Okay . Um so f here's our agenda for today . Um we're gonna do some tool training , project plan and discuss then close . {vocalsound} Um so . So our aim is to produce a remote control that is original , trendy and user friendly . And to do this , we have to {disfmarker} um there's certain things we have to consider about functional aspects and conceptual design of the thing . So . We'll get to that . Oh there it is . Right . Functional design , conceptual design and detailed design . So throughout our next couple of meetings we'll we'll be covering these things . Um {vocalsound} so we're gonna try out our white board . If we'll all draw our favourite animal , to sum up the characteristics of that animal . Okay .",
#   'So you want us to draw it and then talk about it ? Or just draw it ?',
#   '{vocalsound}',
#   'I think both . {vocalsound}',
#   'Yeah . Both . Yeah {vocalsound} .',
#   "Okay . Why don't we do both . Right .",
#   'Who starts ? We ought to decide who starts and {vocalsound} all that . No ?',
#   'Any volunteers ?',
#   'Uh-huh .',
#   'Does anyone know what they wanna draw ? {vocalsound}',
#   '{vocalsound}',
#   'Mm , I gotta think about it for a second like . Uh {disfmarker} Does it have to be {vocalsound} functional , trendy and user friendly ? {vocalsound}',
#   "{vocalsound} I don't think so .",
#   '{vocalsound}',
#   "Um . Okay , I'll draw . I'll draw one .",
#   '{gap}',
#   'Make sure {gap} my things here . Uh-oh . Right . Okay , my favourite animal is {disfmarker} see . {vocalsound} Oops .',
#   'A dolphin .',
#   "Yeah , it's {vocalsound} {disfmarker}",
#   '{vocalsound}',
#   "{vocalsound} 'S like playing Pictionary .",
#   "{vocalsound} Yeah , I guess it has a fin on top too , yeah . {vocalsound} It's my dolphin .",
#   '{vocalsound} So what characteristics do you like about your animal ? {vocalsound}',
#   '{vocalsound}',
#   'I like its tail .',
#   '{vocalsound}',
#   "{vocalsound} Um , no , I think dolphins are really uh {disfmarker} I dunno , they're smart and they they're cute and they like swimming and that's cool , like {disfmarker}",
#   "{vocalsound} They're graceful .",
#   "they're graceful yeah , and they're so {disfmarker}",
#   'Sleek {vocalsound} .',
#   "{vocalsound} Yeah they're sleek",
#   '{vocalsound}',
#   "and they look intelligent and I don't know , they're {disfmarker} I guess it's the whole like binocular vision thing .",
#   "I don't know how intelligent that one looks {vocalsound} .",
#   '{vocalsound}',
#   "Yeah he he doesn't look that smart {vocalsound} . He's a {disfmarker} {vocalsound} I dunno um they're {disfmarker} I think it's cool the the um {vocalsound} the interaction that or the th things that {disfmarker} the reasons people seem to like you know {disfmarker} you get ex you know people are sitting on the beach and p they're like oh look there's dolphins and it's kinda like {vocalsound} {disfmarker} but they're you know they jump around in the water and they're happy and they're mammals , but they swim . {gap} {vocalsound}",
#   'Yes . {vocalsound} Does anybody else wanna draw their animal ?',
#   'Suppose I can draw an animal , yeah .',
#   '{vocalsound} {vocalsound} .',
#   '{vocalsound}',
#   'Uh-oh there goes the ten .',
#   '{vocalsound} Yeah .',
#   "{vocalsound} It's a cat . {vocalsound}",
#   '{vocalsound}',
#   "I don't know . They sleep all day , {vocalsound} they're easy to draw {vocalsound} .",
#   '{vocalsound} Do you wanna {gap} anything ?',
#   'Uh yeah .',
#   'I dunno if the the {disfmarker}',
#   'I think the pen is running out of {disfmarker}',
#   "Well I had the cat as well , but uh I've got a spare one .",
#   'ah .',
#   '{vocalsound}',
#   '{vocalsound}',
#   "So I'll use the spare one . Um but it's harder to draw {gap} um .",
#   "And the pen's dying {vocalsound} .",
#   'Um .',
#   'A horse .',
#   'Horse .',
#   "Uh . Um I don't {vocalsound} really know how the legs go ,",
#   '{vocalsound}',
#   "That's very good .",
#   '{vocalsound}',
#   "but anyway I will do that . Um , and the main reason is they're pretty . I think they're very pretty and they go well with the environment , and I like the way they run and I used to do horse riding and they're just very sort of sturdy and nice animals . And I like the way um they feel , sort of under under the hand , I think that's pretty much it . Um {disfmarker}",
#   "{gap} Yeah . This cord's {disfmarker} {gap} Uh . Right . Actually I haven't thought of anything yet {vocalsound} . Uh {disfmarker} It's a pig .",
#   '{vocalsound}',
#   '{vocalsound}',
#   "{vocalsound} So I'm thinking we should design a remote control that's water resistant , strong and furry . What do you think , yeah ? This is {disfmarker}",
#   'And furry .',
#   'yeah , well like a cat , you know , soft yeah .',
#   '{vocalsound}',
#   'Textile {disfmarker} tactile , {vocalsound} tactile remote control .',
#   '{vocalsound}',
#   "{vocalsound} Although {disfmarker} uh I'll just put there . Right .",
#   "You're dragging a {disfmarker} you have a tail {vocalsound} .",
#   "{gap} Oh my gosh , this is disastrous . Sorry about that . {vocalsound} Okay . {vocalsound} So moving on . Our selling price goal is twenty five Euro and profit aim is fifty million Euro . So I'm guessing that we're not actually in Scotland , we're in some European country {vocalsound} . Um , and we will hope to sell this internationally .",
#   "Sorry can you just say that {disfmarker} what's the {disfmarker} what are our price goals again ?",
#   'Um selling price is twenty five Euro . Profit aim fifty million Euro .',
#   'Okay .',
#   'How many should we sell then ? {vocalsound} Um , a lot ,',
#   'Anyone a mathematician ? {vocalsound}',
#   'two two two million , {gap} two mi no , more f four million .',
#   'Two million .',
#   'Four million . And it {disfmarker}',
#   '{vocalsound}',
#   "well it's the profit so if a profit for each is twelve fifty , that'll do four million .",
#   'Oh , yeah .',
#   '{vocalsound} It is a lot . Uh .'],
#  ["Here we go . Welcome everybody . Um , I'm Abigail Claflin . You can call me Abbie . 'S see . PowerPoint , that's not it . There we go . So this is our kick off meeting . Um and I guess we should all get acquainted  .  Let's  shall we all introduce ourselves ?",
#   "Hi I'm Chiara , I'm the um Marketing Expert . Um , would you like me to talk about my aims at the moment , or would you like me to just say my name and then we can talk about business later ?",
#   "I think we'll get around to that , yeah . So this is just introductions yeah .",
#   "We'll get round to that later . My name is Chiara and I'm the Marketing Expert .",
#   "Okay . I forgot to s say I'm the Project Manager but I figured you all knew that already ,",
#   '',
#   '',
#   ' um so .',
#   " I'm Stephanie and I am the User Interface Designer .",
#   "I'm Krista and I'm the Industrial Designer .",
#   "Okay . Um so f here's our agenda for today . Um we're gonna do some tool training , project plan and discuss then close .  Um so . So our aim is to produce a remote control that is original , trendy and user friendly . And to do this , we have to  um there's certain things we have to consider about functional aspects and conceptual design of the thing . So . We'll get to that . Oh there it is . Right . Functional design , conceptual design and detailed design . So throughout our next couple of meetings we'll we'll be covering these things . Um  so we're gonna try out our white board . If we'll all draw our favourite animal , to sum up the characteristics of that animal . Okay .",
#   'So you want us to draw it and then talk about it ? Or just draw it ?',
#   '',
#   'I think both . ',
#   'Yeah . Both . Yeah  .',
#   "Okay . Why don't we do both . Right .",
#   'Who starts ? We ought to decide who starts and  all that . No ?',
#   'Any volunteers ?',
#   'Uh-huh .',
#   'Does anyone know what they wanna draw ? ',
#   '',
#   'Mm , I gotta think about it for a second like . Uh  Does it have to be  functional , trendy and user friendly ? ',
#   " I don't think so .",
#   '',
#   "Um . Okay , I'll draw . I'll draw one .",
#   '',
#   'Make sure  my things here . Uh-oh . Right . Okay , my favourite animal is  see .  Oops .',
#   'A dolphin .',
#   "Yeah , it's  ",
#   '',
#   " 'S like playing Pictionary .",
#   " Yeah , I guess it has a fin on top too , yeah .  It's my dolphin .",
#   ' So what characteristics do you like about your animal ? ',
#   '',
#   'I like its tail .',
#   '',
#   " Um , no , I think dolphins are really uh  I dunno , they're smart and they they're cute and they like swimming and that's cool , like ",
#   " They're graceful .",
#   "they're graceful yeah , and they're so ",
#   'Sleek  .',
#   " Yeah they're sleek",
#   '',
#   "and they look intelligent and I don't know , they're  I guess it's the whole like binocular vision thing .",
#   "I don't know how intelligent that one looks  .",
#   '',
#   "Yeah he he doesn't look that smart  . He's a   I dunno um they're  I think it's cool the the um  the interaction that or the th things that  the reasons people seem to like you know  you get ex you know people are sitting on the beach and p they're like oh look there's dolphins and it's kinda like   but they're you know they jump around in the water and they're happy and they're mammals , but they swim .  ",
#   'Yes .  Does anybody else wanna draw their animal ?',
#   'Suppose I can draw an animal , yeah .',
#   '  .',
#   '',
#   'Uh-oh there goes the ten .',
#   ' Yeah .',
#   " It's a cat . ",
#   '',
#   "I don't know . They sleep all day ,  they're easy to draw  .",
#   ' Do you wanna  anything ?',
#   'Uh yeah .',
#   'I dunno if the the ',
#   'I think the pen is running out of ',
#   "Well I had the cat as well , but uh I've got a spare one .",
#   'ah .',
#   '',
#   '',
#   "So I'll use the spare one . Um but it's harder to draw  um .",
#   "And the pen's dying  .",
#   'Um .',
#   'A horse .',
#   'Horse .',
#   "Uh . Um I don't  really know how the legs go ,",
#   '',
#   "That's very good .",
#   '',
#   "but anyway I will do that . Um , and the main reason is they're pretty . I think they're very pretty and they go well with the environment , and I like the way they run and I used to do horse riding and they're just very sort of sturdy and nice animals . And I like the way um they feel , sort of under under the hand , I think that's pretty much it . Um ",
#   " Yeah . This cord's   Uh . Right . Actually I haven't thought of anything yet  . Uh  It's a pig .",
#   '',
#   '',
#   " So I'm thinking we should design a remote control that's water resistant , strong and furry . What do you think , yeah ? This is ",
#   'And furry .',
#   'yeah , well like a cat , you know , soft yeah .',
#   '',
#   'Textile  tactile ,  tactile remote control .',
#   '',
#   " Although  uh I'll just put there . Right ."],
#  ["{gap} Oh my gosh , this is disastrous . Sorry about that . {vocalsound} Okay . {vocalsound} So moving on . Our selling price goal is twenty five Euro and profit aim is fifty million Euro . So I'm guessing that we're not actually in Scotland , we're in some European country {vocalsound} . Um , and we will hope to sell this internationally .",
#   "Sorry can you just say that {disfmarker} what's the {disfmarker} what are our price goals again ?",
#   'Um selling price is twenty five Euro . Profit aim fifty million Euro .',
#   'Okay .',
#   'How many should we sell then ? {vocalsound} Um , a lot ,',
#   'Anyone a mathematician ? {vocalsound}',
#   'two two two million , {gap} two mi no , more f four million .',
#   'Two million .',
#   'Four million . And it {disfmarker}',
#   '{vocalsound}',
#   "well it's the profit so if a profit for each is twelve fifty , that'll do four million .",
#   'Oh , yeah .',
#   '{vocalsound} It is a lot . Uh .',
#   "So f that's a fifty percent um uh . Um , I don't know what these mean because I didn't actually make the slide-show . Experience with remote control . So I guess we have to reflect on our experiences with remote controls to decide what um we would like to see in a convenient , practical , nice remote control . Um so do we have any initial ideas for uh how this remote control should be designed or formatted or the the buttons it should have .",
#   'Um , I think one thing is that it should be easy to find',
#   '{vocalsound}',
#   'I was thinking that too .',
#   'bec yeah {vocalsound} bec',
#   'Yeah .',
#   'I think we should design something that has like a {disfmarker} so you can {disfmarker} like somehow like you {disfmarker} I mean you always know where your T_V_ is , so just have a call button ,',
#   '{vocalsound}',
#   "I've always wanted that ,",
#   'Yeah .',
#   'so like {vocalsound} you can push a button on your T_V_ {disfmarker}',
#   'Yeah , yeah yeah yeah yeah .',
#   'I mean you have it for the portable phone , so why not {disfmarker} yeah .',
#   'Yeah , yeah yeah yeah , so you should have a call button on your television to be able to find your remote control .',
#   "Yeah . And even I think a little light . Um or even a {disfmarker} maybe a vib a vibrating thing . I dunno but someth because it's usually under the sofa .",
#   '{vocalsound}',
#   'Yeah . Yeah .',
#   "In which case you're going to be l but if it has a sort of signal which isn't any sound {disfmarker}",
#   'Yeah .',
#   "I don't know if it's expensive maybe to {disfmarker}",
#   "I don't {disfmarker} yeah I mean it {disfmarker} but like I mean {disfmarker}",
#   'Maybe call is enough . But yeah .',
#   'just I mean like your phone even just has so {disfmarker} like it can vibrate , it can light up and make noise and I dunno {vocalsound}',
#   'Yeah yeah yeah . Yeah .',
#   'What if it had something like um just like a magnet on the back of it and you could {disfmarker} I mean j just to have some place to put it besides like a base . You know like a portable phone has a base ,',
#   'Yeah . Yeah , or if it had a {disfmarker} yeah .',
#   'like just to have a home for it .',
#   '{vocalsound}',
#   'Yeah yeah yeah yeah .',
#   'Yeah ,',
#   "{vocalsound} 'Cause people just stick it on top of their T_V_ , but the point of having a remote is not to have to walk over to the T_V_ , so {disfmarker}",
#   'I mean {disfmarker}',
#   "{vocalsound} Well that's why it's always in the couch .",
#   'Yeah .',
#   'Yeah {vocalsound} .',
#   'Yeah , in in the couch {vocalsound} .',
#   '{vocalsound}',
#   '{gap}',
#   "I dunno , it seems like though that that would be hard , 'cause you not you're not gonna be lazy anyway and {disfmarker}",
#   'Yeah . Maybe we should design couches that have the remote control in the side arm . {vocalsound}',
#   '{vocalsound} {vocalsound}',
#   'Yeah so we {disfmarker} {vocalsound} the project is now couches and remote controls .',
#   '{vocalsound} But even just a thing to attach it to the w you know if you had a thing , a pretty object attached to the wall . But that would really make it more expensive .',
#   'Yeah .',
#   "But it's only a plastic thing , r really , the thing on the wall .",
#   'Yeah .',
#   'Yeah .',
#   'Something like that .',
#   'Do you think it needs to be bigger to not lose , or does that not factor in ?',
#   'And the other thing is {disfmarker}',
#   'Bigger .',
#   'Not {disfmarker} well it needs to be sort of {disfmarker}',
#   'Like Hand hand held size , yeah .',
#   'Hand-sized .',
#   "Yeah . I don't think you need a {disfmarker}",
#   'Not not huge , but {vocalsound}',
#   '{vocalsound}',
#   "But definitely not {disfmarker} well I don't know .",
#   "It can't be that hard to put some kind of a noise on it .",
#   "No , it can't be , uh-uh .",
#   "No it really wouldn't be .",
#   'Huh .',
#   'Or like or like a light thing . You know . I dunno {vocalsound}',
#   '{vocalsound}',
#   '{vocalsound} Like spaceship .',
#   '. Yeah {vocalsound} . Or make it mobile so it runs around and comes come find you yeah {vocalsound} .',
#   '{vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   "That would be really {disfmarker} I'm sure we could do that for twenty five Euros a pop .",
#   'Little homing device . {vocalsound} {vocalsound} Um .',
#   '{vocalsound}',
#   '{vocalsound} Yeah {vocalsound} . Uh .',
#   'Okay . So what do we think this remote control should {disfmarker} Five minutes .',
#   'Oh dear .',
#   'Till the meeting {disfmarker} oh right . This is what we have left . Um , oh we just {gap}',
#   "I also think though that it shouldn't have too many buttons ,",
#   'Yeah , I agree .',
#   "'cause I hate that when they have too many buttons and {disfmarker}",
#   'Yeah .',
#   "{vocalsound} B_ button and the F_ button , they don't do anything .",
#   'Yeah , yeah yeah .',
#   "I mean I know it has to have enough functions but like , I don't know you , just have like eight thousand buttons and you're like , no , you never use half of them . So .",
#   'You {disfmarker} what if um may be a little fancy but what if it had like a little screen , so it has less buttons but it still has all the functions . Like the way a mobile phone does .',
#   'That would be cool .',
#   'Yeah .',
#   'Yeah . I mean it just seems like {disfmarker}',
#   'So you could like um {disfmarker} like if you have I dunno if you have satellite if you have a hundred channels , you can {disfmarker} the way you do it on your radio is that you uh {disfmarker}',
#   'yeah .',
#   'what do you call it {disfmarker}',
#   'Select . Uh .',
#   's y yeah but you can programme , so you can programme like your favourite channels , so like if you had a s',
#   'But , would you have the screen on the thing , or would you have it on the telly transmitting the screen .',
#   "That's something we could decide . Mm .",
#   'Because {disfmarker}',
#   'I guess they would go together somehow ? I dunno .',
#   "Because , I don't know if it's {disfmarker} {vocalsound} I think it's e expensive , if you have {disfmarker} if you use the telly screen , 'cause the telly's already a screen , then you can pro sort of have a programming function , really easy sort of arrow up and down , on the remote ,",
#   'Yeah . Yeah .',
#   'and then use the telly as a screen .',
#   'Right .',
#   'But um {disfmarker}',
#   "I'm thinking kind of {disfmarker}",
#   "But yeah for sure . Something like not {disfmarker} it's not on the button but it's telling you what to do ,",
#   'Yeah .',
#   'is that what you mean ?',
#   'Yeah .',
#   'Right . Mm .',
#   "Or like you h you see those you know people {disfmarker} I'm thinking of like celebrity cribs kind of things when like they have all those {disfmarker} these things that at their house you know {disfmarker} their their entire house is so electronic , and they have like this one master control that {disfmarker} and it's like a hand held like {disfmarker} turns on everything sort of control and it has like a screen and like {disfmarker} so I think it should be possible to have some kind of a screen , I don't know if {disfmarker} it must be {disfmarker} it would probably {disfmarker}",
#   'Yeah .',
#   'must be ex too expensive though t like I dunno .',
#   'Mm .',
#   "But like mobile phones have screens and they're cheap .",
#   "Yeah , yeah . Yeah that's true .",
#   'Yeah . I mean , we have to remember our budget is twelve point {disfmarker} twelve fifty for {disfmarker} to actually make the device .',
#   'Yeah .',
#   'Mm .',
#   "Um but it's something to think about , yeah .",
#   'Well , I guess we have to get to that later , yeah .'],
#  ["Here we go . Welcome everybody . Um , I'm Abigail Claflin . You can call me Abbie . 'S see . PowerPoint , that's not it . There we go . So this is our kick off meeting . Um and I guess we should all get acquainted  .  Let's  shall we all introduce ourselves ?",
#   "Hi I'm Chiara , I'm the um Marketing Expert . Um , would you like me to talk about my aims at the moment , or would you like me to just say my name and then we can talk about business later ?",
#   "I think we'll get around to that , yeah . So this is just introductions yeah .",
#   "We'll get round to that later . My name is Chiara and I'm the Marketing Expert .",
#   "Okay . I forgot to s say I'm the Project Manager but I figured you all knew that already ,",
#   '',
#   '',
#   ' um so .',
#   " I'm Stephanie and I am the User Interface Designer .",
#   "I'm Krista and I'm the Industrial Designer .",
#   "Okay . Um so f here's our agenda for today . Um we're gonna do some tool training , project plan and discuss then close .  Um so . So our aim is to produce a remote control that is original , trendy and user friendly . And to do this , we have to  um there's certain things we have to consider about functional aspects and conceptual design of the thing . So . We'll get to that . Oh there it is . Right . Functional design , conceptual design and detailed design . So throughout our next couple of meetings we'll we'll be covering these things . Um  so we're gonna try out our white board . If we'll all draw our favourite animal , to sum up the characteristics of that animal . Okay .",
#   'So you want us to draw it and then talk about it ? Or just draw it ?',
#   '',
#   'I think both . ',
#   'Yeah . Both . Yeah  .',
#   "Okay . Why don't we do both . Right .",
#   'Who starts ? We ought to decide who starts and  all that . No ?',
#   'Any volunteers ?',
#   'Uh-huh .',
#   'Does anyone know what they wanna draw ? ',
#   '',
#   'Mm , I gotta think about it for a second like . Uh  Does it have to be  functional , trendy and user friendly ? ',
#   " I don't think so .",
#   '',
#   "Um . Okay , I'll draw . I'll draw one .",
#   '',
#   'Make sure  my things here . Uh-oh . Right . Okay , my favourite animal is  see .  Oops .',
#   'A dolphin .',
#   "Yeah , it's  ",
#   '',
#   " 'S like playing Pictionary .",
#   " Yeah , I guess it has a fin on top too , yeah .  It's my dolphin .",
#   ' So what characteristics do you like about your animal ? ',
#   '',
#   'I like its tail .',
#   '',
#   " Um , no , I think dolphins are really uh  I dunno , they're smart and they they're cute and they like swimming and that's cool , like ",
#   " They're graceful .",
#   "they're graceful yeah , and they're so ",
#   'Sleek  .',
#   " Yeah they're sleek",
#   '',
#   "and they look intelligent and I don't know , they're  I guess it's the whole like binocular vision thing .",
#   "I don't know how intelligent that one looks  .",
#   '',
#   "Yeah he he doesn't look that smart  . He's a   I dunno um they're  I think it's cool the the um  the interaction that or the th things that  the reasons people seem to like you know  you get ex you know people are sitting on the beach and p they're like oh look there's dolphins and it's kinda like   but they're you know they jump around in the water and they're happy and they're mammals , but they swim .  ",
#   'Yes .  Does anybody else wanna draw their animal ?',
#   'Suppose I can draw an animal , yeah .',
#   '  .',
#   '',
#   'Uh-oh there goes the ten .',
#   ' Yeah .',
#   " It's a cat . ",
#   '',
#   "I don't know . They sleep all day ,  they're easy to draw  .",
#   ' Do you wanna  anything ?',
#   'Uh yeah .',
#   'I dunno if the the ',
#   'I think the pen is running out of ',
#   "Well I had the cat as well , but uh I've got a spare one .",
#   'ah .',
#   '',
#   '',
#   "So I'll use the spare one . Um but it's harder to draw  um .",
#   "And the pen's dying  .",
#   'Um .',
#   'A horse .',
#   'Horse .',
#   "Uh . Um I don't  really know how the legs go ,",
#   '',
#   "That's very good .",
#   '',
#   "but anyway I will do that . Um , and the main reason is they're pretty . I think they're very pretty and they go well with the environment , and I like the way they run and I used to do horse riding and they're just very sort of sturdy and nice animals . And I like the way um they feel , sort of under under the hand , I think that's pretty much it . Um ",
#   " Yeah . This cord's   Uh . Right . Actually I haven't thought of anything yet  . Uh  It's a pig .",
#   '',
#   '',
#   " So I'm thinking we should design a remote control that's water resistant , strong and furry . What do you think , yeah ? This is ",
#   'And furry .',
#   'yeah , well like a cat , you know , soft yeah .',
#   '',
#   'Textile  tactile ,  tactile remote control .',
#   '',
#   " Although  uh I'll just put there . Right .",
#   "You're dragging a  you have a tail  .",
#   " Oh my gosh , this is disastrous . Sorry about that .  Okay .  So moving on . Our selling price goal is twenty five Euro and profit aim is fifty million Euro . So I'm guessing that we're not actually in Scotland , we're in some European country  . Um , and we will hope to sell this internationally .",
#   "Sorry can you just say that  what's the  what are our price goals again ?",
#   'Um selling price is twenty five Euro . Profit aim fifty million Euro .',
#   'Okay .',
#   'How many should we sell then ?  Um , a lot ,',
#   'Anyone a mathematician ? ',
#   'two two two million ,  two mi no , more f four million .',
#   'Two million .',
#   'Four million . And it ',
#   '',
#   "well it's the profit so if a profit for each is twelve fifty , that'll do four million .",
#   'Oh , yeah .'],
#  ["So f that's a fifty percent um uh . Um , I don't know what these mean because I didn't actually make the slide-show . Experience with remote control . So I guess we have to reflect on our experiences with remote controls to decide what um we would like to see in a convenient , practical , nice remote control . Um so do we have any initial ideas for uh how this remote control should be designed or formatted or the the buttons it should have .",
#   'Um , I think one thing is that it should be easy to find',
#   '{vocalsound}',
#   'I was thinking that too .',
#   'bec yeah {vocalsound} bec',
#   'Yeah .',
#   'I think we should design something that has like a {disfmarker} so you can {disfmarker} like somehow like you {disfmarker} I mean you always know where your T_V_ is , so just have a call button ,',
#   '{vocalsound}',
#   "I've always wanted that ,",
#   'Yeah .',
#   'so like {vocalsound} you can push a button on your T_V_ {disfmarker}',
#   'Yeah , yeah yeah yeah yeah .',
#   'I mean you have it for the portable phone , so why not {disfmarker} yeah .',
#   'Yeah , yeah yeah yeah , so you should have a call button on your television to be able to find your remote control .',
#   "Yeah . And even I think a little light . Um or even a {disfmarker} maybe a vib a vibrating thing . I dunno but someth because it's usually under the sofa .",
#   '{vocalsound}',
#   'Yeah . Yeah .',
#   "In which case you're going to be l but if it has a sort of signal which isn't any sound {disfmarker}",
#   'Yeah .',
#   "I don't know if it's expensive maybe to {disfmarker}",
#   "I don't {disfmarker} yeah I mean it {disfmarker} but like I mean {disfmarker}",
#   'Maybe call is enough . But yeah .',
#   'just I mean like your phone even just has so {disfmarker} like it can vibrate , it can light up and make noise and I dunno {vocalsound}',
#   'Yeah yeah yeah . Yeah .',
#   'What if it had something like um just like a magnet on the back of it and you could {disfmarker} I mean j just to have some place to put it besides like a base . You know like a portable phone has a base ,',
#   'Yeah . Yeah , or if it had a {disfmarker} yeah .',
#   'like just to have a home for it .',
#   '{vocalsound}',
#   'Yeah yeah yeah yeah .',
#   'Yeah ,',
#   "{vocalsound} 'Cause people just stick it on top of their T_V_ , but the point of having a remote is not to have to walk over to the T_V_ , so {disfmarker}",
#   'I mean {disfmarker}',
#   "{vocalsound} Well that's why it's always in the couch .",
#   'Yeah .',
#   'Yeah {vocalsound} .',
#   'Yeah , in in the couch {vocalsound} .',
#   '{vocalsound}',
#   '{gap}',
#   "I dunno , it seems like though that that would be hard , 'cause you not you're not gonna be lazy anyway and {disfmarker}",
#   'Yeah . Maybe we should design couches that have the remote control in the side arm . {vocalsound}',
#   '{vocalsound} {vocalsound}',
#   'Yeah so we {disfmarker} {vocalsound} the project is now couches and remote controls .',
#   '{vocalsound} But even just a thing to attach it to the w you know if you had a thing , a pretty object attached to the wall . But that would really make it more expensive .',
#   'Yeah .',
#   "But it's only a plastic thing , r really , the thing on the wall .",
#   'Yeah .',
#   'Yeah .',
#   'Something like that .',
#   'Do you think it needs to be bigger to not lose , or does that not factor in ?',
#   'And the other thing is {disfmarker}',
#   'Bigger .',
#   'Not {disfmarker} well it needs to be sort of {disfmarker}',
#   'Like Hand hand held size , yeah .',
#   'Hand-sized .',
#   "Yeah . I don't think you need a {disfmarker}",
#   'Not not huge , but {vocalsound}',
#   '{vocalsound}',
#   "But definitely not {disfmarker} well I don't know .",
#   "It can't be that hard to put some kind of a noise on it .",
#   "No , it can't be , uh-uh .",
#   "No it really wouldn't be .",
#   'Huh .',
#   'Or like or like a light thing . You know . I dunno {vocalsound}',
#   '{vocalsound}',
#   '{vocalsound} Like spaceship .',
#   '. Yeah {vocalsound} . Or make it mobile so it runs around and comes come find you yeah {vocalsound} .',
#   '{vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   "That would be really {disfmarker} I'm sure we could do that for twenty five Euros a pop .",
#   'Little homing device . {vocalsound} {vocalsound} Um .',
#   '{vocalsound}',
#   '{vocalsound} Yeah {vocalsound} . Uh .',
#   'Okay . So what do we think this remote control should {disfmarker} Five minutes .',
#   'Oh dear .',
#   'Till the meeting {disfmarker} oh right . This is what we have left . Um , oh we just {gap}',
#   "I also think though that it shouldn't have too many buttons ,",
#   'Yeah , I agree .',
#   "'cause I hate that when they have too many buttons and {disfmarker}",
#   'Yeah .',
#   "{vocalsound} B_ button and the F_ button , they don't do anything .",
#   'Yeah , yeah yeah .',
#   "I mean I know it has to have enough functions but like , I don't know you , just have like eight thousand buttons and you're like , no , you never use half of them . So .",
#   'You {disfmarker} what if um may be a little fancy but what if it had like a little screen , so it has less buttons but it still has all the functions . Like the way a mobile phone does .',
#   'That would be cool .',
#   'Yeah .',
#   'Yeah . I mean it just seems like {disfmarker}',
#   'So you could like um {disfmarker} like if you have I dunno if you have satellite if you have a hundred channels , you can {disfmarker} the way you do it on your radio is that you uh {disfmarker}',
#   'yeah .',
#   'what do you call it {disfmarker}',
#   'Select . Uh .',
#   's y yeah but you can programme , so you can programme like your favourite channels , so like if you had a s',
#   'But , would you have the screen on the thing , or would you have it on the telly transmitting the screen .',
#   "That's something we could decide . Mm .",
#   'Because {disfmarker}',
#   'I guess they would go together somehow ? I dunno .',
#   "Because , I don't know if it's {disfmarker} {vocalsound} I think it's e expensive , if you have {disfmarker} if you use the telly screen , 'cause the telly's already a screen , then you can pro sort of have a programming function , really easy sort of arrow up and down , on the remote ,",
#   'Yeah . Yeah .',
#   'and then use the telly as a screen .',
#   'Right .',
#   'But um {disfmarker}',
#   "I'm thinking kind of {disfmarker}",
#   "But yeah for sure . Something like not {disfmarker} it's not on the button but it's telling you what to do ,",
#   'Yeah .',
#   'is that what you mean ?',
#   'Yeah .',
#   'Right . Mm .',
#   "Or like you h you see those you know people {disfmarker} I'm thinking of like celebrity cribs kind of things when like they have all those {disfmarker} these things that at their house you know {disfmarker} their their entire house is so electronic , and they have like this one master control that {disfmarker} and it's like a hand held like {disfmarker} turns on everything sort of control and it has like a screen and like {disfmarker} so I think it should be possible to have some kind of a screen , I don't know if {disfmarker} it must be {disfmarker} it would probably {disfmarker}",
#   'Yeah .',
#   'must be ex too expensive though t like I dunno .',
#   'Mm .',
#   "But like mobile phones have screens and they're cheap .",
#   "Yeah , yeah . Yeah that's true .",
#   'Yeah . I mean , we have to remember our budget is twelve point {disfmarker} twelve fifty for {disfmarker} to actually make the device .',
#   'Yeah .',
#   'Mm .',
#   "Um but it's something to think about , yeah .",
#   'Well , I guess we have to get to that later , yeah .',
#   "I mean we'll have to see how much that would be .",
#   '{vocalsound}',
#   "Or some {disfmarker} it i we can find out probably on the internet {vocalsound} how much it's {disfmarker}",
#   'Yeah .',
#   'Um . Yeah , and the other thing you said that thing about robust and water um {disfmarker}',
#   '{vocalsound}',
#   'What was the word ?',
#   'Furry .',
#   'Water resistant .',
#   'Oh I was just {disfmarker} {vocalsound}',
#   '{vocalsound}',
#   "No but it's {disfmarker} I thought , ah , spot on .",
#   '{vocalsound}',
#   'Good feel , tact tactile , good tactile feel ,',
#   'Yeah .',
#   "maybe something didn doesn't make your hands sweat lot .",
#   'Yeah . Mm , mm .',
#   "That's quite annoying .",
#   'Maybe um just like a simple thing to have a clip on it , like so you can clip it to your {disfmarker}',
#   'Yeah .',
#   "like that's another {disfmarker}"],
#  ["That's the same as uh on the top of it uh with the the round uh button .",
#   'Like this one .',
#   "But uh we don't uh we don't uh {disfmarker} we do think it's um well {disfmarker} what if with ease of use , w which prefers the {disfmarker} which the the customer of the user prefers .",
#   "It's important . Uh I think th this is device which which has a learning curve . Um novice users u use this device as uh normal users use uh a c a remote control . And after a while they start to develop uh some skills in the the voice recognition functions , and then they will not use this dial as often . But other users who are new to this device need something like that .",
#   'Okay .',
#   "They n they need to understand what {disfmarker} uh how to change channels and uh change the volume , so it's easier for them",
#   'Could could I see the scroll bar as uh as as a sort of shortcut ? A a and the voice recognition as well ,',
#   "Yeah , maybe so . Yes , it's {disfmarker}",
#   'th maybe you could uh could uh {disfmarker}',
#   "Well , it's it's it's another approach , it's more that our um {gap} . {vocalsound} There are there are many ways of doing uh things uh on such a device .",
#   '{vocalsound} Yeah .',
#   "It's it's quite easy .",
#   'Okay . Okay , good . And and the case is is rubber ?',
#   'Yes , rubber ?',
#   'And the buttons ?',
#   '{vocalsound} Plastic or rubber .',
#   '{vocalsound} There are plastic or rubber .',
#   'Well ,',
#   'Okay ,',
#   'yeah .',
#   'and uh the colouring ?',
#   'Uh yellow with uh',
#   '{gap} with with grey or black .',
#   'grey or black or something like that . Whatever cost uh cost uh the least . {vocalsound}',
#   '{vocalsound} Okay ,',
#   '{vocalsound}',
#   "we'll we'll come to that later . Um",
#   '{vocalsound}',
#   'okay . Anything else to add or {disfmarker}',
#   'No . {vocalsound} Uh maybe we should uh think about these buttons .',
#   'Yeah .',
#   '{vocalsound} But {disfmarker}',
#   'Well , you could use two of them to programme the um channels on the two channel button ,',
#   'Yes , but it {disfmarker}',
#   "'cause you have to assign two channel {disfmarker} new channels .",
#   'but these are tasks that are only executed once , I think .',
#   'M uh yeah .',
#   'Or not ?',
#   'M m but maybe you do want a programme button to uh for example activate the voice recognition , or train the voice voice recognition .',
#   'You {disfmarker}',
#   "Well okay . Okay , yeah , that's right . Or something li like that .",
#   'And a button for disabling the voice recognition .',
#   "Yeah al although by pressing the button for I n don't know two , three seconds , you could also say it {disfmarker} you'd disable it with a little beep and and {disfmarker}",
#   'Yes .',
#   'Yeah .',
#   "but o okay , that that's not really really important .",
#   "{vocalsound} That's the basic idea , yeah . Of our prototype ."],
#  ["That's the same as uh on the top of it uh with the the round uh button .",
#   'Like this one .',
#   "But uh we don't uh we don't uh  we do think it's um well  what if with ease of use , w which prefers the  which the the customer of the user prefers .",
#   "It's important . Uh I think th this is device which which has a learning curve . Um novice users u use this device as uh normal users use uh a c a remote control . And after a while they start to develop uh some skills in the the voice recognition functions , and then they will not use this dial as often . But other users who are new to this device need something like that .",
#   'Okay .',
#   "They n they need to understand what  uh how to change channels and uh change the volume , so it's easier for them",
#   'Could could I see the scroll bar as uh as as a sort of shortcut ? A a and the voice recognition as well ,',
#   "Yeah , maybe so . Yes , it's ",
#   'th maybe you could uh could uh ',
#   "Well , it's it's it's another approach , it's more that our um  .  There are there are many ways of doing uh things uh on such a device .",
#   ' Yeah .',
#   "It's it's quite easy .",
#   'Okay . Okay , good . And and the case is is rubber ?',
#   'Yes , rubber ?',
#   'And the buttons ?',
#   ' Plastic or rubber .',
#   ' There are plastic or rubber .',
#   'Well ,',
#   'Okay ,',
#   'yeah .',
#   'and uh the colouring ?',
#   'Uh yellow with uh',
#   ' with with grey or black .',
#   'grey or black or something like that . Whatever cost uh cost uh the least . ',
#   ' Okay ,',
#   '',
#   "we'll we'll come to that later . Um",
#   '',
#   'okay . Anything else to add or ',
#   'No .  Uh maybe we should uh think about these buttons .',
#   'Yeah .',
#   ' But ',
#   'Well , you could use two of them to programme the um channels on the two channel button ,',
#   'Yes , but it ',
#   "'cause you have to assign two channel  new channels .",
#   'but these are tasks that are only executed once , I think .',
#   'M uh yeah .',
#   'Or not ?',
#   'M m but maybe you do want a programme button to uh for example activate the voice recognition , or train the voice voice recognition .',
#   'You ',
#   "Well okay . Okay , yeah , that's right . Or something li like that .",
#   'And a button for disabling the voice recognition .',
#   "Yeah al although by pressing the button for I n don't know two , three seconds , you could also say it  you'd disable it with a little beep and and ",
#   'Yes .',
#   'Yeah .',
#   "but o okay , that that's not really really important .",
#   " That's the basic idea , yeah . Of our prototype ."],
#  ['The basic {disfmarker} okay . Okay . Um you thought of some evaluation crit criteria ?',
#   'Yes .',
#   'Okay .',
#   'Uh my name is not name',
#   '{vocalsound} You are nameless . {vocalsound}',
#   '{vocalsound}',
#   'but {disfmarker}',
#   '{vocalsound}',
#   'Uh well , I used the {gap} {disfmarker} the uh {gap} documents . And these uh were the most important criteria .',
#   '{vocalsound} Is it spongy ? {vocalsound}',
#   'It should be . {gap} {disfmarker} {vocalsound} yeah ,',
#   '{vocalsound}',
#   '{vocalsound}',
#   "that's uh how the fashion guys uh state it . Fancy look and feel . So {disfmarker}",
#   "So just walk through it step by step . I mean , is it fancy , everything {disfmarker} I believe uh I believe it's fancy . {vocalsound}",
#   'Uh well appar',
#   "I believe it's fancy too .",
#   "Yeah , but apparently uh we shouldn't evaluate yet .",
#   'No .',
#   'Oh , sorry .',
#   'So {disfmarker}',
#   'Okay , so',
#   'Okay .',
#   'this {disfmarker} these are the cr uh the criteria .',
#   'Yeah , I think these are the most important criteria .',
#   'Okay , well {disfmarker}',
#   'So uh',
#   "the then we'll switch to my presentation . Um {disfmarker}"],
#  ["That's the same as uh on the top of it uh with the the round uh button .",
#   'Like this one .',
#   "But uh we don't uh we don't uh  we do think it's um well  what if with ease of use , w which prefers the  which the the customer of the user prefers .",
#   "It's important . Uh I think th this is device which which has a learning curve . Um novice users u use this device as uh normal users use uh a c a remote control . And after a while they start to develop uh some skills in the the voice recognition functions , and then they will not use this dial as often . But other users who are new to this device need something like that .",
#   'Okay .',
#   "They n they need to understand what  uh how to change channels and uh change the volume , so it's easier for them",
#   'Could could I see the scroll bar as uh as as a sort of shortcut ? A a and the voice recognition as well ,',
#   "Yeah , maybe so . Yes , it's ",
#   'th maybe you could uh could uh ',
#   "Well , it's it's it's another approach , it's more that our um  .  There are there are many ways of doing uh things uh on such a device .",
#   ' Yeah .',
#   "It's it's quite easy .",
#   'Okay . Okay , good . And and the case is is rubber ?',
#   'Yes , rubber ?',
#   'And the buttons ?',
#   ' Plastic or rubber .',
#   ' There are plastic or rubber .',
#   'Well ,',
#   'Okay ,',
#   'yeah .',
#   'and uh the colouring ?',
#   'Uh yellow with uh',
#   ' with with grey or black .',
#   'grey or black or something like that . Whatever cost uh cost uh the least . ',
#   ' Okay ,',
#   '',
#   "we'll we'll come to that later . Um",
#   '',
#   'okay . Anything else to add or ',
#   'No .  Uh maybe we should uh think about these buttons .',
#   'Yeah .',
#   ' But ',
#   'Well , you could use two of them to programme the um channels on the two channel button ,',
#   'Yes , but it ',
#   "'cause you have to assign two channel  new channels .",
#   'but these are tasks that are only executed once , I think .',
#   'M uh yeah .',
#   'Or not ?',
#   'M m but maybe you do want a programme button to uh for example activate the voice recognition , or train the voice voice recognition .',
#   'You ',
#   "Well okay . Okay , yeah , that's right . Or something li like that .",
#   'And a button for disabling the voice recognition .',
#   "Yeah al although by pressing the button for I n don't know two , three seconds , you could also say it  you'd disable it with a little beep and and ",
#   'Yes .',
#   'Yeah .',
#   "but o okay , that that's not really really important .",
#   " That's the basic idea , yeah . Of our prototype .",
#   '',
#   'The basic  okay . Okay . Um you thought of some evaluation crit criteria ?',
#   'Yes .',
#   'Okay .',
#   'Uh my name is not name',
#   ' You are nameless . ',
#   '',
#   'but ',
#   '',
#   'Uh well , I used the   the uh  documents . And these uh were the most important criteria .',
#   ' Is it spongy ? ',
#   'It should be .    yeah ,',
#   '',
#   '',
#   "that's uh how the fashion guys uh state it . Fancy look and feel . So ",
#   "So just walk through it step by step . I mean , is it fancy , everything  I believe uh I believe it's fancy . ",
#   'Uh well appar',
#   "I believe it's fancy too .",
#   "Yeah , but apparently uh we shouldn't evaluate yet .",
#   'No .',
#   'Oh , sorry .',
#   'So ',
#   'Okay , so',
#   'Okay .',
#   'this  these are the cr uh the criteria .',
#   'Yeah , I think these are the most important criteria .',
#   'Okay , well ',
#   'So uh',
#   "the then we'll switch to my presentation . Um ",
#   "that's about it .",
#   'The production costs . The costs are not under  Can I   Um this is the ',
#   'Twenty two .',
#   "Yeah , it's it's w way above um uh above the the the twelve Euro fifty .",
#   'Yikes .',
#   'And what makes it very expensive is uh for example the solar cell . So I guess we should skip that ,',
#   "Well it's very expensive .",
#   "because it's not that important .",
#   'Okay .',
#   'Why does the price and and the s oh , one uh exa',
#   'Yeah , the the price , the the number of items and the the sum .',
#   'yeah . The number of uh  yeah .',
#   ' Okay .',
#   'Um well , this is what I would call our luxury model . Um if you would ',
#   'And and does it ',
#   'if you look at the uh w w w what we could do to make it more um  to make it  just between the twelve Euro fifty , um then I did the following changes . Twelve Euro forty cents I came up with by leaving out the solar cells , um by not using the voice recognition feature ,',
#   'Mm-hmm .',
#   "because it's uh it's a four Euro uh addition to the price .",
#   'Mm-hmm .',
#   'Um  Yeah , I believe  Uh , push-button , well   It makes it the thirteen  yeah . Push-buttons are  buttons are are not the most expensive , but do add extra cost .',
#   'Hmm .',
#   'So um  yeah , th this design is not um within our price model .',
#   'Okay .',
#   'Um ',
#   "But I'm afraid it's not complete . Because we use spec uh specic uh special materials , the last item . And you have not added one item there .",
#   'Yeah .',
#   "So it's c way too expensive .",
#   "It's still too expensive , yeah . Um ",
#   "But that's that's only for the buttons .",
#   'I I guess if we leave the  if we leave this one out , um ',
#   'So the button we can use plastic .',
#   'oh . ',
#   '',
#   'And uh maybe not use the special form .',
#   'And the pla uh  And a plastic b just plastic buttons , a plas uh instead of rubber .',
#   'But it ',
#   ' It becomes a very dull remote control , I know .',
#   'Yes .',
#   "But it's the board decision . Um  And um  yeah .",
#   "Well , b basically it   when when this is our only option , we should even consider changing the casing , because I think there's very little added value in uh an enhanced case with these dull functions .",
#   'Yeah . Yeah , I know . Maybe we should look at an  uh focus on another uh ',
#   'So  Type of m maybe another market segment .',
#   'Yeah , m uh maybe not not all that fancy , but just way way more easy uh uh um basic',
#   'Yeah .',
#   'and uh m maximise the profits',
#   'Yes .',
#   'and um ',
#   "That's  maybe that's better . ",
#   'Yeah .',
#   'Maybe we could uh  we should go for straight and simple ,',
#   'Yeah .',
#   "but that's not what uh has been asked .",
#   'I know , I know .',
#   "So we should kick the board's uh   Well ",
#   ' Yeah . Although I think we  yeah , but we could still make uh a remote control that ap uh um applies um more to young people uh by giving it another colour already .',
#   'Hmm .',
#   'Um so it is possible to make uh uh a device that attracts a little bit more to young people .',
#   'Yes .',
#   "Um but uh I agree it's it's not a fancy high-tech uh device . Definitely not , no .  It's not that innovative .",
#   '',
#   '',
#   'Or however you s pronounce that .',
#   'Yeah , too bad . ',
#   'Um so , okay .  Um  Oh ,',
#   '',
#   'this is the wrong one . So uh that means redesign .  We do not have the time o uh now to to redesign the product .',
#   'Mm-hmm .',
#   "Um  but we can evaluate the process and um uh uh the satisfaction on how things went . Um I'm not sure if we need to evaluate uh the device first . I guess ",
#   "Um well , since we're not gonna manufacture it anyway  ",
#   'Yeah . ',
#   '',
#   '',
#   "Yeah , that's true .",
#   "Well , maybe it's good to do it anyway , because if we evaluate it , we we can also determine if our objectives are good .",
#   'We l we can learn . Yeah . Yeah . I agree .',
#   'So '],
#  ['Is it fancy ? {vocalsound}',
#   'I d it is it is {disfmarker} {vocalsound}',
#   'Uh {disfmarker}',
#   '{vocalsound}',
#   'Yay . Is it ? Is it fancy ?',
#   'Yeah , I think so .',
#   'Um the yellow rubber , I think so .',
#   'I think so .',
#   '{vocalsound} You like the rubber , uh Roo . {vocalsound}',
#   "{vocalsound} I'm into it . {vocalsound}",
#   '{vocalsound}',
#   '{vocalsound}',
#   'So uh one ?',
#   'Yeah .',
#   "But it's not that fancy .",
#   "No , I'll I'll I'll give it a two .",
# ...
#   ' yeah maybe , maybe may',
#   'Yeah .',
#   '',
#   "it's the next prototype , maybe we cou",
#   ' Okay okay , okay .',
#   'S maybe we can change from th',
#   "Four . Maybe four , it's okay .",
#   'Four . Okay .',
#   'Four ? Easy to use , four .',
#   "I'll put four .",
#   'Gonna say four .',
#   'Four .',
#   "Yeah , four it's more reasonable .",
#   "Uh it's even easier to  maybe .",
#   'You can you can erase with this er yeah .',
#   'Ok',
#   'Okay .',
#   'Mm .',
#   "Yeah , four it's more reasonable , so . So it's nine ,",
#   'So , average ?',
#   'nine over three .',
#   'Three ?',
#   'Three ?',
#   'Trois . Three . ',
#   "Oh yeah , it's  .",
#   'Trois . ',
#   '',
#   'Okay , so ',
#   "It need maybe some wo further work , but it's ",
#   'Yeah , especially on the easy to use',
#   'Yeah , uh s yeah .',
#   'Yeah .',
#   'target .',
#   'Might  it might be fine .',
#   'So , th the project is accepted ?',
#   'Okay .',
#   'Yeah .',
#   'Yeah , b I think  ',
#   'But I d m I think that it will be good to do some more work to transform this into a pineapple .',
#   'Yeah , yeah .',
#   'Yeah .',
#   'If you re we really want to have a fruitful remote control . ',
#   'Yeah .',
#   '',
#   ' Okay .'],
#  ["That's the finance .",
#   "{vocalsound} Okay and we we had a project prototype presentation with the evaluation . So as we all agree to accept , under certain conditions , the prototype , we'll have look to the final sh financial view .",
#   'Yeah .',
#   'Mm . Okay .',
#   '{vocalsound} So we need to calculate the production cost . As I said in the first meeting we need to have so a remote control that would cost not more than twelve and point fifty Euros .',
#   'Mm-hmm .',
#   'Mm-hmm .',
#   "And if not {disfmarker} if it's not the case y you would have to redesign it .",
#   'Mm-hmm .',
#   'Oh yeah .',
#   'Yeah .',
#   'So , just have a look at the {disfmarker} okay here is the Excel sheet , so',
#   '{vocalsound}',
#   "so it has the energy source . We have hand dynamo . No , we don't use that .",
#   'No .',
#   'We have battery , right ?',
#   'Yeah , we have battery .',
#   "Kinetic , we don't have it , I suppose ,",
#   'No ,',
#   'but we have solar cells .',
#   'um solar cells , yeah .',
#   'Um , how many do y do you need , solar cells ? Do you think one would be enough , or {disfmarker} such as {vocalsound} as number of branches ?',
#   'Uh I think in each ball you have three {disfmarker}',
#   'Three ?',
#   'three uh yeah , three , yeah . Three {gap} three solar cells .',
#   'So , electronic . Single simple chip on print ? Just one would be necessary ?',
#   'S s simple , simple , yeah .',
#   'One ?',
#   'Yeah .',
#   'Zero for the others . And sample sensor , sample speaker . One ?',
#   'Mm . One maybe , yeah .',
#   'As we have voice recognition , I think .',
#   'Yeah yeah yeah .',
#   'So the case .',
#   'Is it {disfmarker}',
#   '{vocalsound} {vocalsound}',
#   'Is sh it {gap}',
#   'So we are all already nineteen .',
#   'Wooden . {vocalsound}',
#   '{vocalsound} {vocalsound} Okay ,',
#   '{vocalsound}',
#   'just keep on going , just to have an idea .',
#   'The solar cell is too expensive . {vocalsound}',
#   '{vocalsound}',
#   'Yeah . {vocalsound}',
#   "Is {disfmarker} Yes a wooden pl I and that's {disfmarker}",
#   'Well uh {disfmarker}',
#   "There's no wood , so plastic just only , I think .",
#   "yeah , but what what about case ? Uncurved , flat , single curved , double curved . I think it's more like double curved .",
#   "That's gonna be double curved , yeah .",
#   'Double curve , yeah , double curve .',
#   'One ?',
#   'One , you have .',
#   '{vocalsound} Uh wood ? {vocalsound}',
#   "But it's {disfmarker} yeah , a a rubber uh {disfmarker}",
#   'Rather four buttons .',
#   'Uh do we need special colour ?',
#   'Oh no , interface .',
#   'Y maybe , two ? We have two special colours .',
#   'Yeah , yeah . Y y yeah , yeah .',
#   "Yeah , yeah that's special colours , sure .",
#   'Push button .',
#   'Mm . Yeah , we have four .',
#   'Five ?',
#   '{vocalsound} Five . {vocalsound}',
#   'Okay . {vocalsound} Scroll wheel . We don no .',
#   'No .',
#   "It it's more like integrated scor .",
#   'I think that this will be like a scroll wheel , actually .',
#   'No no .',
#   "Yeah tha that's wheel .",
#   'Y you tu you turn you turn it , so {disfmarker}',
#   'No no no , it {disfmarker} {vocalsound} Okay .',
#   'Yeah , maybe two scroll wheel , as we have the coarse coarse to fine scroll wheel .',
#   'Yeah .',
#   'Yeah , true . Yeah , yeah . Yeah . Okay , yeah , yeah . Scr',
#   'So , no button supplements ?',
#   'I think the price is okay .',
#   'No .',
#   'Okay .',
#   'Um , no .',
#   'Okay we {disfmarker} I think we have problem . {vocalsound}',
#   'L_C_ display , maybe . Interface .',
#   'I think we s if we keep on adding things {disfmarker}',
#   "It's okay . {vocalsound} {gap} fine {gap} .",
#   'so we have to {disfmarker}',
#   'Yeah w one of the m key point is solar cells .',
#   'Maybe if w t if suppose if we change and we g put just one ?',
#   'Yeah .',
#   'Has it changed .',
#   '{vocalsound}',
#   'Yeah , it was stage one , so .',
#   'No y i it did change , but',
#   'Okay .',
#   'We have change the electronics to {disfmarker} from from the the the sample sensor to regular chip . Oh .',
#   'just imagine we have {disfmarker}',
#   'So {disfmarker}',
#   'We have to delete the the sample sensor , I think .',
#   'Yeah , but we have {disfmarker} you {disfmarker} the the voice recognition ,',
#   'Yeah .',
#   'no ?',
#   'Yeah but this one one of the feature we were not really {disfmarker}',
#   "Yeah it's the one it's {disfmarker}",
#   'Okay .',
#   'm maybe we ha we have two versions , the first version , the basic version .',
#   'I think you can transform the wood into plastic , maybe .',
#   'Advanced version we have speak .',
#   'Yeah .',
#   'Because uh it seems that this can be {disfmarker}',
#   'Yeah , if {disfmarker}',
#   'Or it would be better .',
#   'yeah , wood into plastic and it it should be fine .',
#   'Plastic is free . {vocalsound}',
#   'Yeah .',
#   '{vocalsound} So , do we need special colour ?',
#   "Yeah , that's one of the requirement .",
#   'Because we have red .',
#   'Yeah , red and yellow .',
#   'Red and yellow .',
#   'Wait .',
#   'Fancy .',
#   'We we can we can we c {vocalsound}',
#   'We could turn we could turn everything in either yellow or black .',
#   'yellow .',
#   'Black then is a regular colour , so .',
#   'I think so we need {disfmarker} if we try to have a kind of',
#   '{gap}',
#   'Yeah , one .',
#   'pineapple bee . {vocalsound}',
#   '{vocalsound}',
#   "Yeah . So push button then it's it's the next expensive one .",
#   'Yeah . An but we have integrated scroll wheel with push dut button . And I think this is one . Integrated scroll wheel push button',
#   'Yeah , thi this might be .',
#   ". So we'll {disfmarker} we have only one ? And push button .",
#   'Close to .',
#   "So if we have all integrated i in the scroll wheel and push button , it's uh {disfmarker}",
#   'One . I can remove maybe f you have five with push buttons , so we can just , I dunno , try to modify some of them to have {disfmarker} yeah .',
#   "Okay , so what's the bottleneck ?",
#   'How about we change the sale ?',
#   'Double curved .',
#   'Double curve . We can transform the double curve into single c yeah .',
#   'Something flat .',
#   'F some {disfmarker}',
#   'Yeah , but flat {disfmarker}',
#   'S uncurved . Yeah , maybe not .',
#   '{vocalsound} Single curve {gap} .',
#   "Case , what's the ca",
#   'Yeah .',
#   'Single curve should be fine , so . Oh , what {disfmarker} {vocalsound}',
#   'Mm . Nearly .',
#   'Ah we have one {disfmarker} {vocalsound}',
#   'And then one Euro left .',
#   '{vocalsound}',
#   'Um .',
#   "{vocalsound} Maybe don't bat no battery , only solar cells .",
#   "{vocalsound} It's it's a bad idea , so . {vocalsound}",
#   '{vocalsound}',
#   '{vocalsound} Um {disfmarker}',
#   "{vocalsound} I think there's a problem with the push push button . We only need maybe just one .",
#   '{vocalsound} Two ?',
#   'Just one .',
#   'One . {vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   '{vocalsound} Yeah .',
#   "That's fine . That's fine . {vocalsound}",
#   'Okay . Okay . {vocalsound} Agree .',
#   'So {vocalsound} yeah , you will have {disfmarker}',
#   'So we have one button ,',
#   '{gap} One s one scroll wheel , so',
#   'one wheel .',
#   'So one button , and s scroll wheel with push button on it .',
#   '{vocalsound}',
#   "{disfmarker} {vocalsound} And the vocal chord , it's fine . {gap} It I th it's fine .",
#   'So {disfmarker}',
#   "It's good they're not charging anything for that . {vocalsound}",
#   '{vocalsound}',
#   '{vocalsound}',
#   "So , yeah . It think we we've done good job , as the cost is",
#   'Cou could we have look {disfmarker}',
#   'twelve fifty e',
#   'Could we have look at the p the the prod the p the cost ?',
#   "Yeah y actually it's wrong . We're not under twelve Euros and a half .",
#   "{vocalsound} Yeah , but it's under or equal . It's not written . Sometimes it's under or equal .",
#   "It's fine . It's under or equal . It's fine , so {disfmarker}",
#   'Okay . Okay .',
#   '{vocalsound}',
#   "Okay . So let's say {disfmarker}",
#   'Twelve fifty .',
#   'Wha what {disfmarker}',
#   "It's fine , twelve fifty uh {disfmarker}",
#   'yeah . Which part is the most expensive part ? {vocalsound}',
#   'Solar cells .',
#   'Yeah , I think .',
#   'The solar cells , r is i is it ?',
#   "Yeah , I think it's not t t",
#   'I think , yeah . But it would i be interesting for our marketing team , to make a lot of advertisement concerning these solar cells to be {disfmarker}',
#   'Yeah , to be able to si to sell it .',
#   'Yeah .',
#   'Cheaper .',
#   "That's nice argument ,",
#   'Yeah , with mi',
#   "but if it's it's still four our of twelve .",
#   "It's {disfmarker} it is really really uh really very very expensive , though .",
#   'Yeah .',
#   'Maybe if uh {disfmarker} okay .',
#   'Yeah but it will be technologically innova innovative , so . {vocalsound}',
#   'Okay .',
#   'Yeah , yeah .',
#   'Yeah but we just have one button . {vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   "So it's easy to use and powerful , as the remote control a has only one button .",
#   "Easy . I don't know about powerful . Yeah .",
#   'Easy , powerful .',
#   "It's easy to use . It's very easy to use . {gap} {vocalsound}",
#   '{vocalsound}',
#   'Mm .',
#   "So I don't think we need to redesign the p the product .",
#   'No .',
#   "Uh that's what we've just done .",
#   "We've done it with {disfmarker} it is under the {disfmarker} if it was low , high or so .",
#   'Yeah .',
#   'Yeah .',
#   'So {disfmarker}',
#   'Um okay .',
#   'Now {disfmarker}',
#   'So {disfmarker} So what are we going to do with this project evaluation ?',
#   'So {disfmarker}',
#   'Well I think we have just have to discuss if {disfmarker}',
#   "Okay , okay , it's fine .",
#   'I dunno .',
#   'So did you enjoy your clay modelling ?',
#   'Yes . Of course . This is my job . {vocalsound}',
#   'Yeah ? {vocalsound} Was it a nice way to create your remote control ?',
#   '{vocalsound}',
#   "Yeah , it's uh it's good , to to create a control instead of a computer . {vocalsound}",
#   '{vocalsound}',
#   'Yeah , I think I find it really funny and amazing and interesting to go through all the process to {disfmarker} from the beginning to the end . And designing , looking at the chips , the solar cells and uh and it was very {vocalsound} informative for {gap} .',
#   'Yeah .',
#   'And for the marketing guy ?',
#   'Uh tha that was good but we should have more brainstorming like meetings , maybe .',
#   'Yep {vocalsound} .',
#   "'Cause we just presenting one is presenting his stuff",
#   'Okay .',
#   'next one his stuff and then we try to combine afterwards , so it {disfmarker} um .',
#   'Okay , okay .',
#   'And new ideas about new products , maybe , wi which would be fashion and uh and yellow . {vocalsound}',
#   '{vocalsound} Yellow . {vocalsound} I think you can think about a yellow T_V_ now after {disfmarker} {vocalsound} a fruit T_V_ or I dunno .',
#   '{vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   "It can be an interesting I don't know {disfmarker}",
#   'Yes , just lemon .',
#   "Yeah , just a lemon T_V_ it'd be {vocalsound} yellow lemon .",
#   "Yeah , but y you know the traditional T_V_ it's um {disfmarker}",
#   "It's flat , uh {disfmarker}",
#   "Yeah yeah it's flat ,",
#   'Squared ?',
#   'yeah the shape is very boring .',
#   "Yeah , that's right . It's really boring , yeah .",
#   'Could we come up with new T_V_ with {disfmarker} such as this kind of T_V_ ?',
#   'Yeah . {vocalsound}',
#   'So you can {disfmarker} {vocalsound} you have base , triangle base so you the T_V_ you can {disfmarker}',
#   '{vocalsound}',
#   '{vocalsound} Ah , the lemon T_V_ with the pineapple remote control .',
#   "{vocalsound} Yeah , that's {disfmarker} that would be really interesting , actually .",
#   'Yeah . Yeah . Because the T_V_ you {vocalsound} also {disfmarker}',
#   "Oh , that's interesting . You could f we could do a kind of fruit collection of electronics things . Electronic device .",
#   '{vocalsound} {gap} Device devi',
#   '{vocalsound} Yeah .',
#   "Yeah , but just don't trust too much the trends .",
#   'Yeah .',
#   'The fruit ? {vocalsound} Yeah .',
#   'Maybe {disfmarker}',
#   "'Cause fruit and vegetables it won't last for ten years uh .",
#   'Yeah , maybe la next year it will be insects .',
#   "Yeah , it's {disfmarker}",
#   "Maybe two years it's dead .",
#   '{vocalsound}',
#   'Yeah .',
#   "But I think it's good to follow the f flow and you know make it now and after , you know , if the people change their mind you change also the product .",
#   'Yeah .',
#   'Mm .',
#   "Yeah , but this is good because it's not a long long life product .",
#   'Yeah .',
#   'T_V_ is more like fifteen years , maybe , so .',
#   "Yeah , yeah . That's a {disfmarker} yeah , yeah .",
#   'If you have a lemon lemon T_V_ for',
#   'We can think about T_V_ with you know where you can change you know the aspects o like for the cell phones , you know .',
#   'fifteen years {disfmarker}',
#   'Customable T_V_ .',
#   'Yeah , you customise it every ti so every ti if people change , you just change the appearance , and y y you can keep {disfmarker}',
#   '{vocalsound}',
#   'Yeah , yeah .',
#   "Ah such {disfmarker} yeah . You've already said mobile phones .",
#   'Okay .',
#   'Tha that would that would make it . Yeah .',
#   'Yeah , you can keep the global appearan',
#   'Yeah , and following {disfmarker}',
#   'The mood of persons , the fashions uh {disfmarker}',
#   'Mm .',
#   'Yeah .',
#   "It's interesting , maybe we can create a a line of uh T_V_ with uh a a tr",
#   "We int {vocalsound} {vocalsound} {vocalsound} Yeah , T_V_ , yeah . A T_V_ for autumn and a T_V_ for winter , you know , so it's {disfmarker} {vocalsound}",
#   'Yeah . Yeah .',
#   '{vocalsound}',
#   '{vocalsound}',
#   'So what i and do w is it {vocalsound} {disfmarker} Okay .',
#   "So I think the costs are within the budget . We're just at twelve fifty Euros .",
#   'Yeah , the pr {gap} at {disfmarker}',
#   'Yep .',
#   'Yeah .',
#   'So',
#   '{vocalsound}',
#   '{vocalsound}',
#   '{vocalsound}',
#   'do you think you can celebrate your creation ?',
#   'And you can celebrate your leadership . {vocalsound}',
#   'Oh , thanks a lot . {vocalsound} Thank you , mister David Jordan . {vocalsound}',
#   "Yeah but I think f {vocalsound} it's really a celebrating object . {vocalsound} So it's yellow and very {disfmarker} a very ha it's very happy , so .",
#   '{vocalsound} Yeah .',
#   'Hmm .',
#   "Uh it's it's a pr it's like {disfmarker} yeah .",
#   "Yeah . It's party party remote control .",
#   'The thing now is to to sell it .',
#   '{vocalsound}',
#   "Yeah , it's your job . {vocalsound}",
#   '{vocalsound}',
#   '{vocalsound} Yeah ,',
#   '{vocalsound}',
#   'Sell it . {vocalsound}',
#   'right , go and sell it . Goo and good luck , so {disfmarker} {vocalsound}',
#   'Yeah . {vocalsound}',
#   'Yeah . Okay and the twelve fifty {disfmarker} twelve uh twelve {disfmarker}',
#   '{vocalsound}',
#   'Uh-huh . Twenty five Euros .',
#   'Twenty five Euros , yeah .',
#   '{vocalsound} It should be fine .',
#   "Yeah , I think it's {vocalsound} {disfmarker}",
#   "It's maybe a little bit expensive . {vocalsound}",
#   'Twenty five Euros .',
#   "It's cheap , yeah . {vocalsound} No , I {disfmarker}"]]
