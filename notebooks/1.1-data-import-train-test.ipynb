# %%
# Run if working locally
# %load_ext autoreload
# %autoreload 2
# %load_ext nb_black

# %%
import sqlite3
from sqlite3 import Error
import pickle
import os, sys
import config

config.root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, config.root_path)

from src.dataset.dataset import RawData
from src.dataset.qmsum_preprocessing import (
    tokenize,
    clean_sentence,
    preprocess_text_segmentation,
    format_data_for_db_insertion,
)

# %%
from db.dbv2 import Table, AugmentedTable, TrainTestTable

# %%
dataset_type = "product"
table = Table(dataset_type)
augmented_table = AugmentedTable(dataset_type)
train_test_table = TrainTestTable(dataset_type)
# Out:
# qmsum_product_train_test

# %%
train_test_table.create_train_test_split()

# %% [markdown]
# ## Testing other db functions

# %%
table.get_random_segments_pct(1)
# Out:
# [[(81201, 'time .', 1, None, 0),
#   (81202, 'thanks .', 0, 81201, 1),
#   (81203, 'are you fey ?', 0, 81201, 2),
#   (81204, 'i am fey , yeah .', 0, 81201, 3),
#   (81205, 'oh .', 0, 81201, 4),
#   (81206, 'what day is today ?', 0, 81201, 5),
#   (81207, 'hi .', 0, 81201, 6),
#   (81208,
#    "hi . i think we 've met before , like , i remember talking to you about aspect or something like that at some point or other .",
#    0,
#    81201,
#    7),
#   (81209, 'a couple times yeah .', 0, 81201, 8),
#   (81210, "it 's the uh twenty nineteenth .", 0, 81201, 9),
#   (81211, 'nineteenth ?', 0, 81201, 10),
#   (81212, "that 's right , yeah .", 0, 81201, 11),
#   (81213, 'so .', 0, 81201, 12),
#   (81214,
#    'and you were my gsi briefly , until i dropped the class .',
#    0,
#    81201,
#    13),
#   (81215, 'right , right .', 0, 81201, 14),
#   (81216, "oh that 's right .", 0, 81201, 15),
#   (81217, 'but .', 0, 81201, 16),
#   (81218, 'well .', 0, 81201, 17),
#   (81219, 'ok , wh wh', 0, 81201, 18),
#   (81220, 'no offense .', 0, 81201, 19),
#   (81221, 'yeah .', 0, 81201, 20),
#   (81222, 'like .', 0, 81201, 21),
#   (81223, 'ok . some in some introductions are in order .', 0, 81201, 22),
#   (81224, 'oh , ok sorry .', 0, 81201, 23),
#   (81225, 'ok .', 0, 81201, 24),
#   (81226, 'getting ahead of myself .', 0, 81201, 25),
#   (81227,
#    "so . um . for those who do n't know everyone knows me , this is great . um , apart from that , sort of the old gang , johno and bhaskara have been with us from from day one",
#    0,
#    81201,
#    26),
#   (81228, 'yay !', 0, 81201, 27),
#   (81229, 'hi .', 0, 81201, 28),
#   (81230,
#    "and um they 're engaged in in various activities , some of which you will hear about today . ami is um our counselor and spiritual guidance and um also interested in problems concerning reference of the more complex type ,",
#    0,
#    81201,
#    29),
#   (81231, 'well .', 0, 81201, 30),
#   (81232, 'oh wow .', 0, 81201, 31),
#   (81233,
#    'and um he sits in as a interested participant and helper . is that a good characterization ?',
#    0,
#    81201,
#    32),
#   (81234, "u that 's pretty good , i think .", 0, 81201, 33),
#   (81235, "i do n't know .", 0, 81201, 34),
#   (81236, 'yeah . thanks .', 0, 81201, 35),
#   (81237, 'ok . keith is not technically one of us yet ,', 0, 81201, 36),
#   (81238, 'not yet .', 0, 81201, 37),
#   (81239, "ha - ha . but um it 's too late for him now .", 0, 81201, 38),
#   (81240, '`` one of us . ``', 0, 81201, 39),
#   (81241, 'so .', 0, 81201, 40),
#   (81242, "yeah right . i 've got the headset on after all .", 0, 81201, 41),
#   (81243,
#    'um . officially i guess he will be joining us in the summer .',
#    0,
#    81201,
#    42),
#   (81244, 'yes .', 0, 81201, 43),
#   (81245,
#    "and um hopefully it is by by means of keith that we will be able to get a b a better formal and a better semantic um idea of what a construction is and um how we can make it work for us . additionally his interest um surpasses um english because it also entails german , an extra capability of speaking and writing and understanding and reading that language . and um , is there anyone who does n't know nancy ? do you do you know nancy ?",
#    0,
#    81201,
#    44),
#   (81246, 'me ?', 0, 81201, 45),
#   (81247, 'i know nancy .', 0, 81201, 46),
#   (81248, 'mm - hmm .', 0, 81201, 47),
#   (81249, 'i made that joke already , nancy , sadly .', 0, 81201, 48),
#   (81250, 'ok .', 0, 81201, 49),
#   (81251, 'what ?', 0, 81201, 50),
#   (81252, "the `` i do n't know myself `` joke .", 0, 81201, 51),
#   (81253, 'you did ? when ?', 0, 81201, 52),
#   (81254, 'uh before you came in .', 0, 81201, 53),
#   (81255, 'oh .', 0, 81201, 54),
#   (81256, 'man !', 0, 81201, 55),
#   (81257, 'about me or you ?', 0, 81201, 56),
#   (81258, 'about me .', 0, 81201, 57),
#   (81259, 'ok . ok .', 0, 81201, 58),
#   (81260, 'you could do it about you .', 0, 81201, 59),
#   (81261, 'yeah .', 0, 81201, 60),
#   (81262,
#    "well i did n't know . i did n't mean to be humor copying , but ok , sorry . yes , i know myself . it 's ok .",
#    0,
#    81201,
#    61),
#   (81263, 'ok .', 0, 81201, 62),
#   (81264, "it 's a", 0, 81201, 63),
#   (81265,
#    'and um fey is with us as of six days ago officially ?',
#    0,
#    81201,
#    64),
#   (81266, 'officially ,', 0, 81201, 65),
#   (81267, 'officially ,', 0, 81201, 66),
#   (81268, 'yeah .', 0, 81201, 67),
#   (81269,
#    "but in reality already um much much longer and um um next to some some more or less bureaucratic uh stuff with the the data collection she 's also the wizard in the data collection um ,",
#    0,
#    81201,
#    68),
#   (81270, 'of oz .', 0, 81201, 69),
#   (81271, "it 's very exciting .", 0, 81201, 70),
#   (81272, "we 're sticking with the term `` wizard `` ,", 0, 81201, 71),
#   (81273, 'yes .', 0, 81201, 72),
#   (81274, 'ok .', 0, 81201, 73),
#   (81275, 'yes .', 0, 81201, 74),
#   (81276, 'and um', 0, 81201, 75),
#   (81277, 'not witch - like .', 0, 81201, 76),
#   (81278, 'wizardette .', 0, 81201, 77),
#   (81279, 'wizard .', 0, 81201, 78),
#   (81280, 'wizardess .', 0, 81201, 79),
#   (81281, 'sorceress , i think .', 0, 81201, 80),
#   (81282, 'ok .', 0, 81201, 81),
#   (81283, 'wizard .', 0, 81201, 82),
#   (81284, 'wizard uh by by popular vote', 0, 81201, 83),
#   (81285, 'ok .', 0, 81201, 84),
#   (81286, 'um', 0, 81201, 85),
#   (81287, "did n't take a vote ? ok .", 0, 81201, 86),
#   (81288,
#    "ok , um , why do n't we get started on that subject anyways . um , so we 're about to collect data and um the uh s the following things have happened since we last met . when will we three meet again ? and um",
#    0,
#    81201,
#    87),
#   (81289, 'more than three of us .', 0, 81201, 88),
#   (81290,
#    "what happened is that um , `` a `` , { comment } there was some confusion between you and jerry with the that leading to your talking to catherine snow , and he was uh he he agreed completely that some something confusing happened . um his idea was to get sort of the l the lists of mayors of the department , the students . it it 's exactly how you interpreted it , sort of s",
#    0,
#    81201,
#    89),
#   (81291, 'the list of majors in the department ?', 0, 81201, 90),
#   (81292, 'm m majors ?', 0, 81201, 91),
#   (81293, 'ma - majors , majors .', 0, 81201, 92),
#   (81294, 'majors ?', 0, 81201, 93),
#   (81295, '`` mayors `` .', 0, 81201, 94),
#   (81296, 'ok , mayor', 0, 81201, 95),
#   (81297, 'majors .', 0, 81201, 96),
#   (81298, "something i do n't know about these", 0, 81201, 97),
#   (81299, 'the department has many mayors .', 0, 81201, 98),
#   (81300,
#    'majors and um just sending the the little write - up that we did on to those email lists',
#    0,
#    81201,
#    99),
#   (81301, 'ok . ok . yeah , yeah , yeah . but yeah .', 0, 81201, 100),
#   (81302, 'uh', 0, 81201, 101),
#   (81303,
#    'so it was really carol snow who was confused , not me and not jerry .',
#    0,
#    81201,
#    102),
#   (81304, 'yep , yep , yep . ok . so . so , that is uh', 0, 81201, 103),
#   (81305, "that 's good . so i should still do that .", 0, 81201, 104),
#   (81306, 'yep .', 0, 81201, 105),
#   (81307, 'ok .', 0, 81201, 106),
#   (81308, 'and', 0, 81201, 107),
#   (81309, 'and using the thing that you wrote up .', 0, 81201, 108),
#   (81310, 'yep .', 0, 81201, 109),
#   (81311, 'ok .', 0, 81201, 110),
#   (81312,
#    'wonderful . and um we have a little description of asking peop subjects to contact fey for you know recruiting them for our thing and um there was some confusion as to the consent form , which is basically that that what what you just signed',
#    0,
#    81201,
#    111),
#   (81313, 'right .', 0, 81201, 112),
#   (81314, 'and since we have one already um', 0, 81201, 113),
#   (81315,
#    "did jerry talk to you about maybe using our class ? the students in the undergrad class that he 's teaching ?",
#    0,
#    81201,
#    114),
#   (81316, 'um well he said um we definitely `` yes `` ,', 0, 81201, 115),
#   (81317, 'e', 0, 81201, 116),
#   (81318,
#    "however there is always more people in a in a facul uh in a department than are just taking his class or anybody else 's class at the moment",
#    0,
#    81201,
#    117),
#   (81319, 'yeah .', 0, 81201, 118),
#   (81320,
#    'and one should sort of reach out and try and get them all .',
#    0,
#    81201,
#    119),
#   (81321,
#    "ok , but th i guess it 's that um people in his class cover a different set so than the c is the cogsci department that you were talking about ?",
#    0,
#    81201,
#    120),
#   (81322, 'i guess . see', 0, 81201, 121),
#   (81323, 'uh reaching out to ?', 0, 81201, 122),
#   (81324,
#    "that 's what i suggested to him , that people like like jerry and george and et cetera just",
#    0,
#    81201,
#    123),
#   (81325, 'cuz we have you know people from other areas', 0, 81201, 124),
#   (81326, 'yeah .', 0, 81201, 125),
#   (81327, 'advertise in their classes as well .', 0, 81201, 126),
#   (81328,
#    'yeah or even i could you know i could do the actual',
#    0,
#    81201,
#    127),
#   (81329, 'mm - hmm .', 0, 81201, 128),
#   (81330, 'cuz i mean i i know how to contact our students ,', 0, 81201, 129),
#   (81331, "that 's generally the way it 's done .", 0, 81201, 130),
#   (81332,
#    "so if there 's something that you 're sending out you can also s um send me a copy ,",
#    0,
#    81201,
#    131),
#   (81333, 'yeah .', 0, 81201, 132),
#   (81334,
#    'me or bhaskara could either of us could post it to uh is it',
#    0,
#    81201,
#    133),
#   (81335, 'a mailing list .', 0, 81201, 134),
#   (81336,
#    "if it 's a general solicitation that you know is just contact you then we can totally pro post it to the news group",
#    0,
#    81201,
#    135),
#   (81337, 'mm - hmm . yeah .', 0, 81201, 136),
#   (81338, 'yeah .', 0, 81201, 137),
#   (81339, 'so .', 0, 81201, 138),
#   (81340, 'do it . yeah .', 0, 81201, 139),
#   (81341, "that 's", 0, 81201, 140),
#   (81342, "ok , so you 'll send it or something so .", 0, 81201, 141),
#   (81343, 'as a matter of fact , if you', 0, 81201, 142),
#   (81344, 'i can send it .', 0, 81201, 143),
#   (81345, 'if', 0, 81201, 144),
#   (81346, "i 'll send it ,", 0, 81201, 145),
#   (81347, 'you can send it to me .', 0, 81201, 146),
#   (81348, 'now , i', 0, 81201, 147),
#   (81349, 'yeah .', 0, 81201, 148),
#   (81350,
#    "ok . do n't worry , we this does n't concern you anymore , robert .",
#    0,
#    81201,
#    149),
#   (81351,
#    'how however i suggest that if you if you look at your email carefully you may think you may find that you already have it .',
#    0,
#    81201,
#    150),
#   (81352, "it 's fine . oops . already ? really ?", 0, 81201, 151),
#   (81353, 'maybe .', 0, 81201, 152),
#   (81354, 'probab', 0, 81201, 153),
#   (81355, 'oops .', 0, 81201, 154),
#   (81356, "ok . w we 'll see .", 0, 81201, 155),
#   (81357, "i do n't remember getting anything .", 0, 81201, 156),
#   (81358,
#    'anyhow , um the uh yeah , not only also we will talk about linguistics and of course computer science .',
#    0,
#    81201,
#    157),
#   (81359, 'mm - hmm .', 0, 81201, 158),
#   (81360,
#    'um and then , secondly , we had , you may remember , um the problem with the re - phrasing , that subject always re - phrase sort of the task that uh we gave them ,',
#    0,
#    81201,
#    159),
#   (81361, 'right .', 0, 81201, 160),
#   (81362,
#    "and so we had a meeting on friday talking about how to avoid that , and it proved finally fruitful in the sense that we came up with a new scenario for how to get the the subject m to really have intentions and sort of to act upon those , and um there the idea is now that next actually we we need to hire one more person to actually do that job because it it 's getting more complicated . so if you know anyone interested in in what i 'm about to describe , tell that person to to write a mail to me or jerry soon , fast . um the idea now is to sort of come up with a high level of sort of abstract tasks `` go shopping `` um `` take in uh a batch of art `` um `` visit do some sightseeing `` blah - blah - blah - blah - blah , sort of analogous to what fey has started in in in compiling compiling here and already she has already gone to the trouble of of anchoring it with specific um o { comment } um entities and real world places you will find in heidelberg . and um . so out of these f s these high level categories the subject can pick a couple , such as if if there is a cop uh a category in emptying your roll of film , the person can then decide `` ok , i wan na do that at this place `` , sort of make up their own itinerary a and and tasks and the person is not allowed to take sort of this h high level category list with them , but uh the person is able to take notes on a map that we will give him and the map will be a tourist 's sort of schematic representation with with symbols for the objects . and so , the person can maybe make a mental note that `` ah yeah i wanted to go shopping here `` and `` i wanted to maybe take a picture of that `` and `` maybe um eat here `` and then goes in and solves the task with the system , ie { comment } fey , and um and we 're gon na try out that any questions ?",
#    0,
#    81201,
#    161),
#   (81363,
#    "so um y you 'll have those say somewhere what their intention was so you still have the the nice thing about having data where you know what the actual intention was ?",
#    0,
#    81201,
#    162),
#   (81364, 'mm - hmm . yeah .', 0, 81201, 163),
#   (81365,
#    "but they will um there 's nothing that says you know `` these are the things you want to do `` so they 'll say `` well these are the things i want to do `` and right , so they 'll have a little bit more natural interaction ?",
#    0,
#    81201,
#    164),
#   (81366, 'hopefully .', 0, 81201, 165),
#   (81367, 'ok . mm - hmm .', 0, 81201, 166),
#   (81368,
#    "so they 'll be given this map , which means that they wo n't have to like ask the system for in for like high level information about where things are ?",
#    0,
#    81201,
#    167),
#   (81369,
#    "yeah it 's a schematic tourist map . so it 'll be uh i it 'll still require the that information and an",
#    0,
#    81201,
#    168),
#   (81370,
#    "it w it does n't have like streets on it that would allow them to figure out their way",
#    0,
#    81201,
#    169),
#   (81371, 'n not not not really the street network . nuh .', 0, 81201, 170),
#   (81372, 'ok .', 0, 81201, 171),
#   (81373,
#    "so you 're just saying like what part of town the things are in or whatever ?",
#    0,
#    81201,
#    172),
#   (81374,
#    'yeah a and um the map is more a means for them to have the buildings and their names and maybe some ma ma major streets and their names',
#    0,
#    81201,
#    173),
#   (81375, 'mm - hmm .', 0, 81201, 174),
#   (81376,
#    "and we want to maybe ask them , if you have get it sort of isolated street the the , whatever , `` river street `` , and they know that they have decided that , yes , that 's where they want to do this kind of action um that they have it with them and they can actually read them or sort of have the label for the object because it 's too hard to memorize all these st strange german names . and then we 're going to have another we 're gon na have w another trial run ie the first with that new setup tomorrow at two and we have a real interesting subject which is ron kay for who those who know him , he 's the founder of ici . so he 'll he 's around seven seventy years old , or something .",
#    0,
#    81201,
#    175),
#   (81377, "i did n't know he was the founder . that 's ok .", 0, 81201, 176),
#   (81378,
#    "and he also approached me and he offered to help um our project and he was more thinking about some high level thinking tasks and i said `` sure we need help you can come in as a subject `` and he said `` ok `` . so that 's what 's gon na happen , tomorrow , data .",
#    0,
#    81201,
#    177),
#   (81379, 'using this new new um plan ,', 0, 81201, 178),
#   (81380, 'new new set up .', 0, 81201, 179),
#   (81381, 'ok .', 0, 81201, 180),
#   (81382,
#    "yeah . which i 'll hopefully sort of scrape together t but , thanks to fey , we already have sort of a nice blueprint and i can work with that . questions ? comments on that ? if not , we can move on . no ? no more questions ?",
#    0,
#    81201,
#    181),
#   (81383, "i 'm not sure i totally understand this", 0, 81201, 182),
#   (81384, "so what 's the s this is what you made , fey ?", 0, 81201, 183),
#   (81385, 'hmm ?', 0, 81201, 184),
#   (81386,
#    "but i 'm not sure i totally understand everything that 's being talked about",
#    0,
#    81201,
#    185),
#   (81387,
#    "like so so it 's just based on like the materials you had about heidelberg .",
#    0,
#    81201,
#    186),
#   (81388,
#    'um are you familiar with with the with the very rough setup of the data ?',
#    0,
#    81201,
#    187),
#   (81389, "but i i imagine i 'll c just catch on .", 0, 81201, 188),
#   (81390, 'based on the web site , yeah , at the', 0, 81201, 189),
#   (81391, "oh ok there 's a web site", 0, 81201, 190),
#   (81392, 'experiment ?', 0, 81201, 191),
#   (81393, 'right .', 0, 81201, 192),
#   (81394,
#    'and then you could like um figure out what the cate',
#    0,
#    81201,
#    193),
#   (81395, "it 's a tourist information web site ,", 0, 81201, 194),
#   (81396, "uh , this is where they 're supposed to", 0, 81201, 195),
#   (81397, 'so .', 0, 81201, 196),
#   (81398, 'ok .', 0, 81201, 197),
#   (81399,
#    'talk to a machine and it breaks down and then the human comes on .',
#    0,
#    81201,
#    198),
#   (81400, 'ok .', 0, 81201, 199),
#   (81401, 'yeah . yeah .', 0, 81201, 200),
#   (81402,
#    'the question is just sort of how do we get the tasks in their head that they have an intention of doing something and have a need to ask the system for something without giving them sort of a clear wording or phrasing of the task .',
#    0,
#    81201,
#    201),
#   (81403, 'ok . ok . ok .', 0, 81201, 202),
#   (81404,
#    'because what will happen then is that people repeat repeat , { comment } or as much as they can , of that phrasing .',
#    0,
#    81201,
#    203),
#   (81405, 'ok .', 0, 81201, 204),
#   (81406,
#    'hmm . um , are you worried about being able to identify',
#    0,
#    81201,
#    205),
#   (81407, 'ok .', 0, 81201, 206),
#   (81408,
#    "um . the the goals that we 've d you guys have been talking about are this these you know identifying which of three modes um their question uh concerns .",
#    0,
#    81201,
#    207),
#   (81409, 'mm - hmm .', 0, 81201, 208),
#   (81410, "so it 's like the enter versus view", 0, 81201, 209),
#   (81411,
#    'yeah , we we we will sort of get a protocol of the prior interaction ,',
#    0,
#    81201,
#    210),
#   (81412, 'uh - huh .', 0, 81201, 211),
#   (81413,
#    "right ? that 's where the instructor , the person we are going to hire , um and the subjects sit down together with these high level things",
#    0,
#    81201,
#    212),
#   (81414, 'uh - huh . mm - hmm .', 0, 81201, 213),
#   (81415,
#    'and so th the q first question for the subject is , `` so these are things , you know , we thought a tourist can do . is there anything that interests you ? ``',
#    0,
#    81201,
#    214),
#   (81416, 'mm - hmm .', 0, 81201, 215),
#   (81417,
#    'and the person can say `` yeah , sure sh this is something i would do . i would go shopping `` . yeah ? and then we can sort of this s instructor can say `` well , uh then you you may want to find out how to get over here',
#    0,
#    81201,
#    216),
#   (81418, 'mm - hmm .', 0, 81201, 217),
#   (81419,
#    'because this is where the shopping district is `` .',
#    0,
#    81201,
#    218),
#   (81420,
#    'so the interaction beforehand will give them hints about how specific or how whatever though the kinds of questions that are going to ask during the actual session ?',
#    0,
#    81201,
#    219),
#   (81421,
#    'no . just sort of ok , what what what would you like to buy and then um ok there you wan na buy a whatever cuckoos clocks',
#    0,
#    81201,
#    220),
#   (81422, 'yeah .', 0, 81201, 221),
#   (81423, 'ok and the there is a store there .', 0, 81201, 222),
#   (81424, 'mm - hmm .', 0, 81201, 223),
#   (81425,
#    'so the task then for that person is t finding out how to get there , right ?',
#    0,
#    81201,
#    224),
#   (81426, 'mm - hmm .', 0, 81201, 225),
#   (81427, "that 's sort of what 's left .", 0, 81201, 226),
#   (81428, 'mm - hmm .', 0, 81201, 227),
#   (81429,
#    'and we know that the intention is to enter because we know that the person wants to buy a cuckoos clock .',
#    0,
#    81201,
#    228),
#   (81430,
#    "ok , that 's what i mean so like those tasks are all gon na be um unambiguous about which of the three modes .",
#    0,
#    81201,
#    229),
#   (81431, 'hopefully .', 0, 81201, 230),
#   (81432, 'right . ok . so .', 0, 81201, 231),
#   (81433,
#    'well , so the idea is to try to get the actual phrasing that they might use and try to interfere as little as possible with their choice of words .',
#    0,
#    81201,
#    232),
#   (81434, 'hopefully .', 0, 81201, 233),
#   (81435, "t that they 'll be here ?", 0, 81201, 234),
#   (81436,
#    "yes . in a sense that 's exactly the the the idea ,",
#    0,
#    81201,
#    235),
#   (81437, 'uh uh', 0, 81201, 236),
#   (81438,
#    'which is never possible in a in a s in a lab situation ,',
#    0,
#    81201,
#    237),
#   (81439,
#    "well , u u the one experiment th that that that i 've read somewhere , it was they u used pictures .",
#    0,
#    81201,
#    238),
#   (81440, 'nuh ?', 0, 81201, 239),
#   (81441, 'so to to uh actually um uh specify the the tasks .', 0, 81201, 240),
#   (81442, 'yep .', 0, 81201, 241),
#   (81443, 'mm - hmm .', 0, 81201, 242),
#   (81444, 'uh , but you know i i', 0, 81201, 243),
#   (81445,
#    "yeah . we had exactly that on our list of possible way things so we uh i even made a sort of a silly thing how that could work , how you control you are here you you want to know how to get someplace , and this is the place and it 's a museum and you want to do some and and and there 's a person looking at pictures . so , you know , this is exactly getting someplace with the intention of entering and looking at pictures .",
#    0,
#    81201,
#    244),
#   (81446, 'right .', 0, 81201, 245),
#   (81447,
#    "however , not only was the common census were among all participants of friday 's meeting was it 's gon na be very laborious to to make these drawings for each different things ,",
#    0,
#    81201,
#    246),
#   (81448, 'right .', 0, 81201, 247),
#   (81449,
#    "all the different actions , if at all possible , and also people will get caught up in the pictures . so all of a sudden we 'll get descriptions of pictures in there .",
#    0,
#    81201,
#    248),
#   (81450, 'right .', 0, 81201, 249),
#   (81451,
#    'and people talking about pictures and pictorial representations',
#    0,
#    81201,
#    250),
#   (81452, 'hmm .', 0, 81201, 251),
#   (81453, 'and um', 0, 81201, 252),
#   (81454, 'right .', 0, 81201, 253),
#   (81455, 'i would s i would still be willing to try it .', 0, 81201, 254),
#   (81456,
#    "i mean , i i 'm i 'm not saying it 's necessary but but uh i uh uh i you might be able to combine you know text uh and and some sort of picture and also uh i think it it will be a good idea to show them the text and kind of chew the task and then take the test away the the the the the text away",
#    0,
#    81201,
#    255),
#   (81457, 'mm - hmm . yeah .', 0, 81201, 256),
#   (81458,
#    'so that they are not uh guided by by by what you wrote ,',
#    0,
#    81201,
#    257),
#   (81459, 'we will', 0, 81201, 258),
#   (81460, 'but can come up with their with their own', 0, 81201, 259)],
#  [(13291, "alright . we 're on .", 1, None, 0),
#   (13292,
#    "test , um . test , test , test . guess that 's me . yeah . ok .",
#    0,
#    13291,
#    1),
#   (13293, 'ooh , thursday .', 0, 13291, 2),
#   (13294, "so . there 's two sheets of paper in front of us .", 0, 13291, 3),
#   (13295, 'what are these ?', 0, 13291, 4),
#   (13296, 'yeah . so .', 0, 13291, 5),
#   (13297, 'this is the arm wrestling ?', 0, 13291, 6),
#   (13298, 'uh . yeah , we formed a coalition actually .', 0, 13291, 7),
#   (13299, 'yeah . almost .', 0, 13291, 8),
#   (13300, 'we already made it into one .', 0, 13291, 9),
#   (13301, 'oh , good .', 0, 13291, 10),
#   (13302, 'yeah .', 0, 13291, 11),
#   (13303, 'excellent .', 0, 13291, 12),
#   (13304, 'yeah .', 0, 13291, 13),
#   (13305, "that 's the best thing .", 0, 13291, 14),
#   (13306, 'mm - hmm .', 0, 13291, 15),
#   (13307, 'so , tell me about it .', 0, 13291, 16),
#   (13308,
#    "so it 's well , it 's spectral subtraction or wiener filtering , um , depending on if we put if we square the transfer function or not .",
#    0,
#    13291,
#    17),
#   (13309, 'right .', 0, 13291, 18),
#   (13310,
#    'and then with over - estimation of the noise , depending on the , uh the snr , with smoothing along time , um , smoothing along frequency .',
#    0,
#    13291,
#    19),
#   (13311, 'mm - hmm .', 0, 13291, 20),
#   (13312, "it 's very simple , smoothing things .", 0, 13291, 21),
#   (13313, 'mm - hmm .', 0, 13291, 22),
#   (13314,
#    'and , um , the best result is when we apply this procedure on fft bins , uh , with a wiener filter .',
#    0,
#    13291,
#    23),
#   (13315, 'mm - hmm .', 0, 13291, 24),
#   (13316, 'and there is no noise addition after after that .', 0, 13291, 25),
#   (13317, 'ok .', 0, 13291, 26),
#   (13318,
#    "so it 's good because it 's difficult when we have to add noise to to to find the right level .",
#    0,
#    13291,
#    27),
#   (13319, 'ok .', 0, 13291, 28),
#   (13320,
#    'are you looking at one in in particular of these two ?',
#    0,
#    13291,
#    29),
#   (13321,
#    "yeah . so the sh it 's the sheet that gives fifty - f three point sixty - six .",
#    0,
#    13291,
#    30),
#   (13322, 'mm - hmm .', 0, 13291, 31),
#   (13323,
#    "um , the second sheet is abo uh , about the same . it 's the same , um , idea but it 's working on mel bands , and it 's a spectral subtraction instead of wiener filter , and there is also a noise addition after , uh , cleaning up the mel bins . mmm . well , the results are similar .",
#    0,
#    13291,
#    32),
#   (13324,
#    "yeah . i mean , it 's { comment } it 's actually , uh , very similar .",
#    0,
#    13291,
#    33),
#   (13325, 'mm - hmm .', 0, 13291, 34),
#   (13326,
#    'i mean , if you look at databases , uh , the , uh , one that has the smallest smaller overall number is actually better on the finnish and spanish , uh , but it is , uh , worse on the , uh , aurora',
#    0,
#    13291,
#    35),
#   (13327, "it 's worse on", 0, 13291, 36),
#   (13328, 'i mean on the , uh , ti - ti - digits ,', 0, 13291, 37),
#   (13329, 'on the multi - condition in ti - digits . yeah .', 0, 13291, 38),
#   (13330, 'uh , uh . um .', 0, 13291, 39),
#   (13331, 'mmm .', 0, 13291, 40),
#   (13332,
#    "so , it probably does n't matter that much either way . but , um , when you say u uh , unified do you mean , uh , it 's one piece of software now , or ?",
#    0,
#    13291,
#    41),
#   (13333, 'so now we are , yeah , setting up the software .', 0, 13291, 42),
#   (13334, 'mm - hmm .', 0, 13291, 43),
#   (13335,
#    'um , it should be ready , uh , very soon . um , and we',
#    0,
#    13291,
#    44),
#   (13336,
#    "so what 's what 's happened ? i think i 've missed something .",
#    0,
#    13291,
#    45),
#   (13337,
#    "ok . so a week ago maybe you were n't around when when when hynek and guenther and i ?",
#    0,
#    13291,
#    46),
#   (13338, 'hynek was here .', 0, 13291, 47),
#   (13339, "yeah . i did n't .", 0, 13291, 48),
#   (13340,
#    "oh , ok . so yeah , let 's summarize . um and then if i summarize somebody can tell me if i 'm wrong , which will also be possibly helpful . what did i just press here ? i hope this is still working .",
#    0,
#    13291,
#    49),
#   (13341, 'p - p - p', 0, 13291, 50),
#   (13342,
#    "we , uh we looked at , uh anyway we after coming back from qualcomm we had , you know , very strong feedback and , uh , i think it was hynek and guenter 's and my opinion also that , um , you know , we sort of spread out to look at a number of different ways of doing noise suppression . but given the limited time , uh , it was sort of time to choose one .",
#    0,
#    13291,
#    51),
#   (13343, 'mm - hmm . mmm .', 0, 13291, 52),
#   (13344,
#    "uh , and so , uh , th the vector taylor series had n't really worked out that much . uh , the subspace stuff , uh , had not been worked with so much . um , so it sort of came down to spectral subtraction versus wiener filtering .",
#    0,
#    13291,
#    53),
#   (13345, 'hmm .', 0, 13291, 54),
#   (13346,
#    'uh , we had a long discussion about how they were the same and how they were d uh , completely different .',
#    0,
#    13291,
#    55),
#   (13347, 'mm - hmm .', 0, 13291, 56),
#   (13348,
#    "and , uh , i mean , fundamentally they 're the same sort of thing but the math is a little different so that there 's a a there 's an exponent difference in the index you know , what 's the ideal filtering , and depending on how you construct the problem .",
#    0,
#    13291,
#    57),
#   (13349, 'uh - huh .', 0, 13291, 58),
#   (13350,
#    "and , uh , i guess it 's sort you know , after after that meeting it sort of made more sense to me because um , if you 're dealing with power spectra then how are you gon na choose your error ? and typically you 'll do choose something like a variance . and so that means it 'll be something like the square of the power spectra . whereas when you 're when you 're doing the the , uh , um , looking at it the other way , you 're gon na be dealing with signals",
#    0,
#    13291,
#    59),
#   (13351, 'mm - hmm .', 0, 13291, 60),
#   (13352,
#    "and you 're gon na end up looking at power uh , noise power that you 're trying to reduce . and so , eh so there should be a difference of you know , conceptually of of , uh , a factor of two in the exponent .",
#    0,
#    13291,
#    61),
#   (13353, 'mm - hmm .', 0, 13291, 62),
#   (13354,
#    "but there 're so many different little factors that you adjust in terms of of , uh , uh , over - subtraction and and and and and so forth , um , that arguably , you 're c and and and the choice of do you do you operate on the mel bands or do you operate on the fft beforehand . there 're so many other choices to make that are are almost well , if not independent , certainly in addition to the choice of whether you , uh , do spectral subtraction or wiener filtering , that , um , @ @ again we sort of felt the gang should just sort of figure out which it is they wan na do and then let 's pick it , go forward with it . so that 's that was that was last week . and and , uh , we said , uh , take a week , go arm wrestle , you know ,",
#    0,
#    13291,
#    63),
#   (13355, 'oh .', 0, 13291, 64),
#   (13356,
#    'figure it out . i mean , and th the joke there was that each of them had specialized in one of them .',
#    0,
#    13291,
#    65),
#   (13357, 'oh , ok .', 0, 13291, 66),
#   (13358,
#    "and and so they so instead they went to yosemite and bonded , and and they came out with a single single piece of software . so it 's another another victory for international collaboration . so .",
#    0,
#    13291,
#    67),
#   (13359,
#    "so so you guys have combined or you 're going to be combining the software ?",
#    0,
#    13291,
#    68),
#   (13360, 'uh .', 0, 13291, 69),
#   (13361,
#    'well , the piece of software has , like , plenty of options ,',
#    0,
#    13291,
#    70),
#   (13362, 'oh boy .', 0, 13291, 71),
#   (13363,
#    'like you can parse command - line arguments . so depending on that , it it becomes either spectral subtraction or wiener filtering .',
#    0,
#    13291,
#    72),
#   (13364, 'oh , ok .', 0, 13291, 73),
#   (13365, 'so , ye', 0, 13291, 74),
#   (13366, "they 're close enough .", 0, 13291, 75),
#   (13367,
#    "well , that 's fine , but the thing is the important thing is that there is a piece of software that you that we all will be using now .",
#    0,
#    13291,
#    76),
#   (13368, 'yeah . yeah .', 0, 13291, 77),
#   (13369, 'yes .', 0, 13291, 78),
#   (13370, "there 's just one piece of software .", 0, 13291, 79),
#   (13371, 'yeah .', 0, 13291, 80),
#   (13372, 'yeah .', 0, 13291, 81),
#   (13373,
#    'i need to allow it to do everything and even more more than this .',
#    0,
#    13291,
#    82),
#   (13374, 'right .', 0, 13291, 83),
#   (13375,
#    'well , if we want to , like , optimize different parameters of',
#    0,
#    13291,
#    84),
#   (13376, 'parameters . yeah .', 0, 13291, 85),
#   (13377, 'sure .', 0, 13291, 86),
#   (13378,
#    'yeah , we can do it later . but , still so , there will be a piece of software with , uh , will give this system , the fifty - three point sixty - six , by default and',
#    0,
#    13291,
#    87),
#   (13379, 'mm - hmm .', 0, 13291, 88),
#   (13380, 'how how is how good is that ?', 0, 13291, 89),
#   (13381, 'mm - hmm .', 0, 13291, 90),
#   (13382, "i i i do n't have a sense of", 0, 13291, 91),
#   (13383, "it 's just one percent off of the best proposal .", 0, 13291, 92),
#   (13384, 'best system .', 0, 13291, 93),
#   (13385,
#    "it 's between i we are second actually if we take this system .",
#    0,
#    13291,
#    94),
#   (13386, 'ok .', 0, 13291, 95),
#   (13387, 'yeah .', 0, 13291, 96),
#   (13388, 'yeah .', 0, 13291, 97),
#   (13389, 'right ?', 0, 13291, 98),
#   (13390, 'compared to the last evaluation numbers ? yeah .', 0, 13291, 99),
#   (13391, 'but , uh w which we sort of were before', 0, 13291, 100),
#   (13392, 'yeah .', 0, 13291, 101),
#   (13393, 'mm - hmm . yeah .', 0, 13291, 102),
#   (13394,
#    "but we were considerably far behind . and the thing is , this does n't have neural net in yet for instance . you know ?",
#    0,
#    13291,
#    103),
#   (13395, 'mm - hmm .', 0, 13291, 104),
#   (13396, 'hmm .', 0, 13291, 105),
#   (13397,
#    "so it so , um , it 's it it 's not using our full bal bag of tricks , if you will .",
#    0,
#    13291,
#    106),
#   (13398, 'mm - hmm .', 0, 13291, 107),
#   (13399,
#    "and , uh , and it it is , uh , very close in performance to the best thing that was there before . uh , but , you know , looking at it another way , maybe more importantly , uh , we did n't have any explicit noise , uh , handling stationary dealing with e e we did n't explicitly have anything to deal with stationary noise .",
#    0,
#    13291,
#    108),
#   (13400, 'mm - hmm .', 0, 13291, 109),
#   (13401, 'and now we do .', 0, 13291, 110),
#   (13402,
#    'so will the neural net operate on the output from either the wiener filtering or the spectral subtraction ? or will it operate on the original ?',
#    0,
#    13291,
#    111),
#   (13403,
#    'well , so so so argu arguably , i mean , what we should do i mean , i gather you have it sounds like you have a few more days of of nailing things down with the software and so on . but and then but , um , arguably what we should do is , even though the software can do many things , we should for now pick a set of things , th these things i would guess , and not change that .',
#    0,
#    13291,
#    112),
#   (13404, 'mm - hmm .', 0, 13291, 113),
#   (13405,
#    "and then focus on everything that 's left . and i think , you know , that our goal should be by next week , when hynek comes back , uh , to uh , really just to have a firm path , uh , for the you know , for the time he 's gone , of of , uh , what things will be attacked . but i would i would i would thought think that what we would wan na do is not futz with this stuff for a while because what 'll happen is we 'll change many other things in the system ,",
#    0,
#    13291,
#    114),
#   (13406, 'mm - hmm .', 0, 13291, 115),
#   (13407,
#    "and then we 'll probably wan na come back to this and possibly make some other choices . but , um .",
#    0,
#    13291,
#    116),
#   (13408,
#    'but just conceptually , where does the neural net go ? do do you wan na h run it on the output of the spectrally subtracted ?',
#    0,
#    13291,
#    117),
#   (13409, 'mmm .', 0, 13291, 118),
#   (13410,
#    "well , depending on its size well , one question is , is it on the , um , server side or is it on the terminal side ? uh , if it 's on the server side , it you probably do n't have to worry too much about size .",
#    0,
#    13291,
#    119),
#   (13411, 'mm - hmm .', 0, 13291, 120),
#   (13412,
#    "so that 's kind of an argument for that . we do still , however , have to consider its latency . so the issue is is , um , for instance , could we have a neural net that only looked at the past ?",
#    0,
#    13291,
#    121),
#   (13413, 'right .', 0, 13291, 122),
#   (13414,
#    "um , what we 've done in uh in the past is to use the neural net , uh , to transform , um , all of the features that we use . so this is done early on . this is essentially , um , um i guess it 's it 's more or less like a spee a speech enhancement technique here",
#    0,
#    13291,
#    123),
#   (13415, 'mm - hmm .', 0, 13291, 124),
#   (13416,
#    "right ? where we 're just kind of creating new if not new speech at least new new fft 's that that have you know , which could be turned into speech uh , that that have some of the noise removed .",
#    0,
#    13291,
#    125),
#   (13417, 'mm - hmm .', 0, 13291, 126),
#   (13418, 'mm - hmm .', 0, 13291, 127),
#   (13419,
#    'um , after that we still do a mess of other things to to produce a bunch of features .',
#    0,
#    13291,
#    128),
#   (13420, 'right .', 0, 13291, 129),
#   (13421,
#    'and then those features are not now currently transformed by the neural net . and then the the way that we had it in our proposal - two before , we had the neural net transformed features and we had the untransformed features , which i guess you you actually did linearly transform with the klt ,',
#    0,
#    13291,
#    130),
#   (13422, 'yeah . yeah . right .', 0, 13291, 131),
#   (13423,
#    "but but but uh , to orthogonalize them but but they were not , uh , processed through a neural net . and stephane 's idea with that , as i recall , was that you 'd have one part of the feature vector that was very discriminant and another part that was n't ,",
#    0,
#    13291,
#    132),
#   (13424, 'mm - hmm .', 0, 13291, 133),
#   (13425,
#    "uh , which would smooth things a bit for those occasions when , uh , the testing set was quite different than what you 'd trained your discriminant features for . so , um , all of that is is , uh still seems like a good idea . the thing is now we know some other constraints . we ca n't have unlimited amounts of latency . uh , y you know , that 's still being debated by the by people in europe but , uh , no matter how they end up there , it 's not going to be unlimited amounts ,",
#    0,
#    13291,
#    134),
#   (13426, 'yeah .', 0, 13291, 135),
#   (13427,
#    "so we have to be a little conscious of that . um . so there 's the neural net issue . there 's the vad issue . and , uh , there 's the second stream thing . and i think those that we last time we agreed that those are the three things that have to get , uh , focused on .",
#    0,
#    13291,
#    136),
#   (13428, 'what was the issue with the vad ?', 0, 13291, 137),
#   (13429, 'well , better { comment } ones are good .', 0, 13291, 138),
#   (13430,
#    "and so the w the default , uh , boundaries that they provide are they 're ok , but they 're not all that great ?",
#    0,
#    13291,
#    139),
#   (13431,
#    'i guess they still allow two hundred milliseconds on either side or some ? is that what the deal is ?',
#    0,
#    13291,
#    140),
#   (13432,
#    'mm - hmm . uh , so th um , they keep two hundred milliseconds at the beginning and end of speech . and they keep all the',
#    0,
#    13291,
#    141),
#   (13433, 'outside the beginnings and end .', 0, 13291, 142),
#   (13434, 'yeah .', 0, 13291, 143),
#   (13435, 'uh - huh .', 0, 13291, 144),
#   (13436,
#    'and all the speech pauses , which is sometimes on the speechdat - car you have pauses that are more than one or two seconds .',
#    0,
#    13291,
#    145),
#   (13437, 'wow .', 0, 13291, 146),
#   (13438, 'more than one second for sure . um .', 0, 13291, 147),
#   (13439, 'hmm .', 0, 13291, 148),
#   (13440,
#    'yeah . and , yeah , it seems to us that this way of just dropping the beginning and end is not we cou we can do better , i think ,',
#    0,
#    13291,
#    149),
#   (13441, 'mm - hmm .', 0, 13291, 150),
#   (13442,
#    'because , um , with this way of dropping the frames they improve over the baseline by fourteen percent and sunil already showed that with our current vad we can improve by more than twenty percent .',
#    0,
#    13291,
#    151),
#   (13443, 'on top of the vad that they provide ?', 0, 13291, 152),
#   (13444, 'no .', 0, 13291, 153),
#   (13445, 'just using either their vad or our current vad .', 0, 13291, 154),
#   (13446, 'our way .', 0, 13291, 155),
#   (13447, 'oh , ok .', 0, 13291, 156),
#   (13448,
#    'so , our current vad is is more than twenty percent , while their is fourteen .',
#    0,
#    13291,
#    157),
#   (13449, 'theirs is fourteen ? i see .', 0, 13291, 158),
#   (13450, 'yeah .', 0, 13291, 159),
#   (13451, 'huh .', 0, 13291, 160),
#   (13452,
#    "so . yeah . and another thing that we did also is that we have all this training data for let 's say , for speechdat - car . we have channel zero which is clean , channel one which is far - field microphone . and if we just take only the , um , vad probabilities computed on the clean signal and apply them on the far - field , uh , test utterances , then results are much better .",
#    0,
#    13291,
#    161),
#   (13453, 'mm - hmm .', 0, 13291, 162),
#   (13454, 'in some cases it divides the error rate by two .', 0, 13291, 163),
#   (13455, 'wow .', 0, 13291, 164),
#   (13456, 'so it means that there are stim { comment } still', 0, 13291, 165),
#   (13457,
#    'how how much latency does the , uh does our vad add ?',
#    0,
#    13291,
#    166),
#   (13458,
#    'if if we can have a good vad , well , it would be great .',
#    0,
#    13291,
#    167),
#   (13459, 'is it significant ,', 0, 13291, 168),
#   (13460,
#    "uh , right now it 's , um , a neural net with nine frames .",
#    0,
#    13291,
#    169),
#   (13461, 'or ?', 0, 13291, 170),
#   (13462,
#    "so it 's forty milliseconds plus , um , the rank ordering , which , uh , should be",
#    0,
#    13291,
#    171),
#   (13463, 'like another ten frames .', 0, 13291, 172),
#   (13464, 'ten yeah .', 0, 13291, 173),
#   (13465, 'rank . oh .', 0, 13291, 174),
#   (13466,
#    "so , right now it 's one hundred and forty milliseconds .",
#    0,
#    13291,
#    175),
#   (13467, "with the rank ordering ? i 'm sorry .", 0, 13291, 176),
#   (13468,
#    'the the the smoothing the m the the filtering of the probabilities .',
#    0,
#    13291,
#    177),
#   (13469, 'the the , um', 0, 13291, 178),
#   (13470, 'on the r .', 0, 13291, 179),
#   (13471,
#    "yeah . it 's not a median filtering . it 's just we do n't take the median value . we take something um , so we have eleven , um , frames .",
#    0,
#    13291,
#    180),
#   (13472, 'oh , this is for the vad .', 0, 13291, 181),
#   (13473, 'yeah .', 0, 13291, 182),
#   (13474, 'and for the vad , yeah', 0, 13291, 183),
#   (13475, 'oh , ok .', 0, 13291, 184),
#   (13476, 'yeah .', 0, 13291, 185),
#   (13477, 'and we take th the third .', 0, 13291, 186),
#   (13478, 'yeah .', 0, 13291, 187),
#   (13479, 'dar', 0, 13291, 188),
#   (13480, 'um .', 0, 13291, 189),
#   (13481,
#    'yeah . um . so { comment } yeah , i was just noticing on this that it makes reference to delay .',
#    0,
#    13291,
#    190),
#   (13482, 'mmm .', 0, 13291, 191),
#   (13483,
#    "so what 's the ? if you ignore um , the vad is sort of in in parallel , is n't i is n't it , with with the ? i mean , it is n't additive with the the , uh , lda and the wiener filtering , and so forth .",
#    0,
#    13291,
#    192),
#   (13484, 'the lda ?', 0, 13291, 193),
#   (13485, 'right ?', 0, 13291, 194),
#   (13486,
#    'yeah . so so what happened right now , we removed the delay of the lda .',
#    0,
#    13291,
#    195),
#   (13487, 'mm - hmm .', 0, 13291, 196),
#   (13488, 'yeah .', 0, 13291, 197),
#   (13489,
#    "so we i mean , if so if we if so which is like if we reduce the delay of va so , the f the final delay 's now ba is f determined by the delay of the vad , because the lda does n't have any delay . so if we re if we reduce the delay of the vad , i mean , it 's like effectively reducing the delay .",
#    0,
#    13291,
#    198),
#   (13490, 'how how much , uh , delay was there on the lda ?', 0, 13291, 199),
#   (13491,
#    'so the lda and the vad both had a hundred millisecond delay . so and they were in parallel , so which means you pick either one of them',
#    0,
#    13291,
#    200),
#   (13492, 'mmm .', 0, 13291, 201),
#   (13493, 'the the biggest , whatever .', 0, 13291, 202),
#   (13494, 'i see .', 0, 13291, 203),
#   (13495, 'mm - hmm .', 0, 13291, 204),
#   (13496, 'so , right now the lda delays are more .', 0, 13291, 205),
#   (13497, 'and there', 0, 13291, 206),
#   (13498, 'oh , ok .', 0, 13291, 207),
#   (13499,
#    "and there did n't seem to be any , uh , penalty for that ? there did n't seem to be any penalty for making it causal ?",
#    0,
#    13291,
#    208),
#   (13500,
#    'pardon ? oh , no . it actually made it , like , point one percent better or something , actually .',
#    0,
#    13291,
#    209),
#   (13501, 'ok . well , may as well , then .', 0, 13291, 210),
#   (13502, 'or something like that', 0, 13291, 211),
#   (13503,
#    'and he says wiener filter is is forty milliseconds delay .',
#    0,
#    13291,
#    212),
#   (13504, 'and', 0, 13291, 213),
#   (13505, 'so is it ?', 0, 13291, 214),
#   (13506,
#    "yeah . so that 's the one which stephane was discussing , like",
#    0,
#    13291,
#    215),
#   (13507, 'mmm .', 0, 13291, 216),
#   (13508, 'the smoothing ?', 0, 13291, 217),
#   (13509,
#    'yeah . the you smooth it and then delay the decision by so .',
#    0,
#    13291,
#    218),
#   (13510,
#    "right . ok . so that 's that 's really not not bad . so we may in fact we 'll see what they decide . we may in fact have , um , the the , uh , latency time available for to have a neural net . i mean , sounds like we probably will . so .",
#    0,
#    13291,
#    219),
#   (13511, 'mm - hmm .', 0, 13291, 220),
#   (13512,
#    "that 'd be good . cuz i cuz it certainly always helped us before . so .",
#    0,
#    13291,
#    221),
#   (13513,
#    'what amount of latency are you thinking about when you say that ?',
#    0,
#    13291,
#    222),
#   (13514,
#    "uh . well , they 're you know , they 're disputing it .",
#    0,
#    13291,
#    223),
#   (13515, 'mmm .', 0, 13291, 224),
#   (13516,
#    "you know , they 're saying , uh one group is saying a hundred and thirty milliseconds and another group is saying two hundred and fifty milliseconds . two hundred and fifty is what it was before actually . so ,",
#    0,
#    13291,
#    225),
#   (13517, 'oh .', 0, 13291, 226),
#   (13518,
#    'uh , some people are lobbying lobbying { comment } to make it shorter .',
#    0,
#    13291,
#    227),
#   (13519, 'hmm .', 0, 13291, 228),
#   (13520, 'um . and , um .', 0, 13291, 229),
#   (13521,
#    'were you thinking of the two - fifty or the one - thirty when you said we should have enough for the neural net ?',
#    0,
#    13291,
#    230),
#   (13522,
#    'well , it just it when we find that out it might change exactly how we do it , is all .',
#    0,
#    13291,
#    231),
#   (13523, 'oh , ok .', 0, 13291, 232),
#   (13524,
#    'i mean , how much effort do we put into making it causal ? i mean , i think the neural net will probably do better if it looks at a little bit of the future .',
#    0,
#    13291,
#    233),
#   (13525, 'mm - hmm .', 0, 13291, 234),
#   (13526,
#    "but , um , it will probably work to some extent to look only at the past . and we ha you know , limited machine and human time , and effort . and , you know , how how much time should we put into into that ? so it 'd be helpful if we find out from the the standards folks whether , you know , they 're gon na restrict that or not .",
#    0,
#    13291,
#    235),
#   (13527, 'mm - hmm .', 0, 13291, 236),
#   (13528,
#    "um . but i think , you know , at this point our major concern is making the performance better and and , um , if , uh , something has to take a little longer in latency in order to do it that 's you know , a secondary issue .",
#    0,
#    13291,
#    237),
#   (13529, 'mm - hmm .', 0, 13291, 238),
#   (13530,
#    'but if we get told otherwise then , you know , we may have to c clamp down a bit more .',
#    0,
#    13291,
#    239),
#   (13531, 'mmm .', 0, 13291, 240),
#   (13532,
#    'so , the one one one difference is that was there is like we tried computing the delta and then doing the frame - dropping .',
#    0,
#    13291,
#    241),
#   (13533, 's', 0, 13291, 242),
#   (13534, 'mm - hmm .', 0, 13291, 243),
#   (13535,
#    'the earlier system was do the frame - dropping and then compute the delta on the',
#    0,
#    13291,
#    244),
#   (13536, 'uh - huh .', 0, 13291, 245),
#   (13537, 'so this', 0, 13291, 246),
#   (13538, 'which could be a kind of a funny delta . right ?', 0, 13291, 247),
# ...
#    0,
#    61505,
#    559),
#   (62065,
#    'and and this this curves are the average over the whole database , so .',
#    0,
#    61505,
#    560),
#   (62066, 'yeah . right .', 0, 61505, 561),
#   (62067, 'mmm .', 0, 61505, 562),
#   (62068,
#    'um yeah , and the different points of the curves are for five uh , thresholds on the probability { comment } uh from point three to point seven .',
#    0,
#    61505,
#    563),
#   (62069, 'so that threshold', 0, 61505, 564),
#   (62070, 'mm - hmm . yeah .', 0, 61505, 565),
#   (62071, 'ok . s ok so d the detection threshold is very', 0, 61505, 566),
#   (62072, 'so the v', 0, 61505, 567),
#   (62073, 'yeah , yeah .', 0, 61505, 568),
#   (62074,
#    'the vad ? yeah . there first , a threshold on the probability { comment } @ @ { comment } that puts all the values to zero or one .',
#    0,
#    61505,
#    569),
#   (62075, 'mmm .', 0, 61505, 570),
#   (62076, 'and then the median filtering .', 0, 61505, 571),
#   (62077,
#    'yeah , so the median filtering is fixed . you just change the threshold ?',
#    0,
#    61505,
#    572),
#   (62078, "yeah . it 's fixed ,", 0, 61505, 573),
#   (62079, 'yeah .', 0, 61505, 574),
#   (62080,
#    "yeah . mm - hmm . so , going from channel zero to channel one , uh , almost double the error rate . um , yeah . well , so it 's a reference performance that we can you know , if we want to to work on the vad , { comment } we can work on this basis",
#    0,
#    61505,
#    575),
#   (62081, 'mm - hmm .', 0, 61505, 576),
#   (62082, 'and', 0, 61505, 577),
#   (62083, 'ok .', 0, 61505, 578),
#   (62084, 'is this is this vad a mlp ?', 0, 61505, 579),
#   (62085, 'yeah .', 0, 61505, 580),
#   (62086, 'ok . how how big is it ?', 0, 61505, 581),
#   (62087, "it 's a very big one . i do n't remember .", 0, 61505, 582),
#   (62088, 'so three three hundred and fifty inputs ,', 0, 61505, 583),
#   (62089, 'm', 0, 61505, 584),
#   (62090,
#    'uh , six thousand hidden nodes and two outputs . t t',
#    0,
#    61505,
#    585),
#   (62091, 'ok .', 0, 61505, 586),
#   (62092, 'yeah .', 0, 61505, 587),
#   (62093, 'mm - hmm .', 0, 61505, 588),
#   (62094, 'middle - sized one .', 0, 61505, 589),
#   (62095, 'yeah .', 0, 61505, 590),
#   (62096, 'mm - hmm .', 0, 61505, 591),
#   (62097,
#    "yeah . uh , ppp . i do n't know , you have questions about that , or suggestions ?",
#    0,
#    61505,
#    592),
#   (62098, 'mmm . s so', 0, 61505, 593),
#   (62099,
#    'it seems the performance seems worse in finnish , which',
#    0,
#    61505,
#    594),
#   (62100, "well , it 's not trained on finnish .", 0, 61505, 595),
#   (62101, 'uh', 0, 61505, 596),
#   (62102, "it 's worse .", 0, 61505, 597),
#   (62103, "it 's not trained on finnish , yeah .", 0, 61505, 598),
#   (62104, "what 's it trained on ?", 0, 61505, 599),
#   (62105, "i mean , the mlp 's not trained on finnish .", 0, 61505, 600),
#   (62106, "right , what 's it trained on ?", 0, 61505, 601),
#   (62107, "oh oh . sorry . uh , it 's italian ti - digits .", 0, 61505, 602),
#   (62108, "yeah . oh , it 's trained on italian ?", 0, 61505, 603),
#   (62109, 'yeah .', 0, 61505, 604),
#   (62110, 'yeah , ok .', 0, 61505, 605),
#   (62111, 'mm - hmm . and', 0, 61505, 606),
#   (62112, "that 's right .", 0, 61505, 607),
#   (62113, 'ok .', 0, 61505, 608),
#   (62114,
#    'and also there are like funny noises on finnish more than on italian . i mean , like music',
#    0,
#    61505,
#    609),
#   (62115, 'mm - hmm .', 0, 61505, 610),
#   (62116, "yeah . yeah , the yeah , it 's true .", 0, 61505, 611),
#   (62117,
#    "and um so , yeah , we were looking at this . but for most of the noises , noises are um , i do n't know if we want to talk about that . but , well , the the `` car `` noises are below like five hundred hertz . and we were looking at the `` music `` utterances and in this case the noise is more about two thousand hertz .",
#    0,
#    61505,
#    612),
#   (62118, 'yeah .', 0, 61505, 613),
#   (62119,
#    "well , the music energy 's very low apparently . uh , uh , from zero to two two thousand hertz . so maybe just looking at this frequency range for from five hundred to two thousand would improve somewhat the vad",
#    0,
#    61505,
#    614),
#   (62120, 'mmm .', 0, 61505, 615),
#   (62121, 'and', 0, 61505, 616),
#   (62122, 'yeah .', 0, 61505, 617),
#   (62123, 'mmm', 0, 61505, 618),
#   (62124,
#    'so there are like some some s some parameters you wanted to use or something ?',
#    0,
#    61505,
#    619),
#   (62125, 'yeah , but yes .', 0, 61505, 620),
#   (62126, 'or yeah .', 0, 61505, 621),
#   (62127, "mm - hmm . uh , the next , um oh , it 's there .", 0, 61505, 622),
#   (62128,
#    'so is the is the is the training is the training based on these labels files which you take as reference here ?',
#    0,
#    61505,
#    623),
#   (62129, 'yeah .', 0, 61505, 624),
#   (62130, 'wh - when you train the neural net y y you', 0, 61505, 625),
#   (62131,
#    "no . it 's not . it 's it was trained on some alignment obtained um , uh for the italian data , i think we trained the neural network on with embedded training . so re - estimation of the alignment using the neural network , i guess . that 's right ?",
#    0,
#    61505,
#    626),
#   (62132,
#    'yeah . we actually trained , uh , the on the italian training part .',
#    0,
#    61505,
#    627),
#   (62133, 'yeah .', 0, 61505, 628),
#   (62134, 'we we had another system with u', 0, 61505, 629),
#   (62135,
#    'so it was a f f a phonetic classification system for the italian aurora data .',
#    0,
#    61505,
#    630),
#   (62136, 'yeah . it must be somewhere . yeah .', 0, 61505, 631),
#   (62137,
#    'for the aurora data that it was trained on , it was different . like , for ti - digits you used a a previous system that you had , i guess .',
#    0,
#    61505,
#    632),
#   (62138, "what no it yeah , yeah . that 's true .", 0, 61505, 633),
#   (62139,
#    'so the alignments from the different database that are used for training came from different system .',
#    0,
#    61505,
#    634),
#   (62140, 'syste yeah .', 0, 61505, 635),
#   (62141,
#    'then we put them tog together . well , you put them together and trained the vad on them .',
#    0,
#    61505,
#    636),
#   (62142, 'yeah .', 0, 61505, 637),
#   (62143, 'mmm .', 0, 61505, 638),
#   (62144, 'yeah .', 0, 61505, 639),
#   (62145, 'hmm .', 0, 61505, 640),
#   (62146,
#    'uh , but did you use channel did you align channel one also ? or',
#    0,
#    61505,
#    641),
#   (62147, 'i just took their entire italian training part .', 0, 61505, 642),
#   (62148, 'yeah .', 0, 61505, 643),
#   (62149, 'so it was both channel zero plus channel one .', 0, 61505, 644),
#   (62150,
#    'so di yeah . so the alignments might be wrong then on channel one , right ?',
#    0,
#    61505,
#    645),
#   (62151, 'on one . possible .', 0, 61505, 646),
#   (62152, 'so we might ,', 0, 61505, 647),
#   (62153, 'we can do a realignment .', 0, 61505, 648),
#   (62154, 'yeah ,', 0, 61505, 649),
#   (62155, "that 's true .", 0, 61505, 650),
#   (62156,
#    'at least want to retrain on these alignments , which should be better because they come from close - talking microphone .',
#    0,
#    61505,
#    651),
#   (62157,
#    'yeah , the that was my idea . i mean , if if it ha if it is not the same labeling which is taking the spaces .',
#    0,
#    61505,
#    652),
#   (62158, 'yeah .', 0, 61505, 653),
#   (62159, 'ok .', 0, 61505, 654),
#   (62160, 'yeah , possible .', 0, 61505, 655),
#   (62161, 'yeah .', 0, 61505, 656),
#   (62162, 'mmm .', 0, 61505, 657),
#   (62163, 'i mean , it so the system', 0, 61505, 658),
#   (62164, 'yeah .', 0, 61505, 659),
#   (62165,
#    'so the vad was trained on maybe different set of labels for channel zero and channel one',
#    0,
#    61505,
#    660),
#   (62166, 'mm - hmm .', 0, 61505, 661),
#   (62167, 'and', 0, 61505, 662),
#   (62168, 'mm - hmm .', 0, 61505, 663),
#   (62169,
#    'was the alignments were w were different for s certainly different because they were independently trained .',
#    0,
#    61505,
#    664),
#   (62170, 'mm - hmm .', 0, 61505, 665),
#   (62171,
#    "we did n't copy the channel zero alignments to channel one .",
#    0,
#    61505,
#    666),
#   (62172, 'mm - hmm .', 0, 61505, 667),
#   (62173, 'mm - hmm .', 0, 61505, 668),
#   (62174, 'yeah .', 0, 61505, 669),
#   (62175, 'yeah .', 0, 61505, 670),
#   (62176,
#    'but for the new alignments what you generated , you just copied the channel zero to channel one , right ? yeah .',
#    0,
#    61505,
#    671),
#   (62177,
#    "right . yeah . um . and eh , hhh actually when we look at at the vad , for some utterances it 's almost perfect , i mean , it just dropped one frame , the first frame of speech or so there are some utterances where it 's almost one hundred percent vad performance .",
#    0,
#    61505,
#    672),
#   (62178, 'hmm .', 0, 61505, 673),
#   (62179,
#    "uh , but yeah . mmm yep . so the next thing is um , i have the spreadsheet for three different system . but for this you only have to look right now on the speechdat - car performance uh , because i did n't test so i did n't test the spectral subtraction on ti - digits yet . uh , so you have three she sheets . one is the um proposal - one system . actually , it 's not exe exactly proposal - one . it 's the system that sunil just described . um , but with uh , wiener filtering from um , france telecom included . um , so this gives like fifty - seven point seven percent , uh , s uh , error rate reduction on the speechdat - car data . mmm , and then i have two sheets where it 's for a system where uh , so it 's again the same system . but in this case we have spectral subtraction with a maximum overestimation factor of two point five . uh , there is smoothing of the gain trajectory with some kind of uh , low - pass filter , which has forty milliseconds latency . and then , after subtraction um , i add a constant to the energies and i have two cases d where the first case is where the constant is twenty - five db below the mean speech energy and the other is thirty db below . um , and for these s two system we have like fifty - five point , uh , five - percent improvement , and fifty - eight point one . so again , it 's around fifty - six , fifty - seven . uh",
#    0,
#    61505,
#    674),
#   (62180,
#    'cuz i notice the ti - digits number is exactly the same for these last two ?',
#    0,
#    61505,
#    675),
#   (62181,
#    "yeah , because i did n't for the france telecom uh , spectral subtraction included in the our system , the ti - digits number are the right one , but not for the other system because i did n't test it yet this system , including with spectral subtraction on the ti - digits data . i just tested it on speechdat - car .",
#    0,
#    61505,
#    676),
#   (62182, 'ah ! so so that means the only thing', 0, 61505, 677),
#   (62183, 'mm - hmm . so so so these numbers are simply', 0, 61505, 678),
#   (62184, 'this , we have to yeah .', 0, 61505, 679),
#   (62185, 'but this number .', 0, 61505, 680),
#   (62186, 'yeah .', 0, 61505, 681),
#   (62187, 'yeah .', 0, 61505, 682),
#   (62188,
#    'so you so you just should look at that fifty - eight perc point o nine percent and so on .',
#    0,
#    61505,
#    683),
#   (62189, 'yes .', 0, 61505, 684),
#   (62190, 'ok .', 0, 61505, 685),
#   (62191, 'right . right .', 0, 61505, 686),
#   (62192, 'ok . good .', 0, 61505, 687),
#   (62193, 'mm - hmm . um , yeah .', 0, 61505, 688),
#   (62194,
#    "so this so by uh , by by reducing the noise a a decent threshold like minus thirty db , it 's like uh , you are like r r reducing the floor of the noisy regions , right ?",
#    0,
#    61505,
#    689),
#   (62195, 's', 0, 61505, 690),
#   (62196, 'yeah . yeah . the floor is lower . um ,', 0, 61505, 691),
#   (62197, 'uh - huh .', 0, 61505, 692),
#   (62198, 'mm - hmm .', 0, 61505, 693),
#   (62199,
#    "i 'm sorry . so when you say minus twenty - five or minus thirty db , with respect to what ?",
#    0,
#    61505,
#    694),
#   (62200,
#    'to the average um , speech energy which is estimated on the world database .',
#    0,
#    61505,
#    695),
#   (62201,
#    "ok , so basically you 're creating a signal - to - noise ratio of twenty - five or thirty db ?",
#    0,
#    61505,
#    696),
#   (62202, 'yeah .', 0, 61505, 697),
#   (62203, 'uh r', 0, 61505, 698),
#   (62204, "but it 's not", 0, 61505, 699),
#   (62205, 'i i i think what you do is this .', 0, 61505, 700),
#   (62206, "it it 's", 0, 61505, 701),
#   (62207,
#    'i when when you have this , after you subtracted it , i mean , then you get something w w with this , uh , where you set the values to zero and then you simply add an additive constant again .',
#    0,
#    61505,
#    702),
#   (62208, 'yeah .', 0, 61505, 703),
#   (62209,
#    'so you shift it somehow . this this whole curve is shifted again .',
#    0,
#    61505,
#    704),
#   (62210,
#    'but did you do that before the thresholding to zero ,',
#    0,
#    61505,
#    705),
#   (62211, "right . it 's", 0, 61505, 706),
#   (62212, 'or ?', 0, 61505, 707),
#   (62213, "but , it 's after the thresholding .", 0, 61505, 708),
#   (62214, 'oh ,', 0, 61505, 709),
#   (62215, 'so ,', 0, 61505, 710),
#   (62216, "so you 'd really want to do it before ,", 0, 61505, 711),
#   (62217, 'maybe', 0, 61505, 712),
#   (62218, 'right ?', 0, 61505, 713),
#   (62219, 'maybe we might do it before ,', 0, 61505, 714),
#   (62220,
#    'yeah , because then the then you would have less of that phenomenon .',
#    0,
#    61505,
#    715),
#   (62221, 'yeah . yeah .', 0, 61505, 716),
#   (62222, 'i think .', 0, 61505, 717),
#   (62223, 'uh', 0, 61505, 718),
#   (62224, 'e hhh .', 0, 61505, 719),
#   (62225, 'yeah .', 0, 61505, 720),
#   (62226, 'c', 0, 61505, 721),
#   (62227,
#    'but still , when you do this and you take the log after that , it it reduce the the variance .',
#    0,
#    61505,
#    722),
#   (62228, 'yeah , it it right .', 0, 61505, 723),
#   (62229, 'but mmm ,', 0, 61505, 724),
#   (62230,
#    "yeah , that will reduce the variance . that 'll help . but maybe if you does do it before you get less of these funny - looking things he 's drawing .",
#    0,
#    61505,
#    725),
#   (62231, 'mm - hmm .', 0, 61505, 726),
#   (62232, 'um ,', 0, 61505, 727),
#   (62233,
#    "so before it 's like adding this , col to the to the o exi original",
#    0,
#    61505,
#    728),
#   (62234, 'but but', 0, 61505, 729),
#   (62235, 'we would', 0, 61505, 730),
#   (62236,
#    "right at the point where you 've done the subtraction .",
#    0,
#    61505,
#    731),
#   (62237, 'ok .', 0, 61505, 732),
#   (62238,
#    "um , essentially you 're adding a constant into everything .",
#    0,
#    61505,
#    733),
#   (62239, 'mm - hmm .', 0, 61505, 734),
#   (62240,
#    'but the way stephane did it , it is exactly the way i have implemented in the phone , so .',
#    0,
#    61505,
#    735),
#   (62241, 'oh , yeah , better do it different , then . yeah .', 0, 61505, 736),
#   (62242, 'um .', 0, 61505, 737),
#   (62243,
#    'just you you just ta you just set it for a particular signal - to - noise ratio that you want ?',
#    0,
#    61505,
#    738),
#   (62244, 'yeah .', 0, 61505, 739),
#   (62245,
#    'yeah i i made s similar investigations like stephane did here , just uh , adding this constant and and looking how dependent is it on the value of the constant',
#    0,
#    61505,
#    740),
#   (62246, 'yeah . yeah .', 0, 61505, 741),
#   (62247, 'mm - hmm .', 0, 61505, 742),
#   (62248,
#    'and then , must choose them somehow to give on average the best results for a certain range of the signal - to - noise ratios .',
#    0,
#    61505,
#    743),
#   (62249, 'uh - huh .', 0, 61505, 744),
#   (62250, 'yeah . mm - hmm .', 0, 61505, 745),
#   (62251, 'so', 0, 61505, 746)]]

# %%
table.get_target_sentence_ids("train")
# Out:
# [(163, 57673, 'train'),
#  (236, 1312, 'train'),
#  (46, 48734, 'train'),
#  (7, 29217, 'train'),
#  (153, 23393, 'train'),
#  (166, 21460, 'train'),
#  (82, 30709, 'train'),
#  (11, 27099, 'train'),
#  (19, 73686, 'train'),
#  (238, 46111, 'train'),
#  (47, 71691, 'train'),
#  (171, 21855, 'train'),
#  (140, 66124, 'train'),
#  (122, 46950, 'train'),
#  (192, 80476, 'train'),
#  (10, 64777, 'train'),
#  (42, 74448, 'train'),
#  (56, 24701, 'train'),
#  (142, 57154, 'train'),
#  (155, 1200, 'train'),
#  (66, 34105, 'train'),
#  (88, 26728, 'train'),
#  (95, 65282, 'train'),
#  (170, 29, 'train'),
#  (196, 62252, 'train'),
#  (81, 38415, 'train'),
#  (177, 58855, 'train'),
#  (4, 17904, 'train'),
#  (93, 59645, 'train'),
#  (235, 26867, 'train'),
#  (38, 30671, 'train'),
#  (18, 33008, 'train'),
#  (31, 75561, 'train'),
#  (145, 8803, 'train'),
#  (75, 81461, 'train'),
#  (139, 62714, 'train'),
#  (225, 65453, 'train'),
#  (221, 30892, 'train'),
#  (207, 65624, 'train'),
#  (112, 14567, 'train'),
#  (102, 39591, 'train'),
#  (162, 68245, 'train'),
#  (233, 5076, 'train'),
#  (200, 57274, 'train'),
#  (59, 15986, 'train'),
#  (152, 12882, 'train'),
#  (109, 57568, 'train'),
#  (199, 56257, 'train'),
#  (25, 83161, 'train'),
#  (213, 60231, 'train'),
#  (121, 21652, 'train'),
#  (150, 19984, 'train'),
#  (228, 41292, 'train'),
#  (191, 47752, 'train'),
#  (92, 24607, 'train'),
#  (45, 37177, 'train'),
#  (190, 84444, 'train'),
#  (135, 16646, 'train'),
#  (103, 26640, 'train'),
#  (180, 6155, 'train'),
#  (6, 39182, 'train'),
#  (13, 50391, 'train'),
#  (70, 79669, 'train'),
#  (181, 14779, 'train'),
#  (35, 14673, 'train'),
#  (130, 12887, 'train'),
#  (136, 31905, 'train'),
#  (198, 41595, 'train'),
#  (79, 21503, 'train'),
#  (28, 15607, 'train'),
#  (57, 31511, 'train'),
#  (110, 19268, 'train'),
#  (9, 36650, 'train'),
#  (205, 69312, 'train'),
#  (222, 63416, 'train'),
#  (185, 57951, 'train'),
#  (115, 67297, 'train'),
#  (2, 35100, 'train'),
#  (52, 76246, 'train'),
#  (168, 50113, 'train'),
#  (158, 32510, 'train'),
#  (1, 47991, 'train'),
#  (107, 63005, 'train'),
#  (126, 22210, 'train'),
#  (5, 13543, 'train'),
#  (113, 30748, 'train'),
#  (104, 83246, 'train'),
#  (50, 53893, 'train'),
#  (183, 3631, 'train'),
#  (143, 64217, 'train'),
#  (53, 65223, 'train'),
#  (234, 15228, 'train'),
#  (141, 84699, 'train'),
#  (40, 75211, 'train'),
#  (229, 51730, 'train'),
#  (84, 13984, 'train'),
#  (71, 70368, 'train'),
#  (154, 55714, 'train'),
#  (20, 55148, 'train'),
#  (32, 3170, 'train'),
#  (83, 17799, 'train'),
#  (8, 63594, 'train'),
#  (172, 62595, 'train'),
#  (60, 25092, 'train'),
#  (193, 76578, 'train'),
#  (209, 26913, 'train'),
#  (43, 25484, 'train'),
#  (157, 40897, 'train'),
#  (227, 27516, 'train'),
#  (123, 80805, 'train'),
#  (159, 84292, 'train'),
#  (68, 4484, 'train'),
#  (77, 53070, 'train'),
#  (210, 22905, 'train'),
#  (41, 70221, 'train'),
#  (129, 75749, 'train'),
#  (144, 3893, 'train'),
#  (214, 84533, 'train'),
#  (3, 56705, 'train'),
#  (69, 600, 'train'),
#  (167, 13156, 'train'),
#  (51, 27428, 'train'),
#  (100, 78884, 'train'),
#  (99, 30228, 'train'),
#  (175, 46500, 'train'),
#  (105, 69144, 'train'),
#  (116, 45240, 'train'),
#  (125, 77841, 'train'),
#  (65, 34928, 'train'),
#  (37, 7833, 'train'),
#  (33, 12238, 'train'),
#  (44, 5499, 'train'),
#  (85, 37748, 'train'),
#  (114, 61288, 'train'),
#  (148, 55072, 'train'),
#  (226, 37084, 'train'),
#  (29, 77908, 'train'),
#  (169, 55885, 'train'),
#  (182, 33507, 'train'),
#  (160, 63694, 'train'),
#  (208, 34377, 'train'),
#  (111, 67665, 'train'),
#  (149, 14270, 'train'),
#  (22, 42560, 'train'),
#  (216, 39866, 'train'),
#  (187, 54574, 'train'),
#  (106, 41823, 'train'),
#  (124, 17800, 'train'),
#  (97, 12925, 'train'),
#  (165, 3152, 'train'),
#  (174, 58460, 'train'),
#  (195, 31201, 'train'),
#  (48, 43298, 'train'),
#  (90, 5370, 'train'),
#  (78, 18370, 'train'),
#  (118, 3029, 'train'),
#  (55, 2025, 'train'),
#  (186, 68404, 'train'),
#  (73, 2169, 'train'),
#  (133, 66875, 'train'),
#  (17, 45397, 'train'),
#  (134, 65788, 'train'),
#  (87, 76287, 'train'),
#  (16, 31076, 'train'),
#  (230, 79778, 'train'),
#  (12, 78495, 'train'),
#  (119, 54652, 'train'),
#  (128, 39317, 'train'),
#  (36, 41032, 'train'),
#  (30, 64332, 'train'),
#  (206, 48162, 'train'),
#  (27, 73211, 'train'),
#  (218, 55645, 'train'),
#  (179, 3435, 'train'),
#  (54, 66271, 'train'),
#  (23, 43449, 'train'),
#  (178, 46727, 'train'),
#  (39, 60759, 'train'),
#  (58, 81595, 'train'),
#  (219, 51546, 'train'),
#  (127, 7591, 'train'),
#  (176, 32058, 'train'),
#  (15, 31981, 'train'),
#  (91, 8563, 'train'),
#  (49, 10516, 'train'),
#  (67, 49237, 'train'),
#  (89, 81102, 'train'),
#  (151, 12790, 'train'),
#  (63, 14087, 'train'),
#  (156, 24408, 'train'),
#  (108, 43947, 'train'),
#  (94, 43555, 'train'),
#  (212, 78107, 'train'),
#  (62, 7106, 'train'),
#  (34, 40004, 'train'),
#  (61, 5241, 'train'),
#  (64, 3240, 'train'),
#  (80, 47103, 'train'),
#  (117, 42355, 'train'),
#  (76, 54233, 'train'),
#  (217, 36349, 'train'),
#  (131, 19150, 'train'),
#  (164, 46895, 'train'),
#  (220, 44423, 'train'),
#  (224, 47427, 'train'),
#  (24, 18504, 'train'),
#  (189, 80942, 'train'),
#  (215, 62476, 'train'),
#  (138, 24532, 'train'),
#  (120, 75997, 'train'),
#  (137, 75937, 'train'),
#  (96, 59715, 'train'),
#  (201, 6858, 'train'),
#  (132, 17686, 'train'),
#  (223, 21409, 'train'),
#  (147, 26395, 'train'),
#  (231, 53766, 'train'),
#  (101, 32828, 'train'),
#  (197, 19488, 'train'),
#  (161, 47256, 'train'),
#  (173, 40418, 'train'),
#  (86, 60050, 'train'),
#  (188, 34756, 'train'),
#  (194, 48362, 'train'),
#  (26, 39459, 'train'),
#  (204, 40450, 'train'),
#  (203, 46620, 'train'),
#  (21, 10032, 'train'),
#  (98, 78310, 'train'),
#  (237, 6639, 'train'),
#  (232, 13637, 'train'),
#  (202, 56630, 'train'),
#  (72, 38321, 'train'),
#  (146, 14183, 'train'),
#  (14, 18110, 'train'),
#  (184, 26602, 'train'),
#  (74, 47820, 'train'),
#  (211, 24568, 'train')]
